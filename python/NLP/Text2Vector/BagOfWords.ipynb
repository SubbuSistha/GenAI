# %% [markdown]
# Bag of  words (Spam/Ham)

# %%
# !pip install chardet
import chardet
with open("spam.csv", "rb") as f:
    raw_data = f.read(100000)  # Read a large enough sample
    result = chardet.detect(raw_data)

print("Detected encoding:", result["encoding"])
# Out:
# Collecting chardet
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0
# Detected encoding: Windows-1252

# %%
import pandas

dataset = pandas.read_csv("spam.csv",names=["label","message"], encoding='Windows-1252', on_bad_lines='skip')

# %%
dataset
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5517  spam  This is the 2nd time we have tried 2 contact u...
# 5518   ham            Will ï¿½_ b going to esplanade fr home?
# 5519   ham  Pity, * was in mood for that. So...any other s...
# 5520   ham  The guy did some bitching but I acted like i'd...
# 5521   ham                         Rofl. Its true to its name
#
# [5522 rows x 2 columns]

# %% [markdown]
# Data Cleaning and Processing

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
len(dataset)
# Out:
# 5522

# %%
dataset['message'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
tokenized_messages = []
stemmer = PorterStemmer()
for i in range(len(dataset)):
    message = dataset['message'][i].lower()
    message = re.sub('[^a-zA-Z\\s]','', message)
    words_in_message = message.split()
    stemmed_words = [stemmer.stem(word) for word in words_in_message if not word in stopwords.words('english')]
    message = '  '.join(stemmed_words)
    tokenized_messages.append(message)

tokenized_messages
# Out:
# ['go  jurong  point  crazi  avail  bugi  n  great  world  la  e  buffet  cine  got  amor  wat',
#  'ok  lar  joke  wif  u  oni',
#  'free  entri  wkli  comp  win  fa  cup  final  tkt  st  may  text  fa  receiv  entri  questionstd  txt  ratetc  appli  over',
#  'u  dun  say  earli  hor  u  c  alreadi  say',
#  'nah  dont  think  goe  usf  live  around  though',
#  'freemsg  hey  darl  week  word  back  id  like  fun  still  tb  ok  xxx  std  chg  send  rcv',
#  'even  brother  like  speak  treat  like  aid  patent',
#  'per  request  mell  mell  oru  minnaminungint  nurungu  vettam  set  callertun  caller  press  copi  friend  callertun',
#  'winner  valu  network  custom  select  receivea  prize  reward  claim  call  claim  code  kl  valid  hour',
#  'mobil  month  u  r  entitl  updat  latest  colour  mobil  camera  free  call  mobil  updat  co  free',
#  'im  gonna  home  soon  dont  want  talk  stuff  anymor  tonight  k  ive  cri  enough  today',
#  'six  chanc  win  cash  pound  txt  csh  send  cost  pday  day  tsandc  appli  repli  hl  info',
#  'urgent  week  free  membership  prize  jackpot  txt  word  claim  tc  wwwdbuknet  lccltd  pobox  ldnwarw',
#  'ive  search  right  word  thank  breather  promis  wont  take  help  grant  fulfil  promis  wonder  bless  time',
#  'date  sunday',
#  'xxxmobilemovieclub  use  credit  click  wap  link  next  txt  messag  click  httpwap  xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh  kim  watch',
#  'eh  u  rememb  spell  name  ye  v  naughti  make  v  wet',
#  'fine  that  way  u  feel  that  way  gota  b',
#  'england  v  macedonia  dont  miss  goalsteam  news  txt  ur  nation  team  eg  england  trywal  scotland  txt  poboxoxwwq',
#  'serious  spell  name',
#  'im  go  tri  month  ha  ha  joke',
#  'pay  first  lar  da  stock  comin',
#  'aft  finish  lunch  go  str  lor  ard  smth  lor  u  finish  ur  lunch  alreadi',
#  'ffffffffff  alright  way  meet  sooner',
#  'forc  eat  slice  im  realli  hungri  tho  suck  mark  get  worri  know  im  sick  turn  pizza  lol',
#  'lol  alway  convinc',
#  'catch  bu  fri  egg  make  tea  eat  mom  left  dinner  feel  love',
#  'im  back  amp  pack  car  ill  let  know  there  room',
#  'ahhh  work  vagu  rememb  feel  like  lol',
#  'wait  that  still  clear  sure  sarcast  that  x  doesnt  want  live  us',
#  'yeah  got  v  apologet  n  fallen  actin  like  spoilt  child  got  caught  till  wont  go  badli  cheer',
#  'k  tell  anyth',
#  'fear  faint  housework  quick  cuppa',
#  'thank  subscript  rington  uk  mobil  charg  month  pleas  confirm  repli  ye  repli  charg',
#  'yup  ok  go  home  look  time  msg  xuhui  go  learn  nd  may  lesson',
#  'oop  ill  let  know  roommat  done',
#  'see  letter  b  car',
#  'anyth  lor  u  decid',
#  'hello  how  saturday  go  text  see  youd  decid  anyth  tomo  im  tri  invit  anyth',
#  'pl  go  ahead  watt  want  sure  great  weekend  abiola',
#  'forget  tell  want  need  crave  love  sweet  arabian  steed  mmmmmm  yummi',
#  'rodger  burn  msg  tri  call  repli  sm  free  nokia  mobil  free  camcord  pleas  call  deliveri  tomorrow',
#  'see',
#  'great  hope  like  man  well  endow  ltgt  inch',
#  'callsmessagesmiss  call',
#  'didnt  get  hep  b  immunis  nigeria',
#  'fair  enough  anyth  go',
#  'yeah  hope  tyler  cant  could  mayb  ask  around  bit',
#  'u  dont  know  stubborn  didnt  even  want  go  hospit  kept  tell  mark  im  weak  sucker  hospit  weak  sucker',
#  'think  first  time  saw  class',
#  'gram  usual  run  like  ltgt  half  eighth  smarter  though  get  almost  whole  second  gram  ltgt',
#  'k  fyi  x  ride  earli  tomorrow  morn  he  crash  place  tonight',
#  'wow  never  realiz  embarass  accomod  thought  like  sinc  best  could  alway  seem  happi  cave  im  sorri  didnt  dont  give  im  sorri  offer  im  sorri  room  embarass',
#  'sm  ac  sptv  new  jersey  devil  detroit  red  wing  play  ice  hockey  correct  incorrect  end  repli  end  sptv',
#  'know  mallika  sherawat  yesterday  find  lturlgt',
#  'congrat  year  special  cinema  pass  call  c  suprman  v  matrix  starwar  etc  free  bxipw  pm  dont  miss',
#  'sorri  ill  call  later  meet',
#  'tell  reach',
#  'yesgauti  sehwag  odi  seri',
#  'gonna  pick  burger  way  home  cant  even  move  pain  kill',
#  'ha  ha  ha  good  joke  girl  situat  seeker',
#  'part  check  iq',
#  'sorri  roommat  took  forev  ok  come',
#  'ok  lar  doubl  check  wif  da  hair  dresser  alreadi  said  wun  cut  v  short  said  cut  look  nice',
#  'valu  custom  pleas  advis  follow  recent  review  mob  award  bonu  prize  call',
#  'today  song  dedic  day  song  u  dedic  send  ur  valuabl  frnd  first  rpli',
#  'urgent  ur  award  complimentari  trip  eurodisinc  trav  acoentri  claim  txt  di  morefrmmob  shracomorsglsuplt  ls  aj',
#  'hear  new  divorc  barbi  come  ken  stuff',
#  'plane  give  month  end',
#  'wah  lucki  man  save  money  hee',
#  'finish  class',
#  'hi  babe  im  home  wanna  someth  xx',
#  'kkwhere  youhow  perform',
#  'u  call',
#  'wait  machan  call  free',
#  'that  cool  gentleman  treat  digniti  respect',
#  'like  peopl  much  shi  pa',
#  'oper  ltgt',
#  'still  look  job  much  ta  earn',
#  'sorri  ill  call  later',
#  'k  call  ah',
#  'ok  way  home  hi  hi',
#  'place  man',
#  'yup  next  stop',
#  'call  later  dont  network  urgnt  sm',
#  'real  u  get  yo  need  ticket  one  jacket  im  done  alreadi  use  multi',
#  'ye  start  send  request  make  pain  came  back  im  back  bed  doubl  coin  factori  gotta  cash  nitro',
#  'im  realli  still  tonight  babe',
#  'ela  kanoil  download  come  wen  ur  free',
#  'yeah  dont  stand  close  tho  youll  catch  someth',
#  'sorri  pain  ok  meet  anoth  night  spent  late  afternoon  casualti  mean  havent  done  stuffmoro  includ  time  sheet  sorri',
#  'smile  pleasur  smile  pain  smile  troubl  pour  like  rain  smile  sum  hurt  u  smile  becoz  someon  still  love  see  u  smile',
#  'pleas  call  custom  servic  repres  ampm  guarante  cash  prize',
#  'havent  plan  buy  later  check  alreadi  lido  got  show  e  afternoon  u  finish  work  alreadi',
#  'watch  telugu  moviewat  abt  u',
#  'see  finish  load  loan  pay',
#  'hi  wk  ok  hol  ye  bit  run  forgot  hairdress  appoint  four  need  get  home  n  shower  beforehand  caus  prob  u  ham',
#  'pleas  dont  text  anymor  noth  els  say',
#  'okay  name  ur  price  long  legal  wen  pick  u  ave  x  am  xx',
#  'im  still  look  car  buy  gone  drive  test  yet',
#  'per  request  mell  mell  oru  minnaminungint  nurungu  vettam  set  callertun  caller  press  copi  friend  callertun',
#  'wow  your  right  didnt  mean  guess  gave  boston  men  chang  search  locat  nyc  someth  chang  cuz  signin  page  still  say  boston',
#  'umma  life  vava  umma  love  lot  dear',
#  'thank  lot  wish  birthday  thank  make  birthday  truli  memor',
#  'aight  ill  hit  get  cash',
#  'would  ip  address  test  consid  comput  isnt  minecraft  server',
#  'know  grumpi  old  peopl  mom  like  better  lie  alway  one  play  joke',
#  'dont  worri  guess  he  busi',
#  'plural  noun  research',
#  'go  dinnermsg',
#  'im  ok  wif  co  like  tri  new  thing  scare  u  dun  like  mah  co  u  said  loud',
#  'gent  tri  contact  last  weekend  draw  show  prize  guarante  call  claim  code  k  valid  hr  ppm',
#  'wa  ur  openin  sentenc  formal  anyway  im  fine  juz  tt  im  eatin  much  n  puttin  weighthaha  anythin  special  happen',
#  'enter  cabin  pa  said  happi  bday  boss  felt  special  askd  lunch  lunch  invit  apart  went',
#  'winner  u  special  select  receiv  holiday  flight  inc  speak  live  oper  claim  pmin',
#  'goodo  ye  must  speak  friday  eggpotato  ratio  tortilla  need',
#  'hmmmi  uncl  inform  he  pay  school  directli  pl  buy  food',
#  'privat  account  statement  show  unredeem  bonu  point  claim  call  identifi  code  expir',
#  'urgent  mobil  award  bonu  caller  prize  final  tri  contact  u  call  landlin  boxwrc  ppm',
#  'new  address  applespairsal  malarki',
#  'today  voda  number  end  select  receiv  award  match  pleas  call  quot  claim  code  standard  rate  app',
#  'go  sao  mu  today  done',
#  'predict  wat  time  finish  buy',
#  'good  stuff',
#  'knowyetund  hasnt  sent  money  yet  sent  text  bother  send  dont  involv  anyth  shouldnt  impos  anyth  first  place  apologis',
#  'room',
#  'hey  girl  r  u  hope  u  r  well  del  r  bak  long  time  c  give  call  sum  time  lucyxx',
#  'kkhow  much  cost',
#  'im  home',
#  'dear  call  tmorrowpl  accomod',
#  'first  answer  question',
#  'sunshin  quiz  wkli  q  win  top  soni  dvd  player  u  know  countri  algarv  txt  ansr  sptyron',
#  'want  get  laid  tonight  want  real  dog  locat  sent  direct  ur  mob  join  uk  largest  dog  network  bt  txting  gravel  nt  eca  pmsgp',
#  'haf  msn  yijuehotmailcom',
#  'call  meet',
#  'check  room  befor  activ',
#  'youll  rcv  msg  chat  svc  free  hardcor  servic  text  go  u  get  noth  u  must  age  verifi  yr  network  tri',
#  'got  c  lazi  type  forgot  lect  saw  pouch  like  v  nice',
#  'k  text  your  way',
#  'sir  wait  mail',
#  'swt  thought  nver  get  tire  littl  thing  lovabl  person  cozsomtim  littl  thing  occupi  biggest  part  heart  gud  ni',
#  'know  pl  open  back',
#  'ye  see  ya  dot',
#  'what  staff  name  take  class  us',
#  'freemsg  havent  repli  text  im  randi  sexi  femal  live  local  luv  hear  u  netcollex  ltd  p  per  msg  repli  stop  end',
#  'ummmawil  call  check  inour  life  begin  qatar  pl  pray  hard',
#  'ki  delet  contact',
#  'sindu  got  job  birla  soft',
#  'wine  flow  im  never',
#  'yup  thk  cine  better  co  need  go  plaza  mah',
#  'ok  ur  typic  repli',
#  'per  request  mell  mell  oru  minnaminungint  nurungu  vettam  set  callertun  caller  press  copi  friend  callertun',
#  'everywher  dirt  floor  window  even  shirt  sometim  open  mouth  come  flow  dream  world  without  half  chore  time  joy  lot  tv  show  ill  see  guess  like  thing  must  exist  like  rain  hail  mist  time  done  becom  one',
#  'aaooooright  work',
#  'im  leav  hous',
#  'hello  love  get  interview  today  happi  good  boy  think  mear  miss',
#  'custom  servic  annonc  new  year  deliveri  wait  pleas  call  arrang  deliveri',
#  'winner  u  special  select  receiv  cash  holiday  flight  inc  speak  live  oper  claim',
#  'keep  safe  need  miss  alreadi  envi  everyon  see  real  life',
#  'new  car  hous  parentsi  new  job  hand',
#  'im  love  im  excit  day  spend  make  happi',
#  'pl  stop  bootydeli  f  invit  friend  repli  ye  see  wwwsmsacubootydeli  stop  send  stop  frnd',
#  'bangbab  ur  order  way  u  receiv  servic  msg  download  ur  content  u  goto  wap  bangb  tv  ur  mobil  internetservic  menu',
#  'place  ur  point  e  cultur  modul  alreadi',
#  'urgent  tri  contact  last  weekend  draw  show  prize  guarante  call  claim  code  valid  hr',
#  'hi  frnd  best  way  avoid  missunderstd  wit  belov  one',
#  'great  escap  fanci  bridg  need  lager  see  tomo',
#  'ye  complet  formclark  also  utter  wast',
#  'sir  need  axi  bank  account  bank  address',
#  'hmmm  thk  sure  got  time  hop  ard  ya  go  free  abt  muz  call  u  discuss  liao',
#  'time  come  later',
#  'bloodi  hell  cant  believ  forgot  surnam  mr  ill  give  u  clue  spanish  begin',
#  'well  im  gonna  finish  bath  goodfin  night',
#  'let  know  youv  got  money  carlo  make  call',
#  'u  still  go  mall',
#  'turn  friend  stay  whole  show  wont  back  til  ltgt  feel  free  go  ahead  smoke  ltgt  worth',
#  'text  doesnt  repli  let  know  log',
#  'hi  spoke  maneesha  v  wed  like  know  satisfi  experi  repli  toll  free  ye',
#  'lift  hope  offer  money  need  especi  end  month  approach  hurt  studi  anyway  gr  weekend',
#  'lol  u  trust',
#  'ok  gentleman  treat  digniti  respect',
#  'guy  close',
#  'go  noth  greatby',
#  'hello  handsom  find  job  lazi  work  toward  get  back  net  mummi  where  boytoy  miss',
#  'haha  awesom  minut',
#  'pleas  call  custom  servic  repres  freephon  ampm  guarante  cash  prize',
#  'got  xma  radio  time  get',
#  'ju  reach  home  go  bath  first  si  use  net  tell  u  finish  k',
#  'uniqu  enough  find  th  august  wwwareyouuniquecouk',
#  'im  sorri  ive  join  leagu  peopl  dont  keep  touch  mean  great  deal  friend  time  even  great  person  cost  great  week',
#  'hi  final  complet  cours',
#  'stop  howev  suggest  stay  someon  abl  give  or  everi  stool',
#  'hope  youv  settl  new  school  year  wishin  gr  day',
#  'gud  mrng  dear  hav  nice  day',
#  'u  got  person  stori',
#  'hamster  dead  hey  tmr  meet  pm  orchard  mrt',
#  'hi  kate  even  hope  see  tomorrow  bit  bloodi  babyjontet  txt  back  u  xxx',
#  'found  enc  ltgt',
#  'sent  ltgt  buck',
#  'hello  darlin  ive  finish  colleg  txt  u  finish  u  love  kate  xxx',
#  'account  refil  success  inr  ltdecimalgt  keralacircl  prepaid  account  balanc  rs  ltdecimalgt  transact  id  kr  ltgt',
#  'goodmorn  sleep  ga',
#  'u  call  alter  ok',
#  'say  like  dat  dun  buy  ericsson  oso  cannot  oredi  lar',
#  'enter  cabin  pa  said  happi  bday  boss  felt  special  askd  lunch  lunch  invit  apart  went',
#  'aight  yo  dat  straight  dogg',
#  'pleas  give  us  connect  today  ltdecimalgt  refund  bill',
#  'shoot  big  load  get  readi',
#  'what  bruv  hope  great  break  reward  semest',
#  'home  alway  chat',
#  'kkgoodstudi  well',
#  'yup  noe  leh',
#  'sound  great  home',
#  'final  match  head  toward  draw  predict',
#  'tire  havent  slept  well  past  night',
#  'easi  ahsen  got  select  mean  good',
#  'take  exam  march',
#  'yeah  think  use  gt  atm  regist  sure  there  anyway  help  let  know  sure  readi',
#  'ok  prob  take  ur  time',
#  'os  call  ubandu  run  without  instal  hard  diskyou  use  os  copi  import  file  system  give  repair  shop',
#  'sorri  ill  call  later',
#  'u  say  leh  cours  noth  happen  lar  say  v  romant  ju  bit  lor  thk  e  nite  sceneri  nice  leh',
#  'new  mobil  must  go  txt  nokia  collect  todayfrom  wwwtcbiz  optout  gbpmtmsg',
#  'would  realli  appreci  call  need  someon  talk',
#  'u  meet  ur  dream  partner  soon  ur  career  flyng  start  find  free  txt  horo  follow  ur  star  sign  e  g  horo  ari',
#  'hey  compani  elama  po  mudyadhu',
#  'life  strict  teacher  bcoz  teacher  teach  lesson  amp  conduct  exam  life  first  conduct  exam  amp  teach  lesson  happi  morn',
#  'dear  good  morn',
#  'get  gandhipuram  walk  cross  cut  road  right  side  ltgt  street  road  turn  first  right',
#  'dear  go  rubber  place',
#  'sorri  batteri  die  yeah  im',
#  'yesher  tv  alway  avail  work  place',
#  'text  meet  someon  sexi  today  u  find  date  even  flirt  u  join  p  repli  name  age  eg  sam  msg  recdthirtyeight  penc',
#  'print  oh  ltgt  come  upstair',
#  'ill  littl  closer  like  bu  stop  street',
#  'youwhen  wil  reach',
#  'new  theori  argument  win  situat  lose  person  dont  argu  ur  friend  kick  amp  say  im  alway  correct',
#  'u  secret  admir  look  make  contact  ufind  rreveal  think  ur  specialcal',
#  'tomarrow  final  hear  laptop  case  cant',
#  'pleassssssseeeee  tel  v  avent  done  sportsx',
#  'okay  shine  meant  sign  sound  better',
#  'although  told  u  dat  im  baig  face  watch  realli  like  e  watch  u  gave  co  fr  u  thanx  everyth  dat  uve  done  today  im  touch',
#  'u  dont  rememb  old  commerci',
#  'late  said  websit  didnt  dont  slipper',
#  'ask  call  ok',
#  'kalli  wont  bat  nd  inning',
#  'didnt  work  oh  ok  goodnight  ill  fix  readi  time  wake  dearli  miss  good  night  sleep',
#  'congratul  ur  award  cd  voucher  gift  guarante  free  entri  wkli  draw  txt  music  tnc  wwwldewcomwinppmxag',
#  'ranjith  cal  drpd  deeraj  deepak  min  hold',
#  'wen  ur  lovabl  bcum  angri  wid  u  dnt  take  serious  coz  angri  childish  n  true  way  show  deep  affect  care  n  luv  kettoda  manda  nice  day  da',
#  'doinghow',
#  'up  day  also  ship  compani  take  wk  way  usp  take  week  get  lag  may  bribe  nipost  get  stuff',
#  'im  back  lemm  know  your  readi',
#  'dont  necessarili  expect  done  get  back  though  im  headin',
#  'mmm  yummi  babe  nice  jolt  suzi',
#  'lover  need',
#  'tri  contact  repli  offer  video  handset  anytim  network  min  unlimit  text  camcord  repli  call',
#  'im  park  next  mini  come  today  think',
#  'yup',
#  'anyway  im  go  shop  co  si  done  yet  dun  disturb  u  liao',
#  'luton  ring  ur  around  h',
#  'hey  realli  horni  want  chat  see  nake  text  hot  text  charg  pm  unsubscrib  text  stop',
#  'dint  come  us',
#  'wana  plan  trip  sometm',
#  'sure  yet  still  tri  get  hold',
#  'ur  rington  servic  chang  free  credit  go  clubmobilescom  choos  content  stop  txt  club  stop  pwk  club  po  box  mk  wt',
#  'evo  download  flash  jealou',
#  'rington  club  get  uk  singl  chart  mobil  week  choos  top  qualiti  rington  messag  free  charg',
#  'come  mu  sort  narcot  situat',
#  'night  end  anoth  day  morn  come  special  way  may  smile  like  sunni  ray  leav  worri  blue  blue  bay',
#  'hmv  bonu  special  pound  genuin  hmv  voucher  answer  easi  question  play  send  hmv  infowwwpercentrealcom',
#  'usf  guess  might  well  take  car',
#  'object  bf  come',
#  'thanx',
#  'tell  rob  mack  gf  theater',
#  'awesom  ill  see  bit',
#  'sent  type  food  like',
#  'done  hand  celebr  full  swing  yet',
#  'got  call  tool',
#  'ok  ask  money  far',
#  'oki',
#  'yeah  think  usual  guy  still  pass  last  night  get  ahold  anybodi  let  know  ill  throw',
#  'k  might  come  tonight  class  let  earli',
#  'ok',
#  'hi  babi  im  cruisin  girl  friend  r  u  give  call  hour  home  that  alright  fone  fone  love  jenni  xxx',
#  'life  mean  lot  love  life  love  peopl  life  world  call  friend  call  world  ge',
#  'dearshal  mail  tonitebusi  streetshal  updat  toniteth  look  okvarunnathu  edukkukaye  raksha  ollubut  good  one  real  sens',
#  'hey  told  name  gautham  ah',
#  'haf  u  found  feel  stupid  da  v  cam  work',
#  'oop  got  bit',
#  'much  buzi',
#  'accident  delet  messag  resend  pleas',
#  'tmobil  custom  may  claim  free  camera  phone  upgrad  pay  go  sim  card  loyalti  call  offer  end  thfebtc  appli',
#  'unless  situat  go  gurl  would  appropri',
#  'hurt  teas  make  cri  end  life  die  plz  keep  one  rose  grave  say  stupid  miss  u  nice  day  bslvyl',
#  'cant  pick  phone  right  pl  send  messag',
#  'need  coffe  run  tomoc  believ  time  week  alreadi',
#  'awesom  rememb  last  time  got  somebodi  high  first  time  diesel  v',
#  'shit  realli  shock  scari  cant  imagin  second  def  night  u  think  somewher  could  crash  night  save  taxi',
#  'oh  way  food  fridg  want  go  meal  tonight',
#  'womdarful  actor',
#  'sm  ac  blind  date  u  rodd  aberdeen  unit  kingdom  check  httpimg  sm  acwicmbcktzr  blind  date  send  hide',
#  'yup  remb  think  book',
#  'jo  ask  u  wana  meet',
#  'lol  ye  friendship  hang  thread  caus  u  wont  buy  stuff',
#  'themob  check  newest  select  content  game  tone  gossip  babe  sport  keep  mobil  fit  funki  text  wap',
#  'garag  key  arent  bookshelf',
#  'today  accept  dayu  accept  brother  sister  lover  dear  best  clo  lvblefrnd  jstfrnd  cutefrnd  lifpartnr  belovd  swtheart  bstfrnd  rpli  mean  enemi',
#  'think  ur  smart  win  week  weekli  quiz  text  play  nowtc  winnersclub  po  box  uz  gbpweek',
#  'say  hell  give  call  friend  got  money  he  definit  buy  end  week',
#  'hi  way  u  day  normal  waythi  real  ur  uniquei  hope  know  u  rest  mylif  hope  u  find  wot  lost',
#  'made  day  great  day',
#  'kkadvanc  happi  pongal',
#  'hmmm  guess  go  kb  n  power  yoga  haha  dunno  tahan  power  yoga  anot  thk  got  lo  oso  forgot  liao',
#  'realli  dude  friend  im  afraid',
#  'decemb  mobil  mth  entitl  updat  latest  colour  camera  mobil  free  call  mobil  updat  co  free',
#  'coffe  cake  guess',
#  'merri  christma  babe  love  ya  kiss',
#  'hey  dont  go  watch  x  men  lunch  haha',
#  'cud  u  tell  ppl  im  gona  b  bit  l  co  buse  hav  gon  past  co  full  im  still  waitin  pete  x',
#  'would  great  well  guild  could  meet  bristol  road  somewher  get  touch  weekend  plan  take  flight  good  week',
#  'problem',
#  'callsmessagesmiss  call',
#  'hi  dahow  today  class',
#  'id  say  that  good  sign  well  know  track  record  read  women',
#  'cool  text  your  park',
#  'im  read  text  sent  meant  joke  read  light',
#  'kkapo  kgood  movi',
#  'mayb  could  get  book  tomo  return  immedi  someth',
#  'call  germani  penc  per  minut  call  fix  line  via  access  number  prepay  direct  access',
#  'chanc  might  evapor  soon  violat  privaci  steal  phone  number  employ  paperwork  cool  pleas  contact  report  supervisor',
#  'valentin  day  special  win  quiz  take  partner  trip  lifetim  send  go  pmsg  rcvd  custcar',
#  'tadaaaaa  home  babe  still',
#  'cool  come  havent  wine  dine',
#  'sleepingand  surf',
#  'sorri  ill  call  later',
#  'u  call  right  call  hand  phone',
#  'ok  that  great  thanx  lot',
#  'take  post  come  must  text  happi  read  one  wiv  hello  carolin  end  favourit  bless',
#  'u  hide  stranger',
#  'interest  like',
#  'sister  clear  two  round  birla  soft  yesterday',
#  'gudnitetcpractic  go',
#  'di  yiju  ju  saw  ur  mail  case  huim  havent  sent  u  num  di  num',
#  'one  small  prestig  problem',
#  'fanci  shag  dointerest  sextextukcom  txt  xxuk  suzi  txt  cost  per  msg  tnc  websit  x',
#  'check  realli  miss  see  jeremiah  great  month',
#  'nah  cant  help  ive  never  iphon',
#  'your  car  hour  half  im  go  apeshit',
#  'today  sorri  day  ever  angri  ever  misbehav  hurt  plz  plz  slap  urself  bcoz  ur  fault  im  basic  good',
#  'yo  guy  ever  figur  much  need  alcohol  jay  tri  figur  much  safe  spend  weed',
#  'ltgt  ish  minut  minut  ago  wtf',
#  'thank  callingforgot  say  happi  onam  sirjii  fine  rememb  met  insur  personmeet  qatar  insha  allahrakhesh  ex  tata  aig  join  tisscotays',
#  'congratul  ur  award  cd  voucher  gift  guarante  free  entri  wkli  draw  txt  music  tnc  wwwldewcomwinppmxag',
#  'ur  cashbal  current  pound  maxim  ur  cashin  send  cash  pmsg  cc  hgsuiteland  rowwjhl',
#  'im  actor  work  work  even  sleep  late  sinc  im  unemploy  moment  alway  sleep  late  your  unemploy  everi  day  saturday',
#  'hello  got  st  andrewsboy  long  way  cold  keep  post',
#  'ha  ha  cool  cool  chikku  chikkudb',
#  'oh  ok  prob',
#  'check  audrey  statu  right',
#  'busi  tri  finish  new  year  look  forward  final  meet',
#  'good  afternoon  sunshin  dawn  day  refresh  happi  aliv  breath  air  smile  think  love  alway',
#  'well  know  z  take  care  worri',
#  'updatenow  xma  offer  latest  motorola  sonyericsson  nokia  free  bluetooth  doubl  min  txt  orang  call  mobileupd  calloptoutfq',
#  'discount  code  rp  stop  messag  repli  stop  wwwregalportfoliocouk  custom  servic',
#  'wat  uniform  get',
#  'cool  text  your  readi',
#  'hello  boytoy  geeee  miss  alreadi  woke  wish  bed  cuddl  love',
#  'spoil  bed  well',
#  'im  go  bath  msg  next  ltgt  min',
#  'cant  keep  talk  peopl  sure  pay  agre  price  pl  tell  want  realli  buy  much  will  pay',
#  'thank  rington  order  refer  charg  gbp  per  week  unsubscrib  anytim  call  custom  servic',
#  'say  happen',
#  'could  seen  mei  didt  recognis  face',
#  'well  there  lot  thing  happen  lindsay  new  year  sigh  bar  ptbo  blue  heron  someth  go',
#  'keep  payasam  rinu  bring',
#  'taught  ranjith  sir  call  sm  like  becau  he  verifi  project  prabu  told  today  pa  dont  mistak',
#  'guess  that  worri  must  know  there  way  bodi  repair  im  quit  sure  shouldnt  worri  well  take  slow  first  test  guid  ovul  relax  noth  youv  said  reason  worri  ill  keep  followin',
#  'yeah  sure  give  coupl  minut  track  wallet',
#  'hey  leav  big  deal  take  care',
#  'hey  late  ah  meet',
#  'doubl  min  txt  month  free  bluetooth  orang  avail  soni  nokia  motorola  phone  call  mobileupd  calloptoutndx',
#  'took  mr  owl  lick',
#  'custom  place  call',
#  'mm  time  dont  like  fun',
#  'mth  half  price  orang  line  rental  latest  camera  phone  free  phone  mth  call  mobilesdirect  free  updat  orstoptxt',
#  'yup  lunch  buffet  u  eat  alreadi',
#  'huh  late  fr  dinner',
#  'hey  sat  go  intro  pilat  kickbox',
#  'morn  ok',
#  'ye  think  offic  lap  room  think  that  last  day  didnt  shut',
#  'pick  bout  ish  time  go',
#  'perform  award  calcul  everi  two  monthnot  current  one  month  period',
#  'actual  sleep  still  might  u  call  back  text  gr  rock  si  send  u  text  wen  wake',
#  'alway  put  busi  put  pictur  ass  facebook  one  open  peopl  ive  ever  met  would  think  pictur  room  would  hurt  make  feel  violat',
#  'good  even  sir  al  salam  wahleykkumshar  happi  newsbi  grace  god  got  offer  tayseertissco  joinedhop  fineinshah  allahmeet  sometimerakheshvisitor  india',
#  'hmmmkbut  want  chang  field  quickli  dai  wanna  get  system  administr  network  administr',
#  'free  rington  text  first  poli  text  get  true  tone  help  st  free  tone  xpw  end  txt  stop',
#  'dear  chechi  talk',
#  'hair  cream  ship',
#  'none  that  happen  til  get  though',
#  'yep  great  loxahatche  xma  tree  burn  ltgt  start  hour',
#  'haha  get  use  drive  usf  man  know  lot  stoner',
#  'well  slightli  disastr  class  pm  fav  darl  hope  day  ok  coffe  wld  good  cant  stay  late  tomorrow  time  place  alway',
#  'hello  good  week  fanci  drink  someth  later',
#  'headin  toward  busetop',
#  'messagesom  text  miss  sendernam  miss  number  miss  sentdat  miss  miss  u  lot  that  everyth  miss  sent  via  fullonsmscom',
#  'come  room  point  iron  plan  weekend',
#  'co  want  thing',
#  'oki  ill  go  yan  jiu  skip  ard  oso  go  cine  den  go  mrt  one  blah  blah  blah',
#  'bring  home  wendi',
#  'date  servic  call  boxskch',
#  'whatsup  dont  u  want  sleep',
#  'alright  new  goal',
#  'free  entri  weekli  competit  text  word  win  tc  wwwtxttowincouk',
#  'alright  ill  head  minut  text  meet',
#  'send  logo  ur  lover  name  join  heart  txt  love  name  name  mobno  eg  love  adam  eve  yahoo  poboxwwq  txtno  ad  p',
#  'yesfrom  last  week  im  take  live  call',
#  'someon  contact  date  servic  enter  phone  fanci  find  call  landlin  poboxntfp',
#  'siva  hostel  aha',
#  'urgent  mobil  number  award  prize  guarante  call  land  line  claim  valid  hr',
#  'send  ur  friend  receiv  someth  ur  voic  speak  express  childish  naughti  sentiment  rowdi  ful  attitud  romant  shi  attract  funni  ltgt  irrit  ltgt  lovabl  repli',
#  'ok  shell  ok  guess',
#  'aathiwher  dear',
#  'pain  urin  thing  els',
#  'esplanad  mind  give  lift  co  got  car  today',
#  'wnt  buy  bmw  car  urgentlyit  vri  urgentbut  hv  shortag  ltgt  lacsther  sourc  arng  di  amt  ltgt  lacsthat  prob',
#  'home  watch  tv  lor',
#  'usual  take  fifteen  fuck  minut  respond  ye  question',
#  'congrat  nokia  video  camera  phone  call  call  cost  ppm  ave  call  min  vari  mobil  close  post  bcm  ldn  wcnxx',
#  'book  ticket  pongal',
#  'avail  im  like  right  around  hillsborough  amp  ltgt  th',
#  'messag  sent  askin  ltgt  dollar  shoul  pay  ltgt  ltgt',
#  'ask  g  iouri  ive  told  stori  like  ten  time  alreadi',
#  'long  applebe  fuck  take',
#  'hi  hope  u  get  txtjourney  hasnt  gdnow  min  late  think',
#  'like  love  arrang',
#  'yesh  realli  greatbhaji  told  kalli  best  cricket  sachin  worldveri  tough  get',
#  'suppos  wake  gt',
#  'oic  saw  tot  din  c  found  group  liao',
#  'sorri  ill  call  later',
#  'sorri  batteri  die  come  im  get  gram  where  place',
#  'well  done  blimey  exercis  yeah  kinda  rememb  wot  hmm',
#  'wont  get  concentr  dear  know  mind  everyth',
#  'lol  made  plan  new  year',
#  'min  later  k',
#  'hank  lotsli',
#  'thank  hope  good  day  today',
#  'kkwhat  detail  want  transferacc  enough',
#  'ok  tell  stay  yeah  tough  optimist  thing  improv  month',
#  'loan  purpos  homeown  tenant  welcom  previous  refus  still  help  call  free  text  back  help',
#  'si  si  think  ill  go  make  oreo  truffl',
#  'look  ami  ure  beauti  intellig  woman  like  u  lot  know  u  dont  like  like  dont  worri',
#  'hope  that  result  consist  intellig  kind  start  ask  practicum  link  keep  ear  open  best  ttyl',
#  'call  cost  guess  isnt  bad  miss  ya  need  ya  want  ya  love  ya',
#  'go  thru  differ  feelingwav  decis  cope  individualtim  heal  everyth  believ',
#  'u  go  phone  gonna  die  stay',
#  'great  never  better  day  give  even  reason  thank  god',
#  'upgrdcentr  orang  custom  may  claim  free  camera  phone  upgrad  loyalti  call  offer  end  th  juli  tc  appli  optout  avail',
#  'sorri  ill  call  later  ok  bye',
#  'ok  way  railway',
#  'great  princess  love  give  receiv  oral  doggi  style  fave  posit  enjoy  make  love  ltgt  time  per  night',
#  'dont  put  stuff  road  keep  get  slipperi',
#  'go  ride  bike',
#  'yup  need  ill  ju  wait  e  rain  stop',
#  'mani  compani  tell  languag',
#  'okmail  dear  dave  final  notic  collect  tenerif  holiday  cash  award  call  landlin  tc  sae  box  cwwx  ppm',
#  'long  sinc  scream  princess',
#  'noth  meant  money  enter  account  bank  remov  flat  rate  someon  transfer  ltgt  account  ltgt  dollar  got  remov  bank  differ  charg  also  differb  sure  trust  ja  person  send  account  detail  co',
#  'want  get  laid  tonight  want  real  dog  locat  sent  direct  ur  mob  join  uk  largest  dog  network  txting  moan  nyt  eca  pmsgp',
#  'nice  line  said  broken  heart  plz  dont  cum  time  infront  wise  trust  u  good',
#  'ok  im  gonna  head  usf  like  fifteen  minut',
#  'love  aathilov  u  lot',
#  'tension  ahwhat  machiani  problem',
#  'k  pick  anoth  th  your  done',
#  'whenr  guy  get  back  g  said  think  stay  mcr',
#  'almost  see  u  sec',
#  'yo  carlo  friend  alreadi  ask  work  weekend',
#  'watch  tv  lor',
#  'thank  babi  cant  wait  tast  real  thing',
#  'chang  fb  jaykwon  thuglyf  falconerf',
#  'win  realli  side  long  time',
#  'free  messag  activ  free  text  messag  repli  messag  word  free  term  condit  visit  wwwcom',
#  'dear  reach  railway  happen',
#  'depend  qualiti  want  type  sent  boy  fade  glori  want  ralph  mayb',
#  'think  ive  fix  send  test  messag',
#  'sorri  man  account  dri  would  want  could  trade  back  half  could  buy  shit  credit  card',
#  'congrat  year  special  cinema  pass  call  c  suprman  v  matrix  starwar  etc  free  bxipw  pm  dont  miss',
#  'sorryin  meet  ill  call  later',
#  'class  ltgt  reunion',
#  'free  nowcan  call',
#  'got  meh',
#  'nope  think  go  monday  sorri  repli  late',
#  'told  accentur  confirm  true',
#  'kate  jackson  rec  center  ish  right',
#  'dear  reach  room',
#  'fight  world  easi  u  either  win  lose  bt  fightng  close  u  dificult  u  lose  u  lose  u  win  u  still  lose',
#  'come',
#  'check  nuerologist',
#  'lolnic  went  fish  water',
#  'congratul  week  competit  draw  u  prize  claim  call  b  tcsstop  sm  ppm',
#  'wait  e  car  dat  bore  wat  co  wait  outsid  got  noth  home  stuff  watch  tv  wat',
#  'mayb  westshor  hyde  park  villag  place  near  hous',
#  'know  how  anthoni  bring  money  ive  school  fee  pay  rent  stuff  like  that  need  help  friend  need',
#  'what  signific',
#  'opinion  jada  kusruthi  lovabl  silent  spl  charact  matur  stylish  simpl  pl  repli',
#  'latest  gs  still  scroung  ammo  want  give  new  ak  tri',
#  'prabhaim  sorydarealyfrm  heart  im  sori',
#  'lol  ok  forgiven',
#  'nojst  chang  tat',
#  'guarante  latest  nokia  phone  gb  ipod  mp  player  prize  txt  word  collect  ibhltd  ldnwh  pmtmsgrcvd',
#  'sno  competit',
#  'boltblu  tone  p  repli  poli  mono  eg  poli  cha  cha  slide  yeah  slow  jamz  toxic  come  stop  tone  txt',
#  'credit  top  httpwwwbubbletextcom  renew  pin  tgxxrz',
#  'way  transport  less  problemat  sat  night  way  u  want  ask  n  join  bday  feel  free  need  know  definit  no  book  fri',
#  'usual  person  unconsci  that  children  adult  may  behav  abnorm  ill  call',
#  'that  ebay  might  less  elsewher',
#  'shall  come  get  pickl',
#  'gonna  go  get  taco',
#  'that  rude  campu',
#  'urgent  mobil  award  bonu  caller  prize  nd  attempt  contact  call  boxqu',
#  'hi  wont  b  ard  christma  enjoy  n  merri  xma',
#  'today  offer  claim  ur  worth  discount  voucher  text  ye  savamob  member  offer  mobil  cs  sub  unsub  repli  x',
#  'ye  pretti  ladi  like  singl',
#  'reciev  tone  within  next  hr  term  condit  pleas  see  channel  u  teletext  pg',
#  'jay  say  your  doublefaggot',
#  'privat  account  statement  show  unredeem  sim  point  call  identifi  code  expir',
#  'todaysundaysunday  holidayso  work',
#  'gudnitetcpractic  go',
#  'ill  late',
#  'ive  call  hope  lr  malaria  know  miss  guy  miss  bani  big  pl  give  love  especi  great  day',
#  'good  afternoon  love  goe  day  hope  mayb  got  lead  job  think  boytoy  send  passion  kiss  across  sea',
#  'probabl  gonna  see  later  tonight  lt',
#  'mayb  fat  finger  press  button  doesnt  know',
#  'ummmmmaah  mani  mani  happi  return  day  dear  sweet  heart  happi  birthday  dear',
#  'tirupur  da  start  offic  call',
#  'wwwapplausestorecom  monthlysubscriptionpmsg  maxmonth  tcsc  web  age  stop  txt  stop',
#  'famou  quot  develop  abil  listen  anyth  uncondit  without  lose  temper  self  confid  mean  marri',
#  'go  colleg  pa  els  ill  come  self  pa',
#  'oclock  mine  bash  flat  plan',
#  'girl  stay  bed  girl  doesnt  need  recoveri  time  id  rather  pass  fun  coop  bed',
#  'special',
#  'know  need  get  hotel  got  invit  apologis  cali  sweet  come  english  bloke  weddin',
#  'sorri  took  long  omw',
#  'wait  ltgt  min',
#  'ok  give  minut  think  see  btw  your  alibi  cut  hair  whole  time',
#  'imagin  final  get  sink  bath  put  pace  mayb  even  eat  left  also  imagin  feel  cage  cock  surround  bath  water  remind  alway  own  enjoy  cuck',
#  'hurri  ive  weeddefici  like  three  day',
#  'sure  get  acknowledg  astoundingli  tactless  gener  faggi  demand  blood  oath  fo',
#  'ok  everi  night  take  warm  bath  drink  cup  milk  youll  see  work  magic  still  need  loos  weight  know',
#  'ill  look  fri  pan  case  cheap  book  perhap  that  silli  fri  pan  isnt  like  book',
#  'well  uv  caus  mutat  sunscreen  like  essenti  theseday',
#  'lunchyou  onlinewhi',
#  'know  friend  alreadi  told',
#  'hi  princess  thank  pic  pretti',
#  'aiyo  u  alway  c  ex  one  dunno  abt  mei  repli  first  time  u  repli  fast  lucki  workin  huh  got  bao  ur  sugardad  ahge',
#  'hi  msg  meim  offic',
#  'thanx  e  browni  v  nice',
#  'geeeee  love  much  bare  stand',
#  'gent  tri  contact  last  weekend  draw  show  prize  guarante  call  claim  code  k  valid  hr  ppm',
#  'fuck  babe  miss  alreadi  know  cant  let  send  money  toward  net  need  want  crave',
#  'ill  call  u  mrw  ninish  address  icki  american  freek  wont  stop  callin  bad  jen  k  eh',
#  'oooh  bed  ridden  ey  think',
#  'anyway  go  gym  whatev  love  smile  hope  ok  good  day  babe  miss  much  alreadi',
#  'love  daddi  make  scream  pleasur  go  slap  ass  dick',
#  'wot  u  wanna  missi',
#  'yar  lor  wait  mum  finish  sch  lunch  lor  whole  morn  stay  home  clean  room  room  quit  clean  hee',
#  'know  lab  goggl  went',
#  'open  door',
#  'wait  call',
#  'nope  wait  sch  daddi',
#  'cash  prize  claim  call',
#  'im  tire  argu  week  week  want  ill',
#  'wait  sch  finish  ard',
#  'mobil  number  claim  call  us  back  ring  claim  hot  line',
#  'arngd  marriag  u  r  walkin  unfortuntli  snake  bite  u  bt  love  marriag  danc  frnt  snake  amp  sayin  bite  bite',
#  'huh  earli  dinner  outsid  izzit',
#  'ok  anyway  need  chang  said',
#  'tri  contact  repli  offer  min  textand  new  video  phone  call  repli  free  deliveri  tomorrow',
#  'exwif  abl  kid  want  kid  one  day',
#  'how  scotland  hope  show  jjc  tendenc  take  care  live  dream',
#  'tell  u  headach  want  use  hour  sick  time',
#  'dun  thk  ill  quit  yet  hmmm  go  jazz  yogasana  oso  go  meet  em  lesson  den',
#  'pete  pleas  ring  meiv  hardli  gotani  credit',
#  'ya  srsli  better  yi  tho',
#  'im  meet  call  later',
#  'ur  chanc  win  wkli  shop  spree  txt  shop  tsc  wwwtxtshopcom  custcar  xpwk',
#  'special  select  receiv  pound  award  call  line  close  cost  ppm  tc  appli  ag  promo',
#  'privat  account  statement  show  unredeem  point  call  identifi  code  expir',
#  'still  grand  prix',
#  'met  stranger  choos  friend  long  world  stand  friendship  never  end  let  friend  forev  gud  nitz',
#  'great',
#  'gud  mrng  dear  nice  day',
#  'import  custom  servic  announc  call  freephon',
#  'exhaust  train  morn  much  wine  pie  sleep  well',
#  'im  go  buy  mum  present  ar',
#  'mind  blastin  tsunami  occur  rajnik  stop  swim  indian  oceand',
#  'u  send  home  first  ok  lor  im  readi  yet',
#  'speak  cash  yet',
#  'happi  come  noon',
#  'meet  lunch  la',
#  'take  care  n  get  well  soon',
#  'xclusiveclubsaisai  morow  soire  special  zouk  nichol  parisfre  rose  ladi  info',
#  'meant  say  cant  wait  see  u  get  bore  bridgwat  banter',
#  'neva  mind  ok',
#  'fine  imma  get  drink  somethin  want  come  find',
#  'day  kick  euro  u  kept  date  latest  news  result  daili  remov  send  get  txt  stop',
#  'valentin  game  send  di  msg  ur  friend  answer  r  someon  realli  love  u  que  colour  suit  bestrpli',
#  'mani  depend',
#  'thanx  today  cer  nice  catch  ave  find  time  often  oh  well  take  care  c  u  soonc',
#  'call  said  himthen  choos  futur',
#  'happi  valentin  day  know  earli  hundr  handsom  beauti  wish  thought  finish  aunti  uncl  st',
#  'like  v  shock  leh  co  tell  shuhui  like  tell  leona  also  like  dat  almost  know  liao  got  ask  abt  ur  reaction  lor',
#  'famili  happi',
#  'come  n  pick  come  immedi  aft  ur  lesson',
#  'let  snow  let  snow  kind  weather  bring  ppl  togeth  friendship  grow',
#  'dear  got  ltgt  dollar  hi  hi',
#  'good  word  word  may  leav  u  dismay  mani  time',
#  'make  sure  alex  know  birthday  fifteen  minut  far  your  concern',
#  'sorri  got  thing  may  pub  later',
#  'nah  straight  bring  bud  drink  someth  that  actual  littl  use  straight  cash',
#  'haha  good  hear  im  offici  paid  market  th',
#  'mani  lick  take  get  center  tootsi  pop',
#  'yup  thk  r  e  teacher  said  make  face  look  longer  darren  ask  cut  short',
#  'new  textbuddi  chat  horni  guy  ur  area  p  free  receiv  search  postcod  gaytextbuddycom  txt  one  name',
#  'today  vodafon  number  end  select  receiv  award  number  match  call  receiv  award',
#  'pleas  dont  say  like  hi  hi  hi',
#  'thank  u',
#  'oh  forward  messag  thought  send',
#  'got  seventeen  pound  seven  hundr  ml  hope  ok',
#  'dear  voucher  holder  claim  week  offer  pc  go  httpwwwetlpcoukexpressoff  tsc  appli  stop  text  txt  stop',
#  'n  funni',
#  'sweetheart  hope  kind  day  one  load  reason  smile  biola',
#  'login  dat  time  dad  fetch  home',
#  'shower  babi',
#  'askd  u  question  hour  answer',
#  'well  imma  definit  need  restock  thanksgiv  ill  let  know  im',
#  'said  kiss  kiss  cant  sound  effect  gorgeou  man  isnt  kind  person  need  smile  brighten  day',
#  'probabl  gonna  swing  wee  bit',
#  'ya  nice  readi  thursday',
#  'allo  brave  buse  taken  train  triumph  mean  bham  jolli  good  rest  week',
#  'watch  cartoon  listen  music  amp  eve  go  templ  amp  church  u',
#  'mind  ask  happen  dont  say  uncomfort',
#  'privat  account  statement  show  unredeem  point  call  identifi  code  expir',
#  'prob  send  email',
#  'cash  prize  claim  call  tc  rstm  sw  ss  ppm',
#  'that  cool  sometim  slow  gentl  sonetim  rough  hard',
#  'im  gonna  say  sorri  would  normal  start  panic  time  sorri  see  tuesday',
#  'wait  know  wesley  town  bet  hella  drug',
#  'fine  miss  much',
#  'u  got  person  stori',
#  'tell  drug  dealer  get  impati',
#  'sun  cant  come  earth  send  luv  ray  cloud  cant  come  river  send  luv  rain  cant  come  meet  u  send  care  msg  u  gud  evng',
#  'place  man',
#  'doesnt  make  sens  take  unless  free  need  know  wikipediacom',
#  'premium  phone  servic  call',
#  'sea  lay  rock  rock  envelop  envelop  paper  paper  word',
#  'mum  repent',
#  'sorri  go  home  first  daddi  come  fetch  later',
#  'leav  de  start  prepar  next',
#  'ye  babi  studi  posit  kama  sutra',
#  'en  chikku  nang  bakra  msg  kalstiyathen  teacoffe',
#  'carlosl  minut  still  need  buy',
#  'pay  ltdecimalgt  lakh',
#  'good  even  ttyl',
#  'u  receiv  msg',
#  'ho  ho  big  belli  laugh  see  ya  tomo',
#  'get  ur  st  rington  free  repli  msg  tone  gr  top  tone  phone  everi  week  per  wk  opt  send  stop',
#  'ditto  wont  worri  say  anyth  anymor  like  said  last  night  whatev  want  ill  peac',
#  'ive  got  ltgt  way  could  pick',
#  'dont  knw  pa  drink  milk',
#  'mayb  say  hi  find  got  card  great  escap  wetherspoon',
#  'piggi  r  u  awak  bet  ure  still  sleep  im  go  lunch',
#  'caus  im  freaki  lol',
#  'miss  call  caus  yell  scrappi  miss  u  cant  wait  u  come  home  im  lone  today',
#  'hex  place  talk  explain',
#  'log  wat  sdrybi',
#  'xy  go  e  lunch',
#  'hi  im  sue  year  old  work  lapdanc  love  sex  text  live  im  bedroom  text  sue  textoper  g  da  ppmsg',
#  'want  ask  wait  finish  lect  co  lect  finish  hour  anyway',
#  'finish  work  yet',
#  'everi  king  cri  babi  everi  great  build  map  imprtant  u  r  today  u  wil  reach  tomorw  gud  ni',
#  'dearm  cherthalain  case  u  r  come  cochin  pl  call  bfore  u  starti  shall  also  reach  accordinglyor  tell  day  u  r  comingtmorow  engag  an  holiday',
#  'thank  love  torch  bold',
#  'forward  pleas  call  immedi  urgent  messag  wait',
#  'farm  open',
#  'sorri  troubl  u  buy  dad  big  small  sat  n  sun  thanx',
#  'sister  law  hope  great  month  say  hey  abiola',
#  'purchas  stuff  today  mail  po  box  number',
#  'ah  poop  look  like  ill  prob  send  laptop  get  fix  cuz  gpu  problem',
#  'good  good  job  like  entrepreneur',
#  'aight  close  still  around  alex  place',
#  'meet  corpor  st  outsid  gap  see  mind  work',
#  'mum  ask  buy  food  home',
#  'ku  also  dont  msg  repli  msg',
#  'much  r  will  pay',
#  'sorri  ill  call  later',
#  'import  prevent  dehydr  give  enough  fluid',
#  'that  bit  weird  even  suppos  happen  good  idea  sure  pub',
#  'true  deari  sat  pray  even  felt  soso  smsd  time',
#  'dont  think  get  away  trek  long  famili  town  sorri',
#  'wanna  gym  harri',
#  'quit  late  lar  ard  anyway  wun  b  drivin',
#  'review  keep  fantast  nokia  ngage  game  deck  club  nokia  go  wwwcnupdatescomnewslett  unsubscrib  alert  repli  word',
#  'mth  half  price  orang  line  rental  latest  camera  phone  free  phone  mth  call  mobilesdirect  free  updat  orstoptxt  tc',
#  'seem  like  weird  time  night  g  want  come  smoke  day  shitstorm  attribut  alway  come  make  everyon  smoke',
#  'ampm  cost  p',
#  'save  stress  person  dorm  account  send  account  detail  money  sent',
#  'also  know  lunch  menu  da  know',
#  'stuff  sell  ill  tell',
#  'urgent  nd  attempt  contact  uu  call  b  tcsbcmwcnxx  callcost  ppm  mobilesvari  max',
#  'book  lesson  msg  call  work  sth  im  go  get  spec  membership  px',
#  'guarante  cash  prize  claim  yr  prize  call  custom  servic  repres  ampm',
#  'macha  dont  feel  upseti  assum  mindsetbeliev  one  even  wonder  plan  uslet  life  begin  againcal  anytim',
#  'oh  send  address',
#  'sfine  anytim  best',
#  'wondar  full  flim',
#  'ya  even  cooki  jelli',
#  'world  run  stillmayb  feel  sameso  itor  admiti  madthen  correctionor  let  call  lifeand  keep  run  worldmay  u  r  also  runninglet  run',
#  'got  look  scrumptiou  daddi  want  eat  night  long',
#  'co  lar  im  ba  dao  ok  pm  lor  u  never  ask  go  ah  said  u  would  ask  fri  said  u  ask  today',
#  'alright  omw  gotta  chang  order  halfth',
#  'exactli  anyway  far  jide  studi  visit',
#  'dunno  u  ask',
#  'email  alertfrom  jeri  stewarts  kbsubject  lowcost  prescripiton  drvgsto  listen  email  call',
#  'didnt  spring  come  earli  yay',
#  'lol  wont  feel  bad  use  money  take  steak  dinner',
#  'even  u  dont  get  troubl  convincingjust  tel  twice  tel  neglect  msg  dont  c  read  itjust  dont  repli',
#  'leav  qatar  tonit  search  opportunityal  went  fastpl  add  ur  prayer  dearrakhesh',
#  'one  talk',
#  'thank  look  realli  appreci',
#  'hi  custom  loyalti  offerth  new  nokia  mobil  txtauction  txt  word  start  get  tctxt  tc  pmtmsg',
#  'wish',
#  'haha  mayb  ure  rite  u  know  well  da  feel  like  someon  gd  lor  u  faster  go  find  one  gal  group  attach  liao',
#  'ye  glad  made',
#  'well  littl  time  thing  good  time  ahead',
#  'got  room  soon  hadnt  put  clock  back  til  shout  everyon  get  realis  wahay  anoth  hour  bed',
#  'ok  may  free  gym',
#  'men  like  shorter  ladi  gaze  eye',
#  'dunno  ju  say  go  lido  time',
#  'promis  take  good  care  princess  run  pleas  send  pic  get  chanc  ttyl',
#  'u  subscrib  best  mobil  content  servic  uk  per  day  send  stop  helplin',
#  'reason  weve  spoken  year  anyway  great  week  best  exam',
#  'monday  next  week  give  full  gist',
#  'realiz  year  well  thousand  old  ladi  run  around  tattoo',
#  'import  custom  servic  announc  premier',
#  'dont  gimm  lip  caveboy',
#  'get  librari',
#  'reali  sorryi  dont  recognis  number  confus  r  u  pleas',
#  'didnt  holla',
#  'cant  think  anyon  spare  room  top  head',
#  'faith  make  thing  possiblehop  make  thing  worklov  make  thing  beautifulmay  three  christmasmerri  christma',
#  'u  made  appoint',
#  'call  youcarlo  isar  phone  vibrat  act  might  hear  text',
#  'romant  pari  night  flight  book  next  year  call  tsc  appli',
#  'grandma  oh  dear  u  still  ill  felt  shit  morn  think  hungov  anoth  night  leav  sat',
#  'urgent  ur  guarante  award  still  unclaim  call  closingd  claimcod  mm  pmmorefrommobilebremovedmobypoboxlsyf',
#  'noth  ju  tot  u  would  ask  co  u  ba  gua  went  mt  faber  yest  yest  ju  went  alreadi  mah  today  go  ju  call  lor',
#  'wish  famili  merri  x  ma  happi  new  year  advanc',
#  'ur  award  citi  break  could  win  summer  shop  spree  everi  wk  txt  store  skilgm  tscswinawkag  perwksub',
#  'im  nt  goin  got  somethin  unless  meetin  dinner  lor  haha  wonder  go  ti  time',
#  'sorri  ill  call  later',
#  'cant  pick  phone  right  pl  send  messag',
#  'lol  know  theyr  dramat  school  alreadi  close  tomorrow  appar  cant  drive  inch  snow  suppos  get',
#  'get  anywher  damn  job  hunt',
#  'lol  u  drunkard  hair  moment  yeah  still  tonight  wat  plan',
#  'idc  get  weasel  way  shit  twice  row',
#  'wil  ltgt  minut  got  space',
#  'sleepingand  surf',
#  'thank  pick  trash',
#  'dont  go  tell  friend  your  sure  want  live  smoke  much  spend  hour  beg  come  smoke',
#  'hi  kate  love  see  tonight  ill  phone  tomorrow  got  sing  guy  gave  card  xxx',
#  'happi  new  year  dear  brother  realli  miss  got  number  decid  send  text  wish  happi  abiola',
#  'mean  get  door',
#  'opinion  jada  kusruthi  lovabl  silent  spl  charact  matur  stylish  simpl  pl  repli',
#  'hmmm  thought  said  hour  slave  late  punish',
#  'beerag',
#  'import  custom  servic  announc  premier  call  freephon',
#  'dont  think  turn  like  randomlli  within  min  open',
#  'suppos  couldnt  make  she  still  town  though',
#  'time  fix  spell  sometim  get  complet  diff  word  go  figur',
#  'ever  thought  live  good  life  perfect  partner  txt  back  name  age  join  mobil  commun  psm',
#  'free  top  polyphon  tone  call  nation  rate  get  toppoli  tune  sent  everi  week  text  subpoli  per  pole  unsub',
#  'gud  mrng  dear  hav  nice  day',
#  'hope  enjoy  game  yesterday  sorri  ive  touch  pl  know  fondli  bein  thot  great  week  abiola',
#  'e  best  ur  drive  tmr',
#  'ywhere  u  dogbreath  sound  like  jan  c  that  al',
#  'omg  want  scream  weigh  lost  weight  woohoo',
#  'gener  isnt  one  uncount  noun  u  dictionari  piec  research',
#  'realli  get  hang  around',
#  'orang  custom  may  claim  free  camera  phone  upgrad  loyalti  call  offer  end  thmarch  tc  appli  optout  availa',
#  'petey  boy  wherear  friendsar  thekingshead  come  canlov  nic',
#  'ok  msg  u  b  leav  hous',
#  'gimm  ltgt  minut  ago',
#  'last  chanc  claim  ur  worth  discount  voucher  today  text  shop  savamob  offer  mobil  cs  savamob  pobox  muz  sub',
#  'appt  lttimegt  fault  u  dont  listen  told  u  twice',
#  'free  st  week  nokia  tone  ur  mobil  everi  week  txt  nokia  get  txting  tell  ur  mate  wwwgetzedcouk  pobox  wwq  normpton',
#  'guarante  award  even  cashto  claim  ur  award  call  free  stop  getstop  php  rg  jx',
#  'k  ill',
#  'dled  imp',
#  'sure  make  sure  know  aint  smokin  yet',
#  'boooo  alway  work  quit',
#  'take  half  day  leav  bec  well',
#  'ugh  dont  wanna  get  bed  warm',
#  'ssnervou  ltgt',
#  'there  ring  come  guy  costum  gift  futur  yowif  hint  hint',
#  'congratul  ur  award  either  cd  gift  voucher  free  entri  weekli  draw  txt  music  tnc  wwwldewcomwinppmxag',
#  'borrow  ur  bag  ok',
#  'u  outbid  simonwatson  shinco  dvd  plyr  bid  visit  sm  acsmsreward  end  bid  notif  repli  end',
#  'where  boytoy  miss  happen',
#  'lot  use  one  babe  model  doesnt  help  youi  bring  hell  match',
#  'also  bring  galileo  dobbi',
#  'respond',
#  'boo  babe  u  enjoyin  yourjob  u  seem  b  gettin  well  hunnyhop  ure  oktak  care  illspeak  u  soonlot  lovem  xxxx',
#  'good  afternoon  starshin  how  boytoy  crave  yet  ach  fuck  sip  cappuccino  miss  babe  teas  kiss',
#  'road  cant  txt',
#  'smsservic  yourinclus  text  credit  pl  goto  wwwcomuknet  login  qxj  unsubscrib  stop  extra  charg  help  comuk  cm  ae',
#  'p  alfi  moon  children  need  song  ur  mob  tell  ur  ms  txt  tone  chariti  nokia  poli  chariti  poli  zed  profit  chariti',
#  'good  even  ttyl',
#  'hmm  bit  piec  lol  sigh',
#  'hahahaus  brain  dear',
#  'hey  got  mail',
#  'sorri  light  turn  green  meant  anoth  friend  want  ltgt  worth  may  around',
#  'thank  yesterday  sir  wonder  hope  enjoy  burial  mojibiola',
#  'u  secret  admir  reveal  think  u  r  special  call  opt  repli  reveal  stop  per  msg  recd  cust  care',
#  'hi  mate  rv  u  hav  nice  hol  messag  say  hello  coz  havent  sent  u  age  start  drive  stay  roadsrvx',
#  'dear  voucher  holder  claim  week  offer  pc  pleas  go  httpwwwetlpcoukexpressoff  tsc  appli  stop  text  txt  stop',
#  'thank  much  skype  wit  kz  sura  didnt  get  pleasur  compani  hope  good  weve  given  ultimatum  oh  countin  aburo  enjoy  messag  sent  day  ago',
#  'sure  result  offer',
#  'good  morn  dear  great  amp  success  day',
#  'want  anytim  network  min  text  new  video  phone  five  pound  per  week  call  repli  deliveri  tomorrow',
#  'sir  late  pay  rent  past  month  pay  ltgt  charg  felt  would  inconsider  nag  someth  give  great  cost  that  didnt  speak  howev  recess  wont  abl  pay  charg  month  henc  askin  well  ahead  month  end  pleas  help  thank',
#  'tri  contact  offer  new  video  phone  anytim  network  min  half  price  rental  camcord  call  repli  deliveri  wed',
#  'last  chanc  claim  ur  worth  discount  voucherstext  ye  nowsavamobmemb  offer  mobil  cs  sub  remov  txt  x  stop',
#  'luv  u  soo  much  u  dont  understand  special  u  r  ring  u  morrow  luv  u  xxx',
#  'pl  send  comprehens  mail  im  pay  much',
#  'prashanthettan  mother  pass  away  last  night  pray  famili',
#  'urgent  call  landlin  complimentari  ibiza  holiday  cash  await  collect  sae  tc  po  box  sk  wp  ppm',
#  'kkwhen  go',
#  'meanwhil  shit  suit  xavier  decid  give  us  ltgt  second  warn  samantha  come  play  jay  guitar  impress  shit  also  dont  think  doug  realiz  dont  live  anymor',
#  'stomach  thru  much  trauma  swear  cant  eat  better  lose  weight',
#  'officewhat  mattermsg  nowi  call  break',
#  'yeah  there  bare  enough  room  two  us  x  mani  fuck  shoe  sorri  man  see  later',
#  'today  offer  claim  ur  worth  discount  voucher  text  ye  savamob  member  offer  mobil  cs  sub  unsub  repli  x',
#  'u  reach  orchard  alreadi  u  wan  go  buy  ticket  first',
#  'real  babi  want  bring  inner  tigress',
#  'da  run  activ  full  version  da',
#  'ah  poor  babyhop  urfeel  bettersn  luv  probthat  overdos  work  hey  go  care  spk  u  sn  lot  lovejen  xxx',
#  'stop  stori  ive  told  ive  return  he  say  order',
#  'talk  sexi  make  new  friend  fall  love  world  discreet  text  date  servic  text  vip  see  could  meet',
#  'go  take  babe',
#  'hai  ana  tomarrow  come  morn  ltdecimalgt  ill  sathi  go  rto  offic  repli  came  home',
#  'spoon  okay',
#  'say  somebodi  name  tampa',
#  'work  go  min',
#  'brother  geniu',
#  'sorri  guess  whenev  get  hold  connect  mayb  hour  two  ill  text',
#  'u  find  time  bu  coz  need  sort  stuff',
#  'dude  ive  see  lotta  corvett  late',
#  'congratul  ur  award  either  yr  suppli  cd  virgin  record  mysteri  gift  guarante  call  tsc  wwwsmsconet  pm  approx  min',
#  'consid  wall  bunker  shit  import  never  play  peac  guess  place  high  enough  dont  matter',
#  'privat  account  statement  xxxxxx  show  unredeem  point  call  identifi  code  expir',
#  'hello  need  posh  bird  chap  user  trial  prod  champney  put  need  address  dob  asap  ta  r',
#  'u  want  xma  free  text  messag  new  video  phone  half  price  line  rental  call  free  find',
#  'well  offici  philosoph  hole  u  wanna  call  home  readi  save',
#  'go  goodno  problembut  still  need  littl  experi  understand  american  custom  voic',
#  'ill  text  drop  x',
#  'ugh  long  day  im  exhaust  want  cuddl  take  nap',
#  'talk  atleast  day  otherwis  miss  best  friend  world  shakespear  shesil  ltgt',
#  'shop  till  u  drop  either  k  k  cash  travel  voucher  call  ntt  po  box  crbt  fixedlin  cost  ppm  mobil  vari',
#  'castor  need  see  someth',
#  'sunshin  quiz  wkli  q  win  top  soni  dvd  player  u  know  countri  liverpool  play  mid  week  txt  ansr  sptyron',
#  'u  secret  admir  look  make  contact  ufind  rreveal  think  ur  specialcal',
#  'u  secret  admir  look  make  contact  ufind  rreveal  think  ur  specialcal  stopsm',
#  'remind  download  content  alreadi  paid  goto  httpdoit  mymobi  tv  collect  content',
#  'see  knew  give  break  time  woul  lead  alway  want  miss  curfew  gonna  gibe  til  one  midnight  movi  gonna  get  til  need  come  home  need  getsleep  anyth  need  b  studdi  ear  train',
#  'love  give  massag  use  lot  babi  oil  fave  posit',
#  'dude  go  sup',
#  'yoyyooo  u  know  chang  permiss  drive  mac  usb  flash  drive',
#  'gibb  unsoldmik  hussey',
#  'like  talk  pa  abl  dont  know',
#  'dun  cut  short  leh  u  dun  like  ah  fail  she  quit  sad',
#  'unbeliev  faglord',
#  'wifehow  knew  time  murder  exactli',
#  'ask  princess',
#  'great  princess  think',
#  'nutter  cutter  ctter  cttergg  cttargg  ctargg  ctagg  ie',
#  'ok  noe  ure  busi  im  realli  bore  msg  u  oso  dunno  wat  colour  choos  one',
#  'doesnt  g  class  earli  tomorrow  thu  shouldnt  tri  smoke  ltgt',
#  'superb  thought  grate  u  dont  everyth  u  want  mean  u  still  opportun  happier  tomorrow  u  today',
#  'hope  good  week  check',
#  'im  use  hope  agent  dont  drop  sinc  ive  book  thing  year  whole  boston  nyc  experi',
#  'thursday  night  yeah  sure  thing  well  work',
#  'probabl  money  worri  thing  come  due  sever  outstand  invoic  work  two  three  month  ago',
#  'possibl  teach',
#  'wonder  phone  batteri  went  dead  tell  love  babe',
#  'love  smell  bu  aint  tobacco',
#  'get  worri  derek  taylor  alreadi  assum  worst',
#  'hey  what  charl  sorri  late  repli',
#  'lastest  stereophon  marley  dizze  racal  libertin  stroke  win  nookii  game  flirt  click  themob  wap  bookmark  text  wap',
#  'ill  give  plu  said  grinul  greet  whenev  speak',
#  'white  fudg  oreo  store',
#  'januari  male  sale  hot  gay  chat  cheaper  call  nation  rate  pmin  cheap  pmin  peak  stop  text  call  pmin',
#  'love  come  took  long  leav  zaher  got  word  ym  happi  see  sad  left  miss',
#  'sorri  hurt',
#  'cant  feel  nauseou  im  piss  didnt  eat  sweet  week  caus  today  plan  pig  diet  week  im  hungri',
#  'ok  lor  earli  still  project  meet',
#  'call  da  wait  call',
#  'could  ask  carlo  could  get  anybodi  els  chip',
#  'actual  send  remind  today  wonder  weekend',
#  'peopl  see  msg  think  iam  addict  msging  wrong  bcoz  dont  know  iam  addict  sweet  friend  bslvyl',
#  'hey  gave  photo  regist  drive  ah  tmr  wanna  meet  yck',
#  'dont  talk  ever  ok  word',
#  'u  wana  see',
#  'way  school  pl  send  ashley  number',
#  'shall  fine  avalarr  hollalat',
#  'went  attend  anoth  two  round  todaybut  still  didt  reach  home',
#  'actual  delet  old  websitenow  blog  magicalsongsblogspotcom',
#  'k  wait  chikkuil  send  aftr  ltgt  min',
#  'im  diet  ate  mani  slice  pizza  yesterday  ugh  im  alway  diet',
#  'ki  give  kvb  acc  detail',
#  'oh  come  ah',
#  'money  r  lucki  winner  claim  prize  text  money  million  give  away  pptxnormal  text  rate  box  wtji',
#  'im  realli  sorri  wont  b  abl  fridayhop  u  find  alternativehop  yr  term  go  ok',
#  'congratul  ore  mo  owo  wa  enjoy  wish  mani  happi  moment  fro  wherev  go',
#  'samu  shoulder  yet',
#  'time  think  youll  need  know  near  campu',
#  'dear  matthew  pleas  call  landlin  complimentari  lux  tenerif  holiday  cash  await  collect  ppm  sae  tc  box  skxh',
#  'dun  wear  jean  lor',
#  'sinc  side  fever  vomitin',
#  'kkare  colleg',
#  'urgent  call  landlin  complimentari  tenerif  holiday  cash  await  collect  sae  tc  box  hp  yf  ppm',
#  'better  made  friday  stuf  like  pig  yesterday  feel  bleh  least  writh  pain  kind  bleh',
#  'sell  well  ton  coin  sell  coin  someon  thru  paypal  voila  money  back  life  pocket',
#  'theyr  lot  place  hospit  medic  place  safe',
#  'get  touch  folk  wait  compani  txt  back  name  age  opt  enjoy  commun  psm',
#  'also  ive  sorta  blown  coupl  time  recent  id  rather  text  blue  look  weed',
#  'sent  score  sopha  secondari  applic  school  think  think  appli  research  cost  also  contact  joke  ogunrind  school  one  less  expens  one',
#  'cant  wait  see  photo  use',
#  'ur  cashbal  current  pound  maxim  ur  cashin  send  go  pmsg  cc  po  box  tcrw',
#  'hey  book  kb  sat  alreadi  lesson  go  ah  keep  sat  night  free  need  meet  confirm  lodg',
#  'chk  ur  belovd  ms  dict',
#  'time  want  come',
#  'awesom  lemm  know  whenev  your  around',
#  'shb  b  ok  lor  thanx',
#  'beauti  truth  graviti  read  care  heart  feel  light  someon  feel  heavi  someon  leav  good  night',
#  'also  rememb  get  dobbi  bowl  car',
#  'filthi  stori  girl  wait',
#  'sorri  c  ur  msg  yar  lor  poor  thing  one  night  tmr  ull  brand  new  room  sleep',
#  'love  isnt  decis  feel  could  decid  love  life  would  much  simpler  less  magic',
#  'welp  appar  retir',
#  'sort  code  acc  bank  natwest  repli  confirm  ive  sent  right  person',
#  '',
#  'u  sure  u  cant  take  sick  time',
#  'urgent  tri  contact  u  today  draw  show  prize  guarante  call  land  line  claim  validhr',
#  'watch  cartoon  listen  music  amp  eve  go  templ  amp  church  u',
#  'yo  chad  gymnast  class  wanna  take  site  say  christian  class  full',
#  'much  buzi',
#  'better  still  catch  let  ask  sell  ltgt',
#  'sure  night  menu  know  noon  menu',
#  'u  want  come  backa  beauti  necklac  token  heart  youthat  give  wife  likingb  seeno  one  give  thatdont  call  mei  wait  till  come',
#  'will  go  aptitud  class',
#  'wont  b  tri  sort  hous  ok',
#  'yar  lor  wan  go  c  hors  race  today  mah  eat  earlier  lor  ate  chicken  rice  u',
#  'haha  awesom  omw  back',
#  'yup  thk  e  shop  close  lor',
#  'account  number',
#  'eh  u  send  wrongli  lar',
#  'hey  ad  crap  nite  borin  without  ya  boggi  u  bore  biatch  thanx  u  wait  til  nxt  time  il  ave  ya',
#  'ok  shall  talk',
#  'dont  hesit  know  second  time  weak  like  keep  notebook  eat  day  anyth  chang  day  sure  noth',
#  'hey  pay  salari  de  ltgt',
#  'anoth  month  need  chocol  weed  alcohol',
#  'start  search  get  job  daysh  great  potenti  talent',
#  'reckon  need  town  eightish  walk  carpark',
#  'congrat  mobil  g  videophon  r  call  videochat  wid  mate  play  java  game  dload  polyph  music  nolin  rentl',
#  'look  fuckin  time  fuck  think',
#  'yo  guess  drop',
#  'carlo  say  hell  mu  ltgt  minut',
#  'im  offic  call  ltgt  min',
#  'geeee  miss  alreadi  know  think  fuck  cant  wait  till  next  year  togeth  love  kiss',
#  'yun  ahth  ubi  one  say  wan  call  tomorrowcal  look  ireneer  got  bu  ubi  cresubi  tech  parkph  st  wkg  daysn',
#  'ugh  gotta  drive  back  sd  la  butt  sore',
#  'th  juli',
#  'hi  im  relax  time  ever  get  everi  day  parti  good  night  get  home  tomorrow  ish',
#  'wan  come  come  lor  din  c  stripe  skirt',
#  'xma  stori  peac  xma  msg  love  xma  miracl  jesu  hav  bless  month  ahead  amp  wish  u  merri  xma',
#  'cant  dont  number',
#  'chang  e  one  next  escal',
#  'yetund  im  class  run  water  make  ok  pl',
#  'lot  happen  feel  quiet  beth  aunt  charli  work  lot  helen  mo',
#  'wait  bu  stop  aft  ur  lect  lar  dun  c  go  get  car  come  back  n  pick',
#  'aight  thank  comin',
#  'nobut  heard  abt  tat',
#  'pleas  call  custom  servic  repres  freephon  ampm  guarante  cash  prize',
#  'yesh  realli  greatbhaji  told  kalli  best  cricket  sachin  worldveri  tough  get',
#  'ltgt  think  say  syllabu',
#  'umma  say  anyth',
#  'give  sec  think  think',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=2500, binary=False)

X = cv.fit_transform(tokenized_messages)

X.toarray()
cv.vocabulary_
# Out:
# {'go': np.int64(883),
#  'point': np.int64(1617),
#  'crazi': np.int64(450),
#  'avail': np.int64(142),
#  'bugi': np.int64(274),
#  'great': np.int64(918),
#  'world': np.int64(2434),
#  'la': np.int64(1162),
#  'cine': np.int64(370),
#  'got': np.int64(904),
#  'wat': np.int64(2366),
#  'ok': np.int64(1477),
#  'lar': np.int64(1171),
#  'joke': np.int64(1123),
#  'wif': np.int64(2404),
#  'oni': np.int64(1487),
#  'free': np.int64(791),
#  'entri': np.int64(620),
#  'wkli': np.int64(2423),
#  'comp': np.int64(405),
#  'win': np.int64(2409),
#  'fa': np.int64(683),
#  'cup': np.int64(463),
#  'final': np.int64(734),
#  'tkt': np.int64(2210),
#  'st': np.int64(2064),
#  'may': np.int64(1309),
#  'text': np.int64(2171),
#  'receiv': np.int64(1777),
#  'questionstd': np.int64(1728),
#  'txt': np.int64(2268),
#  'ratetc': np.int64(1754),
#  'appli': np.int64(100),
#  'dun': np.int64(579),
#  'say': np.int64(1898),
#  'earli': np.int64(583),
#  'alreadi': np.int64(67),
#  'nah': np.int64(1410),
#  'dont': np.int64(559),
#  'think': np.int64(2185),
#  'goe': np.int64(887),
#  'usf': np.int64(2308),
#  'live': np.int64(1224),
#  'around': np.int64(116),
#  'though': np.int64(2191),
#  'freemsg': np.int64(795),
#  'hey': np.int64(987),
#  'darl': np.int64(482),
#  'week': np.int64(2379),
#  'word': np.int64(2431),
#  'back': np.int64(154),
#  'id': np.int64(1047),
#  'like': np.int64(1214),
#  'fun': np.int64(817),
#  'still': np.int64(2076),
#  'tb': np.int64(2148),
#  'xxx': np.int64(2463),
#  'std': np.int64(2074),
#  'send': np.int64(1924),
#  'rcv': np.int64(1757),
#  'even': np.int64(642),
#  'brother': np.int64(261),
#  'speak': np.int64(2048),
#  'treat': np.int64(2246),
#  'per': np.int64(1558),
#  'request': np.int64(1818),
#  'mell': np.int64(1324),
#  'oru': np.int64(1506),
#  'minnaminungint': np.int64(1347),
#  'nurungu': np.int64(1463),
#  'vettam': np.int64(2326),
#  'set': np.int64(1934),
#  'callertun': np.int64(298),
#  'caller': np.int64(297),
#  'press': np.int64(1666),
#  'copi': np.int64(429),
#  'friend': np.int64(803),
#  'winner': np.int64(2413),
#  'valu': np.int64(2318),
#  'network': np.int64(1428),
#  'custom': np.int64(467),
#  'select': np.int64(1919),
#  'receivea': np.int64(1778),
#  'prize': np.int64(1678),
#  'reward': np.int64(1841),
#  'claim': np.int64(374),
#  'call': np.int64(295),
#  'code': np.int64(391),
#  'valid': np.int64(2316),
#  'hour': np.int64(1024),
#  'mobil': np.int64(1362),
#  'month': np.int64(1376),
#  'entitl': np.int64(619),
#  'updat': np.int64(2293),
#  'latest': np.int64(1176),
#  'colour': np.int64(398),
#  'camera': np.int64(304),
#  'co': np.int64(389),
#  'im': np.int64(1056),
#  'gonna': np.int64(892),
#  'home': np.int64(1011),
#  'soon': np.int64(2033),
#  'want': np.int64(2359),
#  'talk': np.int64(2140),
#  'stuff': np.int64(2095),
#  'anymor': np.int64(89),
#  'tonight': np.int64(2228),
#  'ive': np.int64(1101),
#  'cri': np.int64(454),
#  'enough': np.int64(616),
#  'today': np.int64(2217),
#  'six': np.int64(1990),
#  'chanc': np.int64(340),
#  'cash': np.int64(321),
#  'pound': np.int64(1643),
#  'cost': np.int64(432),
#  'pday': np.int64(1551),
#  'day': np.int64(488),
#  'repli': np.int64(1815),
#  'hl': np.int64(999),
#  'info': np.int64(1072),
#  'urgent': np.int64(2299),
#  'membership': np.int64(1326),
#  'tc': np.int64(2149),
#  'pobox': np.int64(1611),
#  'search': np.int64(1909),
#  'right': np.int64(1846),
#  'thank': np.int64(2175),
#  'promis': np.int64(1690),
#  'wont': np.int64(2430),
#  'take': np.int64(2137),
#  'help': np.int64(984),
#  'wonder': np.int64(2429),
#  'bless': np.int64(218),
#  'time': np.int64(2206),
#  'date': np.int64(486),
#  'sunday': np.int64(2112),
#  'use': np.int64(2306),
#  'credit': np.int64(453),
#  'click': np.int64(379),
#  'wap': np.int64(2360),
#  'link': np.int64(1218),
#  'next': np.int64(1434),
#  'messag': np.int64(1330),
#  'oh': np.int64(1475),
#  'watch': np.int64(2367),
#  'eh': np.int64(598),
#  'rememb': np.int64(1804),
#  'spell': np.int64(2052),
#  'name': np.int64(1412),
#  'ye': np.int64(2472),
#  'naughti': np.int64(1419),
#  'make': np.int64(1284),
#  'wet': np.int64(2390),
#  'fine': np.int64(737),
#  'that': np.int64(2178),
#  'way': np.int64(2369),
#  'feel': np.int64(717),
#  'england': np.int64(613),
#  'miss': np.int64(1350),
#  'news': np.int64(1433),
#  'ur': np.int64(2297),
#  'nation': np.int64(1416),
#  'team': np.int64(2155),
#  'eg': np.int64(596),
#  'scotland': np.int64(1904),
#  'serious': np.int64(1931),
#  'tri': np.int64(2248),
#  'ha': np.int64(942),
#  'pay': np.int64(1546),
#  'first': np.int64(743),
#  'da': np.int64(473),
#  'stock': np.int64(2077),
#  'comin': np.int64(402),
#  'aft': np.int64(40),
#  'finish': np.int64(741),
#  'lunch': np.int64(1268),
#  'str': np.int64(2086),
#  'lor': np.int64(1244),
#  'ard': np.int64(107),
#  'smth': np.int64(2014),
#  'alright': np.int64(68),
#  'meet': np.int64(1319),
#  'sooner': np.int64(2034),
#  'forc': np.int64(773),
#  'eat': np.int64(589),
#  'slice': np.int64(2003),
#  'realli': np.int64(1770),
#  'hungri': np.int64(1036),
#  'tho': np.int64(2190),
#  'suck': np.int64(2105),
#  'mark': np.int64(1295),
#  'get': np.int64(863),
#  'worri': np.int64(2435),
#  'know': np.int64(1159),
#  'sick': np.int64(1971),
#  'turn': np.int64(2263),
#  'pizza': np.int64(1588),
#  'lol': np.int64(1236),
#  'alway': np.int64(71),
#  'convinc': np.int64(426),
#  'catch': np.int64(325),
#  'bu': np.int64(269),
#  'fri': np.int64(801),
#  'egg': np.int64(597),
#  'tea': np.int64(2152),
#  'mom': np.int64(1369),
#  'left': np.int64(1191),
#  'dinner': np.int64(537),
#  'love': np.int64(1254),
#  'amp': np.int64(78),
#  'pack': np.int64(1517),
#  'car': np.int64(312),
#  'ill': np.int64(1055),
#  'let': np.int64(1200),
#  'there': np.int64(2182),
#  'room': np.int64(1863),
#  'work': np.int64(2432),
#  'wait': np.int64(2349),
#  'clear': np.int64(378),
#  'sure': np.int64(2124),
#  'doesnt': np.int64(553),
#  'us': np.int64(2305),
#  'yeah': np.int64(2473),
#  'child': np.int64(358),
#  'caught': np.int64(326),
#  'till': np.int64(2205),
#  'cheer': np.int64(354),
#  'tell': np.int64(2161),
#  'anyth': np.int64(91),
#  'fear': np.int64(713),
#  'quick': np.int64(1729),
#  'subscript': np.int64(2103),
#  'rington': np.int64(1848),
#  'uk': np.int64(2276),
#  'charg': np.int64(344),
#  'pleas': np.int64(1596),
#  'confirm': np.int64(415),
#  'yup': np.int64(2498),
#  'look': np.int64(1241),
#  'msg': np.int64(1397),
#  'xuhui': np.int64(2461),
#  'learn': np.int64(1186),
#  'nd': np.int64(1420),
#  'lesson': np.int64(1199),
#  'oop': np.int64(1491),
#  'roommat': np.int64(1864),
#  'done': np.int64(558),
#  'see': np.int64(1916),
#  'letter': np.int64(1201),
#  'decid': np.int64(499),
#  'hello': np.int64(983),
#  'how': np.int64(1027),
#  'saturday': np.int64(1893),
#  'youd': np.int64(2489),
#  'tomo': np.int64(2225),
#  'invit': np.int64(1087),
#  'pl': np.int64(1589),
#  'ahead': np.int64(47),
#  'weekend': np.int64(2380),
#  'abiola': np.int64(5),
#  'forget': np.int64(777),
#  'need': np.int64(1424),
#  'crave': np.int64(449),
#  'sweet': np.int64(2127),
#  'yummi': np.int64(2494),
#  'burn': np.int64(278),
#  'sm': np.int64(2008),
#  'nokia': np.int64(1447),
#  'camcord': np.int64(302),
#  'deliveri': np.int64(510),
#  'tomorrow': np.int64(2226),
#  'hope': np.int64(1017),
#  'man': np.int64(1288),
#  'well': np.int64(2386),
#  'ltgt': np.int64(1263),
#  'inch': np.int64(1065),
#  'callsmessagesmiss': np.int64(300),
#  'didnt': np.int64(525),
#  'nigeria': np.int64(1438),
#  'fair': np.int64(690),
#  'tyler': np.int64(2272),
#  'cant': np.int64(310),
#  'could': np.int64(435),
#  'mayb': np.int64(1310),
#  'ask': np.int64(124),
#  'bit': np.int64(209),
#  'hospit': np.int64(1020),
#  'kept': np.int64(1141),
#  'weak': np.int64(2372),
#  'saw': np.int64(1897),
#  'class': np.int64(376),
#  'gram': np.int64(912),
#  'usual': np.int64(2309),
#  'run': np.int64(1881),
#  'half': np.int64(950),
#  'almost': np.int64(64),
#  'whole': np.int64(2402),
#  'second': np.int64(1913),
#  'fyi': np.int64(825),
#  'ride': np.int64(1845),
#  'morn': np.int64(1381),
#  'he': np.int64(972),
#  'crash': np.int64(448),
#  'place': np.int64(1590),
#  'wow': np.int64(2441),
#  'never': np.int64(1430),
#  'realiz': np.int64(1769),
#  'embarass': np.int64(605),
#  'accomod': np.int64(16),
#  'thought': np.int64(2192),
#  'sinc': np.int64(1980),
#  'best': np.int64(192),
#  'seem': np.int64(1917),
#  'happi': np.int64(962),
#  'sorri': np.int64(2037),
#  'give': np.int64(878),
#  'offer': np.int64(1470),
#  'ac': np.int64(10),
#  'new': np.int64(1431),
#  'red': np.int64(1786),
#  'play': np.int64(1593),
#  'ice': np.int64(1046),
#  'correct': np.int64(431),
#  'end': np.int64(607),
#  'yesterday': np.int64(2479),
#  'find': np.int64(736),
#  'lturlgt': np.int64(1265),
#  'congrat': np.int64(417),
#  'year': np.int64(2474),
#  'special': np.int64(2049),
#  'cinema': np.int64(371),
#  'pass': np.int64(1538),
#  'suprman': np.int64(2122),
#  'matrix': np.int64(1303),
#  'starwar': np.int64(2070),
#  'etc': np.int64(634),
#  'bxipw': np.int64(285),
#  'pm': np.int64(1602),
#  'later': np.int64(1175),
#  'reach': np.int64(1760),
#  'seri': np.int64(1929),
#  'pick': np.int64(1576),
#  'burger': np.int64(277),
#  'move': np.int64(1389),
#  'pain': np.int64(1521),
#  'kill': np.int64(1149),
#  'good': np.int64(893),
#  'girl': np.int64(874),
#  'situat': np.int64(1989),
#  'part': np.int64(1534),
#  'check': np.int64(353),
#  'iq': np.int64(1092),
#  'took': np.int64(2230),
#  'forev': np.int64(775),
#  'come': np.int64(400),
#  'doubl': np.int64(562),
#  'hair': np.int64(948),
#  'dresser': np.int64(567),
#  'said': np.int64(1886),
#  'wun': np.int64(2448),
#  'cut': np.int64(468),
#  'short': np.int64(1958),
#  'nice': np.int64(1436),
#  'advis': np.int64(35),
#  'follow': np.int64(765),
#  'recent': np.int64(1779),
#  'review': np.int64(1839),
#  'mob': np.int64(1360),
#  'award': np.int64(149),
#  'bonu': np.int64(232),
#  'song': np.int64(2030),
#  'dedic': np.int64(501),
#  'valuabl': np.int64(2319),
#  'frnd': np.int64(807),
#  'rpli': np.int64(1870),
#  'complimentari': np.int64(409),
#  'trip': np.int64(2249),
#  'eurodisinc': np.int64(637),
#  'di': np.int64(521),
#  'hear': np.int64(975),
#  'wah': np.int64(2348),
#  'lucki': np.int64(1267),
#  'save': np.int64(1896),
#  'money': np.int64(1373),
#  'hee': np.int64(979),
#  'hi': np.int64(990),
#  'babe': np.int64(152),
#  'wanna': np.int64(2358),
#  'someth': np.int64(2026),
#  'xx': np.int64(2462),
#  'perform': np.int64(1560),
#  'machan': np.int64(1274),
#  'cool': np.int64(428),
#  'gentleman': np.int64(858),
#  'digniti': np.int64(534),
#  'respect': np.int64(1824),
#  'peopl': np.int64(1557),
#  'much': np.int64(1401),
#  'shi': np.int64(1949),
#  'pa': np.int64(1516),
#  'oper': np.int64(1493),
#  'job': np.int64(1119),
#  'ta': np.int64(2134),
#  'earn': np.int64(585),
#  'ah': np.int64(45),
#  'stop': np.int64(2082),
#  'urgnt': np.int64(2302),
#  'real': np.int64(1765),
#  'yo': np.int64(2484),
#  'ticket': np.int64(2202),
#  'one': np.int64(1486),
#  'start': np.int64(2069),
#  'came': np.int64(303),
#  'bed': np.int64(178),
#  'coin': np.int64(393),
#  'gotta': np.int64(906),
#  'nitro': np.int64(1443),
#  'download': np.int64(563),
#  'wen': np.int64(2388),
#  'stand': np.int64(2066),
#  'close': np.int64(382),
#  'youll': np.int64(2490),
#  'anoth': np.int64(84),
#  'night': np.int64(1439),
#  'spent': np.int64(2054),
#  'late': np.int64(1174),
#  'afternoon': np.int64(41),
#  'mean': np.int64(1312),
#  'havent': np.int64(969),
#  'includ': np.int64(1067),
#  'sheet': np.int64(1946),
#  'smile': np.int64(2012),
#  'pleasur': np.int64(1597),
#  'troubl': np.int64(2250),
#  'pour': np.int64(1644),
#  'rain': np.int64(1742),
#  'sum': np.int64(2109),
#  'hurt': np.int64(1038),
#  'becoz': np.int64(177),
#  'someon': np.int64(2025),
#  'servic': np.int64(1933),
#  'repres': np.int64(1817),
#  'ampm': np.int64(79),
#  'guarante': np.int64(931),
#  'plan': np.int64(1592),
#  'buy': np.int64(281),
#  'lido': np.int64(1206),
#  'show': np.int64(1966),
#  'abt': np.int64(8),
#  'load': np.int64(1227),
#  'loan': np.int64(1228),
#  'wk': np.int64(2420),
#  'hol': np.int64(1005),
#  'forgot': np.int64(779),
#  'appoint': np.int64(101),
#  'four': np.int64(786),
#  'shower': np.int64(1967),
#  'caus': np.int64(327),
#  'prob': np.int64(1680),
#  'ham': np.int64(954),
#  'noth': np.int64(1456),
#  'els': np.int64(601),
#  'okay': np.int64(1478),
#  'price': np.int64(1671),
#  'long': np.int64(1239),
#  'legal': np.int64(1193),
#  'ave': np.int64(144),
#  'gone': np.int64(891),
#  'drive': np.int64(570),
#  'test': np.int64(2170),
#  'yet': np.int64(2480),
#  'your': np.int64(2491),
#  'guess': np.int64(935),
#  'gave': np.int64(841),
#  'boston': np.int64(239),
#  'men': np.int64(1327),
#  'chang': np.int64(341),
#  'locat': np.int64(1230),
#  'nyc': np.int64(1467),
#  'cuz': np.int64(471),
#  'page': np.int64(1519),
#  'umma': np.int64(2278),
#  'life': np.int64(1208),
#  'vava': np.int64(2322),
#  'lot': np.int64(1248),
#  'dear': np.int64(493),
#  'wish': np.int64(2415),
#  'birthday': np.int64(207),
#  'truli': np.int64(2252),
#  'aight': np.int64(49),
#  'hit': np.int64(997),
#  'would': np.int64(2439),
#  'ip': np.int64(1089),
#  'address': np.int64(28),
#  'consid': np.int64(420),
#  'comput': np.int64(410),
#  'isnt': np.int64(1097),
#  'old': np.int64(1483),
#  'better': np.int64(194),
#  'lie': np.int64(1207),
#  'busi': np.int64(279),
#  'research': np.int64(1821),
#  'thing': np.int64(2184),
#  'scare': np.int64(1899),
#  'mah': np.int64(1280),
#  'loud': np.int64(1250),
#  'gent': np.int64(856),
#  'contact': np.int64(421),
#  'last': np.int64(1173),
#  'draw': np.int64(564),
#  'hr': np.int64(1030),
#  'ppm': np.int64(1650),
#  'wa': np.int64(2347),
#  'sentenc': np.int64(1927),
#  'anyway': np.int64(94),
#  'juz': np.int64(1133),
#  'tt': np.int64(2258),
#  'eatin': np.int64(591),
#  'puttin': np.int64(1720),
#  'anythin': np.int64(92),
#  'happen': np.int64(960),
#  'enter': np.int64(617),
#  'cabin': np.int64(287),
#  'bday': np.int64(173),
#  'boss': np.int64(238),
#  'felt': np.int64(720),
#  'askd': np.int64(125),
#  'apart': np.int64(96),
#  'went': np.int64(2389),
#  'holiday': np.int64(1008),
#  'flight': np.int64(756),
#  'inc': np.int64(1064),
#  'pmin': np.int64(1603),
#  'goodo': np.int64(900),
#  'must': np.int64(1407),
#  'friday': np.int64(802),
#  'uncl': np.int64(2281),
#  'inform': np.int64(1073),
#  'school': np.int64(1902),
#  'directli': np.int64(540),
#  'food': np.int64(767),
#  'privat': np.int64(1677),
#  'account': np.int64(17),
#  'statement': np.int64(2071),
#  'unredeem': np.int64(2289),
#  'identifi': np.int64(1049),
#  'expir': np.int64(674),
#  'landlin': np.int64(1169),
#  'voda': np.int64(2338),
#  'number': np.int64(1462),
#  'match': np.int64(1300),
#  'quot': np.int64(1735),
#  'standard': np.int64(2067),
#  'rate': np.int64(1753),
#  'app': np.int64(98),
#  'mu': np.int64(1400),
#  'predict': np.int64(1656),
#  'hasnt': np.int64(966),
#  'sent': np.int64(1926),
#  'bother': np.int64(240),
#  'shouldnt': np.int64(1963),
#  'apologis': np.int64(97),
#  'del': np.int64(505),
#  'bak': np.int64(158),
#  'kkhow': np.int64(1154),
#  'answer': np.int64(86),
#  'question': np.int64(1727),
#  'sunshin': np.int64(2114),
#  'quiz': np.int64(1733),
#  'top': np.int64(2231),
#  'soni': np.int64(2031),
#  'dvd': np.int64(581),
#  'player': np.int64(1594),
#  'countri': np.int64(438),
#  'ansr': np.int64(85),
#  'sptyron': np.int64(2063),
#  'laid': np.int64(1167),
#  'dog': np.int64(554),
#  'direct': np.int64(539),
#  'join': np.int64(1122),
#  'largest': np.int64(1172),
#  'bt': np.int64(266),
#  'txting': np.int64(2271),
#  'nt': np.int64(1458),
#  'eca': np.int64(592),
#  'pmsgp': np.int64(1605),
#  'haf': np.int64(944),
#  'befor': np.int64(181),
#  'activ': np.int64(22),
#  'chat': np.int64(348),
#  'hardcor': np.int64(964),
#  'age': np.int64(43),
#  'verifi': np.int64(2324),
#  'yr': np.int64(2493),
#  'lazi': np.int64(1181),
#  'type': np.int64(2273),
#  'lect': np.int64(1189),
#  'pouch': np.int64(1642),
#  'sir': np.int64(1984),
#  'mail': np.int64(1281),
#  'tire': np.int64(2207),
#  'littl': np.int64(1223),
#  'lovabl': np.int64(1253),
#  'person': np.int64(1564),
#  'biggest': np.int64(201),
#  'heart': np.int64(977),
#  'gud': np.int64(932),
#  'ni': np.int64(1435),
#  'open': np.int64(1492),
#  'ya': np.int64(2467),
#  'dot': np.int64(561),
#  'what': np.int64(2392),
#  'randi': np.int64(1748),
#  'sexi': np.int64(1938),
#  'femal': np.int64(721),
#  'local': np.int64(1229),
#  'luv': np.int64(1269),
#  'netcollex': np.int64(1427),
#  'ltd': np.int64(1261),
#  'begin': np.int64(183),
#  'qatar': np.int64(1723),
#  'pray': np.int64(1655),
#  'hard': np.int64(963),
#  'ki': np.int64(1145),
#  'delet': np.int64(507),
#  'birla': np.int64(205),
#  'soft': np.int64(2020),
#  'wine': np.int64(2412),
#  'flow': np.int64(760),
#  'thk': np.int64(2187),
#  'plaza': np.int64(1595),
#  'everywher': np.int64(650),
#  'floor': np.int64(759),
#  'window': np.int64(2411),
#  'shirt': np.int64(1952),
#  'sometim': np.int64(2028),
#  'dream': np.int64(565),
#  'without': np.int64(2418),
#  'joy': np.int64(1126),
#  'tv': np.int64(2264),
#  'becom': np.int64(176),
#  'leav': np.int64(1188),
#  'hous': np.int64(1025),
#  'interview': np.int64(1085),
#  'boy': np.int64(249),
#  'arrang': np.int64(117),
#  'keep': np.int64(1140),
#  'safe': np.int64(1885),
#  'everyon': np.int64(648),
#  'hand': np.int64(956),
#  'excit': np.int64(663),
#  'spend': np.int64(2053),
#  'order': np.int64(1501),
#  'content': np.int64(422),
#  'goto': np.int64(905),
#  'menu': np.int64(1328),
#  'modul': np.int64(1367),
#  'avoid': np.int64(146),
#  'wit': np.int64(2416),
#  'escap': np.int64(628),
#  'fanci': np.int64(695),
#  'complet': np.int64(408),
#  'formclark': np.int64(782),
#  'also': np.int64(70),
#  'utter': np.int64(2311),
#  'wast': np.int64(2365),
#  'bank': np.int64(161),
#  'hmmm': np.int64(1002),
#  'hop': np.int64(1016),
#  'muz': np.int64(1408),
#  'discuss': np.int64(544),
#  'liao': np.int64(1202),
#  'bloodi': np.int64(223),
#  'hell': np.int64(981),
#  'believ': np.int64(187),
#  'mr': np.int64(1392),
#  'spanish': np.int64(2046),
#  'bath': np.int64(166),
#  'youv': np.int64(2492),
#  'carlo': np.int64(317),
#  'mall': np.int64(1287),
#  'stay': np.int64(2073),
#  'til': np.int64(2204),
#  'smoke': np.int64(2013),
#  'worth': np.int64(2437),
#  'log': np.int64(1232),
#  'spoke': np.int64(2057),
#  'maneesha': np.int64(1291),
#  'wed': np.int64(2376),
#  'satisfi': np.int64(1892),
#  'experi': np.int64(673),
#  'toll': np.int64(2222),
#  'lift': np.int64(1211),
#  'especi': np.int64(630),
#  'studi': np.int64(2094),
#  'gr': np.int64(910),
#  'trust': np.int64(2253),
#  'guy': np.int64(938),
#  'toward': np.int64(2238),
#  'net': np.int64(1426),
#  'mummi': np.int64(1403),
#  'where': np.int64(2397),
#  'boytoy': np.int64(250),
#  'haha': np.int64(945),
#  'awesom': np.int64(151),
#  'minut': np.int64(1348),
#  'freephon': np.int64(796),
#  'xma': np.int64(2459),
#  'radio': np.int64(1739),
#  'ju': np.int64(1129),
#  'si': np.int64(1970),
#  'uniqu': np.int64(2285),
#  'th': np.int64(2173),
#  'august': np.int64(138),
#  'touch': np.int64(2235),
#  'deal': np.int64(492),
#  'cours': np.int64(441),
#  'howev': np.int64(1028),
#  'suggest': np.int64(2107),
#  'abl': np.int64(7),
#  'everi': np.int64(645),
#  'settl': np.int64(1935),
#  'mrng': np.int64(1393),
#  'hav': np.int64(968),
#  'stori': np.int64(2085),
#  'hamster': np.int64(955),
#  'dead': np.int64(491),
#  'tmr': np.int64(2213),
#  'orchard': np.int64(1500),
#  'mrt': np.int64(1394),
#  'kate': np.int64(1138),
#  'found': np.int64(785),
#  'buck': np.int64(270),
#  'darlin': np.int64(483),
#  'colleg': np.int64(397),
#  'refil': np.int64(1791),
#  'success': np.int64(2104),
#  'ltdecimalgt': np.int64(1262),
#  'prepaid': np.int64(1661),
#  'balanc': np.int64(159),
#  'rs': np.int64(1872),
#  'transact': np.int64(2242),
#  'goodmorn': np.int64(896),
#  'sleep': np.int64(2000),
#  'ga': np.int64(826),
#  'dat': np.int64(485),
#  'ericsson': np.int64(625),
#  'oso': np.int64(1507),
#  'cannot': np.int64(308),
#  'oredi': np.int64(1502),
#  'straight': np.int64(2087),
#  'connect': np.int64(419),
#  'bill': np.int64(202),
#  'shoot': np.int64(1956),
#  'big': np.int64(199),
#  'readi': np.int64(1764),
#  'break': np.int64(253),
#  'semest': np.int64(1922),
#  'noe': np.int64(1446),
#  'leh': np.int64(1194),
#  'sound': np.int64(2040),
#  'head': np.int64(973),
#  'slept': np.int64(2002),
#  'past': np.int64(1542),
#  'easi': np.int64(587),
#  'exam': np.int64(660),
#  'march': np.int64(1294),
#  'gt': np.int64(929),
#  'atm': np.int64(132),
#  'regist': np.int64(1795),
#  'instal': np.int64(1077),
#  'import': np.int64(1060),
#  'file': np.int64(730),
#  'system': np.int64(2133),
#  'repair': np.int64(1812),
#  'shop': np.int64(1957),
#  'romant': np.int64(1861),
#  'nite': np.int64(1442),
#  'collect': np.int64(396),
#  'wwwtcbiz': np.int64(2454),
#  'optout': np.int64(1498),
#  'gbpmtmsg': np.int64(846),
#  'appreci': np.int64(102),
#  'partner': np.int64(1536),
#  'career': np.int64(316),
#  'star': np.int64(2068),
#  'sign': np.int64(1975),
#  'compani': np.int64(406),
#  'po': np.int64(1610),
#  'teacher': np.int64(2154),
#  'bcoz': np.int64(171),
#  'teach': np.int64(2153),
#  'walk': np.int64(2353),
#  'cross': np.int64(456),
#  'road': np.int64(1854),
#  'side': np.int64(1972),
#  'street': np.int64(2088),
#  'batteri': np.int64(167),
#  'die': np.int64(527),
#  'flirt': np.int64(758),
#  'sam': np.int64(1889),
#  'penc': np.int64(1554),
#  'print': np.int64(1674),
#  'closer': np.int64(384),
#  'wil': np.int64(2407),
#  'theori': np.int64(2181),
#  'argument': np.int64(112),
#  'lose': np.int64(1245),
#  'argu': np.int64(111),
#  'kick': np.int64(1146),
#  'secret': np.int64(1914),
#  'admir': np.int64(29),
#  'ufind': np.int64(2274),
#  'rreveal': np.int64(1871),
#  'specialcal': np.int64(2050),
#  'tomarrow': np.int64(2224),
#  'laptop': np.int64(1170),
#  'case': np.int64(320),
#  'tel': np.int64(2159),
#  'avent': np.int64(145),
#  'meant': np.int64(1313),
#  'told': np.int64(2221),
#  'face': np.int64(685),
#  'fr': np.int64(787),
#  'thanx': np.int64(2177),
#  'everyth': np.int64(649),
#  'uve': np.int64(2313),
#  'websit': np.int64(2375),
#  'slipper': np.int64(2005),
#  'kalli': np.int64(1135),
#  'bat': np.int64(165),
#  'inning': np.int64(1075),
#  'goodnight': np.int64(897),
#  'fix': np.int64(747),
#  'wake': np.int64(2352),
#  'dearli': np.int64(496),
#  'congratul': np.int64(418),
#  'cd': np.int64(330),
#  'voucher': np.int64(2345),
#  'gift': np.int64(871),
#  'music': np.int64(1406),
#  'tnc': np.int64(2214),
#  'wwwldewcomwinppmxag': np.int64(2452),
#  'ranjith': np.int64(1752),
#  'cal': np.int64(291),
#  'min': np.int64(1343),
#  'hold': np.int64(1006),
#  'bcum': np.int64(172),
#  'angri': np.int64(82),
#  'wid': np.int64(2403),
#  'dnt': np.int64(550),
#  'coz': np.int64(443),
#  'childish': np.int64(359),
#  'true': np.int64(2251),
#  'deep': np.int64(502),
#  'affect': np.int64(38),
#  'care': np.int64(315),
#  'kettoda': np.int64(1143),
#  'manda': np.int64(1290),
#  'ship': np.int64(1951),
#  'lemm': np.int64(1196),
#  'expect': np.int64(671),
#  'mmm': np.int64(1355),
#  'lover': np.int64(1255),
#  'video': np.int64(2328),
#  'handset': np.int64(958),
#  'anytim': np.int64(93),
#  'unlimit': np.int64(2288),
#  'park': np.int64(1533),
#  'mini': np.int64(1346),
#  'disturb': np.int64(548),
#  'ring': np.int64(1847),
#  'horni': np.int64(1018),
#  'nake': np.int64(1411),
#  'hot': np.int64(1022),
#  'unsubscrib': np.int64(2292),
#  'dint': np.int64(538),
#  'wana': np.int64(2357),
#  'choos': np.int64(366),
#  'club': np.int64(386),
#  'pwk': np.int64(1721),
#  'box': np.int64(246),
#  'flash': np.int64(753),
#  'jealou': np.int64(1114),
#  'singl': np.int64(1982),
#  'chart': np.int64(346),
#  'qualiti': np.int64(1724),
#  'sort': np.int64(2038),
#  'sunni': np.int64(2113),
#  'ray': np.int64(1756),
#  'blue': np.int64(226),
#  'bay': np.int64(168),
#  'hmv': np.int64(1003),
#  'genuin': np.int64(860),
#  'infowwwpercentrealcom': np.int64(1074),
#  'might': np.int64(1339),
#  'bf': np.int64(197),
#  'rob': np.int64(1856),
#  'gf': np.int64(867),
#  'celebr': np.int64(332),
#  'full': np.int64(815),
#  'swing': np.int64(2130),
#  'far': np.int64(698),
#  'oki': np.int64(1480),
#  'anybodi': np.int64(88),
#  'throw': np.int64(2195),
#  'babi': np.int64(153),
#  'fone': np.int64(766),
#  'ge': np.int64(849),
#  'sens': np.int64(1925),
#  'gautham': np.int64(840),
#  'stupid': np.int64(2096),
#  'cam': np.int64(301),
#  'buzi': np.int64(282),
#  'accident': np.int64(15),
#  'resend': np.int64(1822),
#  'tmobil': np.int64(2212),
#  'phone': np.int64(1572),
#  'upgrad': np.int64(2294),
#  'sim': np.int64(1977),
#  'card': np.int64(313),
#  'loyalti': np.int64(1258),
#  'unless': np.int64(2287),
#  'teas': np.int64(2157),
#  'plz': np.int64(1601),
#  'rose': np.int64(1865),
#  'grave': np.int64(916),
#  'bslvyl': np.int64(264),
#  'coffe': np.int64(392),
#  'somebodi': np.int64(2024),
#  'high': np.int64(992),
#  'shit': np.int64(1953),
#  'shock': np.int64(1955),
#  'scari': np.int64(1900),
#  'imagin': np.int64(1057),
#  'def': np.int64(503),
#  'somewher': np.int64(2029),
#  'meal': np.int64(1311),
#  'hide': np.int64(991),
#  'book': np.int64(234),
#  'jo': np.int64(1118),
#  'friendship': np.int64(804),
#  'hang': np.int64(959),
#  'themob': np.int64(2180),
#  'newest': np.int64(1432),
#  'game': np.int64(830),
#  'tone': np.int64(2227),
#  'gossip': np.int64(903),
#  'sport': np.int64(2060),
#  'fit': np.int64(745),
#  'funki': np.int64(821),
#  'garag': np.int64(835),
#  'key': np.int64(1144),
#  'arent': np.int64(109),
#  'accept': np.int64(12),
#  'dayu': np.int64(489),
#  'sister': np.int64(1986),
#  'clo': np.int64(380),
#  'lvblefrnd': np.int64(1271),
#  'jstfrnd': np.int64(1128),
#  'cutefrnd': np.int64(470),
#  'lifpartnr': np.int64(1210),
#  'belovd': np.int64(190),
#  'swtheart': np.int64(2131),
#  'bstfrnd': np.int64(265),
#  'enemi': np.int64(608),
#  'smart': np.int64(2010),
#  'weekli': np.int64(2381),
#  'uz': np.int64(2314),
#  'gbpweek': np.int64(847),
#  'definit': np.int64(504),
#  'normal': np.int64(1453),
#  'rest': np.int64(1828),
#  'wot': np.int64(2438),
#  'lost': np.int64(1247),
#  'made': np.int64(1277),
#  'pongal': np.int64(1627),
#  'kb': np.int64(1139),
#  'power': np.int64(1646),
#  'yoga': np.int64(2485),
#  'dunno': np.int64(580),
#  'dude': np.int64(577),
#  'afraid': np.int64(39),
#  'decemb': np.int64(498),
#  'mth': np.int64(1399),
#  'cake': np.int64(289),
#  'merri': np.int64(1329),
#  'christma': np.int64(368),
#  'kiss': np.int64(1153),
#  'cud': np.int64(460),
#  'ppl': np.int64(1648),
#  'gona': np.int64(890),
#  'waitin': np.int64(2350),
#  'pete': np.int64(1566),
#  'problem': np.int64(1682),
#  'track': np.int64(2240),
#  'record': np.int64(1784),
#  'read': np.int64(1762),
#  'women': np.int64(2428),
#  ...}

# %% [markdown]
# Using Lemitization

# %%
from nltk import WordNetLemmatizer
tokenized_messages = []
lemmatizer = WordNetLemmatizer()
for i in range(len(dataset)):
    message = dataset['message'][i].lower()
    message = re.sub('[^a-zA-Z\\s]','', message)
    words_in_message = message.split()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words_in_message if not word in stopwords.words('english')]
    message = '  '.join(lemmatized_words)
    tokenized_messages.append(message)

tokenized_messages
# Out:
# ['go  jurong  point  crazy  available  bugis  n  great  world  la  e  buffet  cine  got  amore  wat',
#  'ok  lar  joking  wif  u  oni',
#  'free  entry  wkly  comp  win  fa  cup  final  tkts  st  may  text  fa  receive  entry  questionstd  txt  ratetcs  apply  over',
#  'u  dun  say  early  hor  u  c  already  say',
#  'nah  dont  think  go  usf  life  around  though',
#  'freemsg  hey  darling  week  word  back  id  like  fun  still  tb  ok  xxx  std  chgs  send  rcv',
#  'even  brother  like  speak  treat  like  aid  patent',
#  'per  request  melle  melle  oru  minnaminunginte  nurungu  vettam  set  callertune  caller  press  copy  friend  callertune',
#  'winner  valued  network  customer  selected  receivea  prize  reward  claim  call  claim  code  kl  valid  hour',
#  'mobile  month  u  r  entitled  update  latest  colour  mobile  camera  free  call  mobile  update  co  free',
#  'im  gonna  home  soon  dont  want  talk  stuff  anymore  tonight  k  ive  cried  enough  today',
#  'six  chance  win  cash  pound  txt  csh  send  cost  pday  day  tsandcs  apply  reply  hl  info',
#  'urgent  week  free  membership  prize  jackpot  txt  word  claim  tc  wwwdbuknet  lccltd  pobox  ldnwarw',
#  'ive  searching  right  word  thank  breather  promise  wont  take  help  granted  fulfil  promise  wonderful  blessing  time',
#  'date  sunday',
#  'xxxmobilemovieclub  use  credit  click  wap  link  next  txt  message  click  httpwap  xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh  kim  watching',
#  'eh  u  remember  spell  name  yes  v  naughty  make  v  wet',
#  'fine  thats  way  u  feel  thats  way  gota  b',
#  'england  v  macedonia  dont  miss  goalsteam  news  txt  ur  national  team  eg  england  trywales  scotland  txt  poboxoxwwq',
#  'seriously  spell  name',
#  'im  going  try  month  ha  ha  joking',
#  'pay  first  lar  da  stock  comin',
#  'aft  finish  lunch  go  str  lor  ard  smth  lor  u  finish  ur  lunch  already',
#  'ffffffffff  alright  way  meet  sooner',
#  'forced  eat  slice  im  really  hungry  tho  suck  mark  getting  worried  know  im  sick  turn  pizza  lol',
#  'lol  always  convincing',
#  'catch  bus  frying  egg  make  tea  eating  mom  left  dinner  feel  love',
#  'im  back  amp  packing  car  ill  let  know  there  room',
#  'ahhh  work  vaguely  remember  feel  like  lol',
#  'wait  thats  still  clear  sure  sarcastic  thats  x  doesnt  want  live  u',
#  'yeah  got  v  apologetic  n  fallen  actin  like  spoilt  child  got  caught  till  wont  go  badly  cheer',
#  'k  tell  anything',
#  'fear  fainting  housework  quick  cuppa',
#  'thanks  subscription  ringtone  uk  mobile  charged  month  please  confirm  replying  yes  reply  charged',
#  'yup  ok  go  home  look  timing  msg  xuhui  going  learn  nd  may  lesson',
#  'oops  ill  let  know  roommate  done',
#  'see  letter  b  car',
#  'anything  lor  u  decide',
#  'hello  hows  saturday  go  texting  see  youd  decided  anything  tomo  im  trying  invite  anything',
#  'pls  go  ahead  watt  wanted  sure  great  weekend  abiola',
#  'forget  tell  want  need  crave  love  sweet  arabian  steed  mmmmmm  yummy',
#  'rodger  burn  msg  tried  call  reply  sm  free  nokia  mobile  free  camcorder  please  call  delivery  tomorrow',
#  'seeing',
#  'great  hope  like  man  well  endowed  ltgt  inch',
#  'callsmessagesmissed  call',
#  'didnt  get  hep  b  immunisation  nigeria',
#  'fair  enough  anything  going',
#  'yeah  hopefully  tyler  cant  could  maybe  ask  around  bit',
#  'u  dont  know  stubborn  didnt  even  want  go  hospital  kept  telling  mark  im  weak  sucker  hospital  weak  sucker',
#  'thinked  first  time  saw  class',
#  'gram  usually  run  like  ltgt  half  eighth  smarter  though  get  almost  whole  second  gram  ltgt',
#  'k  fyi  x  ride  early  tomorrow  morning  he  crashing  place  tonight',
#  'wow  never  realized  embarassed  accomodations  thought  liked  since  best  could  always  seemed  happy  cave  im  sorry  didnt  dont  give  im  sorry  offered  im  sorry  room  embarassing',
#  'sm  ac  sptv  new  jersey  devil  detroit  red  wing  play  ice  hockey  correct  incorrect  end  reply  end  sptv',
#  'know  mallika  sherawat  yesterday  find  lturlgt',
#  'congrats  year  special  cinema  pas  call  c  suprman  v  matrix  starwars  etc  free  bxipwe  pm  dont  miss',
#  'sorry  ill  call  later  meeting',
#  'tell  reached',
#  'yesgauti  sehwag  odi  series',
#  'gonna  pick  burger  way  home  cant  even  move  pain  killing',
#  'ha  ha  ha  good  joke  girl  situation  seeker',
#  'part  checking  iq',
#  'sorry  roommate  took  forever  ok  come',
#  'ok  lar  double  check  wif  da  hair  dresser  already  said  wun  cut  v  short  said  cut  look  nice',
#  'valued  customer  pleased  advise  following  recent  review  mob  awarded  bonus  prize  call',
#  'today  song  dedicated  day  song  u  dedicate  send  ur  valuable  frnds  first  rply',
#  'urgent  ur  awarded  complimentary  trip  eurodisinc  trav  acoentry  claim  txt  dis  morefrmmob  shracomorsglsuplt  l  aj',
#  'hear  new  divorce  barbie  come  ken  stuff',
#  'plane  give  month  end',
#  'wah  lucky  man  save  money  hee',
#  'finished  class',
#  'hi  babe  im  home  wanna  something  xx',
#  'kkwhere  youhow  performed',
#  'u  call',
#  'waiting  machan  call  free',
#  'thats  cool  gentleman  treat  dignity  respect',
#  'like  people  much  shy  pa',
#  'operate  ltgt',
#  'still  looking  job  much  ta  earn',
#  'sorry  ill  call  later',
#  'k  call  ah',
#  'ok  way  home  hi  hi',
#  'place  man',
#  'yup  next  stop',
#  'call  later  dont  network  urgnt  sm',
#  'real  u  getting  yo  need  ticket  one  jacket  im  done  already  used  multis',
#  'yes  started  send  request  make  pain  came  back  im  back  bed  double  coin  factory  gotta  cash  nitros',
#  'im  really  still  tonight  babe',
#  'ela  kanoil  download  come  wen  ur  free',
#  'yeah  dont  stand  close  tho  youll  catch  something',
#  'sorry  pain  ok  meet  another  night  spent  late  afternoon  casualty  mean  havent  done  stuffmoro  includes  time  sheet  sorry',
#  'smile  pleasure  smile  pain  smile  trouble  pours  like  rain  smile  sum  hurt  u  smile  becoz  someone  still  love  see  u  smiling',
#  'please  call  customer  service  representative  ampm  guaranteed  cash  prize',
#  'havent  planning  buy  later  check  already  lido  got  show  e  afternoon  u  finish  work  already',
#  'watching  telugu  moviewat  abt  u',
#  'see  finish  load  loan  pay',
#  'hi  wk  ok  hols  yes  bit  run  forgot  hairdresser  appointment  four  need  get  home  n  shower  beforehand  cause  prob  u  ham',
#  'please  dont  text  anymore  nothing  else  say',
#  'okay  name  ur  price  long  legal  wen  pick  u  ave  x  am  xx',
#  'im  still  looking  car  buy  gone  driving  test  yet',
#  'per  request  melle  melle  oru  minnaminunginte  nurungu  vettam  set  callertune  caller  press  copy  friend  callertune',
#  'wow  youre  right  didnt  mean  guess  gave  boston  men  changed  search  location  nyc  something  changed  cuz  signin  page  still  say  boston',
#  'umma  life  vava  umma  love  lot  dear',
#  'thanks  lot  wish  birthday  thanks  making  birthday  truly  memorable',
#  'aight  ill  hit  get  cash',
#  'would  ip  address  test  considering  computer  isnt  minecraft  server',
#  'know  grumpy  old  people  mom  like  better  lying  always  one  play  joke',
#  'dont  worry  guess  he  busy',
#  'plural  noun  research',
#  'going  dinnermsg',
#  'im  ok  wif  co  like  try  new  thing  scared  u  dun  like  mah  co  u  said  loud',
#  'gent  trying  contact  last  weekend  draw  show  prize  guaranteed  call  claim  code  k  valid  hr  ppm',
#  'wa  ur  openin  sentence  formal  anyway  im  fine  juz  tt  im  eatin  much  n  puttin  weighthaha  anythin  special  happened',
#  'entered  cabin  pa  said  happy  bday  bos  felt  special  askd  lunch  lunch  invited  apartment  went',
#  'winner  u  specially  selected  receive  holiday  flight  inc  speak  live  operator  claim  pmin',
#  'goodo  yes  must  speak  friday  eggpotato  ratio  tortilla  needed',
#  'hmmmy  uncle  informed  he  paying  school  directly  pls  buy  food',
#  'private  account  statement  show  unredeemed  bonus  point  claim  call  identifier  code  expires',
#  'urgent  mobile  awarded  bonus  caller  prize  final  try  contact  u  call  landline  boxwrc  ppm',
#  'new  address  applespairsall  malarky',
#  'today  voda  number  ending  selected  receive  award  match  please  call  quoting  claim  code  standard  rate  app',
#  'going  sao  mu  today  done',
#  'predict  wat  time  finish  buying',
#  'good  stuff',
#  'knowyetunde  hasnt  sent  money  yet  sent  text  bother  sending  dont  involve  anything  shouldnt  imposed  anything  first  place  apologise',
#  'room',
#  'hey  girl  r  u  hope  u  r  well  del  r  bak  long  time  c  give  call  sum  time  lucyxx',
#  'kkhow  much  cost',
#  'im  home',
#  'dear  call  tmorrowpls  accomodate',
#  'first  answer  question',
#  'sunshine  quiz  wkly  q  win  top  sony  dvd  player  u  know  country  algarve  txt  ansr  sptyrone',
#  'want  get  laid  tonight  want  real  dogging  location  sent  direct  ur  mob  join  uk  largest  dogging  network  bt  txting  gravel  nt  eca  pmsgp',
#  'haf  msn  yijuehotmailcom',
#  'call  meet',
#  'check  room  befor  activity',
#  'youll  rcv  msg  chat  svc  free  hardcore  service  text  go  u  get  nothing  u  must  age  verify  yr  network  try',
#  'got  c  lazy  type  forgot  lect  saw  pouch  like  v  nice',
#  'k  text  youre  way',
#  'sir  waiting  mail',
#  'swt  thought  nver  get  tired  little  thing  lovable  person  cozsomtimes  little  thing  occupy  biggest  part  heart  gud  ni',
#  'know  pls  open  back',
#  'yes  see  ya  dot',
#  'whats  staff  name  taking  class  u',
#  'freemsg  havent  replied  text  im  randy  sexy  female  live  local  luv  hear  u  netcollex  ltd  p  per  msg  reply  stop  end',
#  'ummmawill  call  check  inour  life  begin  qatar  pls  pray  hard',
#  'ki  deleted  contact',
#  'sindu  got  job  birla  soft',
#  'wine  flowing  im  nevering',
#  'yup  thk  cine  better  co  need  go  plaza  mah',
#  'ok  ur  typical  reply',
#  'per  request  melle  melle  oru  minnaminunginte  nurungu  vettam  set  callertune  caller  press  copy  friend  callertune',
#  'everywhere  dirt  floor  window  even  shirt  sometimes  open  mouth  come  flowing  dream  world  without  half  chore  time  joy  lot  tv  show  ill  see  guess  like  thing  must  exist  like  rain  hail  mist  time  done  become  one',
#  'aaooooright  work',
#  'im  leaving  house',
#  'hello  love  get  interview  today  happy  good  boy  think  meare  missing',
#  'customer  service  annoncement  new  year  delivery  waiting  please  call  arrange  delivery',
#  'winner  u  specially  selected  receive  cash  holiday  flight  inc  speak  live  operator  claim',
#  'keep  safe  need  miss  already  envy  everyone  see  real  life',
#  'new  car  house  parentsi  new  job  hand',
#  'im  love  im  excited  day  spend  make  happy',
#  'pls  stop  bootydelious  f  inviting  friend  reply  yes  see  wwwsmsacubootydelious  stop  send  stop  frnd',
#  'bangbabes  ur  order  way  u  receive  service  msg  download  ur  content  u  goto  wap  bangb  tv  ur  mobile  internetservice  menu',
#  'place  ur  point  e  culture  module  already',
#  'urgent  trying  contact  last  weekend  draw  show  prize  guaranteed  call  claim  code  valid  hr',
#  'hi  frnd  best  way  avoid  missunderstding  wit  beloved  one',
#  'great  escape  fancy  bridge  need  lager  see  tomo',
#  'yes  completely  formclark  also  utter  waste',
#  'sir  need  axis  bank  account  bank  address',
#  'hmmm  thk  sure  got  time  hop  ard  ya  go  free  abt  muz  call  u  discus  liao',
#  'time  coming  later',
#  'bloody  hell  cant  believe  forgot  surname  mr  ill  give  u  clue  spanish  begin',
#  'well  im  gonna  finish  bath  goodfine  night',
#  'let  know  youve  got  money  carlos  make  call',
#  'u  still  going  mall',
#  'turn  friend  staying  whole  show  wont  back  til  ltgt  feel  free  go  ahead  smoke  ltgt  worth',
#  'text  doesnt  reply  let  know  log',
#  'hi  spoke  maneesha  v  wed  like  know  satisfied  experience  reply  toll  free  yes',
#  'lifted  hope  offer  money  need  especially  end  month  approach  hurt  studying  anyways  gr  weekend',
#  'lol  u  trust',
#  'ok  gentleman  treat  dignity  respect',
#  'guy  close',
#  'going  nothing  greatbye',
#  'hello  handsome  finding  job  lazy  working  towards  getting  back  net  mummy  wheres  boytoy  miss',
#  'haha  awesome  minute',
#  'please  call  customer  service  representative  freephone  ampm  guaranteed  cash  prize',
#  'got  xmas  radio  time  get',
#  'jus  reached  home  go  bathe  first  si  using  net  tell  u  finish  k',
#  'unique  enough  find  th  august  wwwareyouuniquecouk',
#  'im  sorry  ive  joined  league  people  dont  keep  touch  mean  great  deal  friend  time  even  great  personal  cost  great  week',
#  'hi  finally  completed  course',
#  'stop  however  suggest  stay  someone  able  give  or  every  stool',
#  'hope  youve  settled  new  school  year  wishin  gr  day',
#  'gud  mrng  dear  hav  nice  day',
#  'u  got  person  story',
#  'hamster  dead  hey  tmr  meet  pm  orchard  mrt',
#  'hi  kate  evening  hope  see  tomorrow  bit  bloody  babyjontet  txt  back  u  xxx',
#  'found  enc  ltgt',
#  'sent  ltgt  buck',
#  'hello  darlin  ive  finished  college  txt  u  finish  u  love  kate  xxx',
#  'account  refilled  successfully  inr  ltdecimalgt  keralacircle  prepaid  account  balance  r  ltdecimalgt  transaction  id  kr  ltgt',
#  'goodmorning  sleeping  ga',
#  'u  call  alter  ok',
#  'say  like  dat  dun  buy  ericsson  oso  cannot  oredi  lar',
#  'entered  cabin  pa  said  happy  bday  bos  felt  special  askd  lunch  lunch  invited  apartment  went',
#  'aight  yo  dat  straight  dogg',
#  'please  give  u  connection  today  ltdecimalgt  refund  bill',
#  'shoot  big  load  get  ready',
#  'whats  bruv  hope  great  break  rewarding  semester',
#  'home  always  chat',
#  'kkgoodstudy  well',
#  'yup  noe  leh',
#  'sound  great  home',
#  'finally  match  heading  towards  draw  prediction',
#  'tired  havent  slept  well  past  night',
#  'easy  ahsen  got  selected  mean  good',
#  'take  exam  march',
#  'yeah  think  use  gt  atm  register  sure  there  anyway  help  let  know  sure  ready',
#  'ok  prob  take  ur  time',
#  'o  called  ubandu  run  without  installing  hard  diskyou  use  o  copy  important  file  system  give  repair  shop',
#  'sorry  ill  call  later',
#  'u  say  leh  course  nothing  happen  lar  say  v  romantic  jus  bit  lor  thk  e  nite  scenery  nice  leh',
#  'new  mobile  must  go  txt  nokia  collect  todayfrom  wwwtcbiz  optout  gbpmtmsg',
#  'would  really  appreciate  call  need  someone  talk',
#  'u  meet  ur  dream  partner  soon  ur  career  flyng  start  find  free  txt  horo  followed  ur  star  sign  e  g  horo  aries',
#  'hey  company  elama  po  mudyadhu',
#  'life  strict  teacher  bcoz  teacher  teach  lesson  amp  conduct  exam  life  first  conduct  exam  amp  teach  lesson  happy  morning',
#  'dear  good  morning',
#  'get  gandhipuram  walk  cross  cut  road  right  side  ltgt  street  road  turn  first  right',
#  'dear  going  rubber  place',
#  'sorry  battery  died  yeah  im',
#  'yeshere  tv  always  available  work  place',
#  'text  meet  someone  sexy  today  u  find  date  even  flirt  u  join  p  reply  name  age  eg  sam  msg  recdthirtyeight  penny',
#  'printed  oh  ltgt  come  upstairs',
#  'ill  little  closer  like  bus  stop  street',
#  'youwhen  wil  reach',
#  'new  theory  argument  win  situation  loses  person  dont  argue  ur  friend  kick  amp  say  im  always  correct',
#  'u  secret  admirer  looking  make  contact  ufind  rreveal  think  ur  specialcall',
#  'tomarrow  final  hearing  laptop  case  cant',
#  'pleassssssseeeeee  tel  v  avent  done  sportsx',
#  'okay  shining  meant  signing  sound  better',
#  'although  told  u  dat  im  baig  face  watch  really  like  e  watch  u  gave  co  fr  u  thanx  everything  dat  uve  done  today  im  touched',
#  'u  dont  remember  old  commercial',
#  'late  said  website  didnt  dont  slipper',
#  'asked  call  ok',
#  'kallis  wont  bat  nd  inning',
#  'didnt  work  oh  ok  goodnight  ill  fix  ready  time  wake  dearly  missed  good  night  sleep',
#  'congratulation  ur  awarded  cd  voucher  gift  guaranteed  free  entry  wkly  draw  txt  music  tncs  wwwldewcomwinppmxage',
#  'ranjith  cal  drpd  deeraj  deepak  min  hold',
#  'wen  ur  lovable  bcums  angry  wid  u  dnt  take  seriously  coz  angry  childish  n  true  way  showing  deep  affection  care  n  luv  kettoda  manda  nice  day  da',
#  'doinghow',
#  'ups  day  also  shipping  company  take  wks  way  usps  take  week  get  lag  may  bribe  nipost  get  stuff',
#  'im  back  lemme  know  youre  ready',
#  'dont  necessarily  expect  done  get  back  though  im  headin',
#  'mmm  yummy  babe  nice  jolt  suzy',
#  'lover  need',
#  'tried  contact  reply  offer  video  handset  anytime  network  min  unlimited  text  camcorder  reply  call',
#  'im  parked  next  mini  coming  today  think',
#  'yup',
#  'anyway  im  going  shopping  co  si  done  yet  dun  disturb  u  liao',
#  'luton  ring  ur  around  h',
#  'hey  really  horny  want  chat  see  naked  text  hot  text  charged  pm  unsubscribe  text  stop',
#  'dint  come  u',
#  'wana  plan  trip  sometme',
#  'sure  yet  still  trying  get  hold',
#  'ur  ringtone  service  changed  free  credit  go  clubmobilescom  choose  content  stop  txt  club  stop  pwk  club  po  box  mk  wt',
#  'evo  download  flash  jealous',
#  'ringtone  club  get  uk  single  chart  mobile  week  choose  top  quality  ringtone  message  free  charge',
#  'come  mu  sorting  narcotic  situation',
#  'night  ended  another  day  morning  come  special  way  may  smile  like  sunny  ray  leaf  worry  blue  blue  bay',
#  'hmv  bonus  special  pound  genuine  hmv  voucher  answer  easy  question  play  send  hmv  infowwwpercentrealcom',
#  'usf  guess  might  well  take  car',
#  'objection  bf  coming',
#  'thanx',
#  'tell  rob  mack  gf  theater',
#  'awesome  ill  see  bit',
#  'sent  type  food  like',
#  'done  handed  celebration  full  swing  yet',
#  'got  called  tool',
#  'ok  asked  money  far',
#  'okie',
#  'yeah  think  usual  guy  still  passed  last  night  get  ahold  anybody  let  know  ill  throw',
#  'k  might  come  tonight  class  let  early',
#  'ok',
#  'hi  baby  im  cruisin  girl  friend  r  u  give  call  hour  home  thats  alright  fone  fone  love  jenny  xxx',
#  'life  mean  lot  love  life  love  people  life  world  call  friend  call  world  ge',
#  'dearshall  mail  tonitebusy  streetshall  update  tonitethings  looking  okvarunnathu  edukkukayee  raksha  ollubut  good  one  real  sense',
#  'hey  told  name  gautham  ah',
#  'haf  u  found  feel  stupid  da  v  cam  working',
#  'oops  got  bit',
#  'much  buzy',
#  'accidentally  deleted  message  resend  please',
#  'tmobile  customer  may  claim  free  camera  phone  upgrade  pay  go  sim  card  loyalty  call  offer  end  thfebtcs  apply',
#  'unless  situation  go  gurl  would  appropriate',
#  'hurt  tease  make  cry  end  life  die  plz  keep  one  rose  grave  say  stupid  miss  u  nice  day  bslvyl',
#  'cant  pick  phone  right  pls  send  message',
#  'need  coffee  run  tomocant  believe  time  week  already',
#  'awesome  remember  last  time  got  somebody  high  first  time  diesel  v',
#  'shit  really  shocking  scary  cant  imagine  second  def  night  u  think  somewhere  could  crash  night  save  taxi',
#  'oh  way  food  fridge  want  go  meal  tonight',
#  'womdarfull  actor',
#  'sm  ac  blind  date  u  rodds  aberdeen  united  kingdom  check  httpimg  sm  acwicmbcktzr  blind  date  send  hide',
#  'yup  remb  think  book',
#  'jos  ask  u  wana  meet',
#  'lol  yes  friendship  hanging  thread  cause  u  wont  buy  stuff',
#  'themob  check  newest  selection  content  game  tone  gossip  babe  sport  keep  mobile  fit  funky  text  wap',
#  'garage  key  arent  bookshelf',
#  'today  accept  dayu  accept  brother  sister  lover  dear  best  clos  lvblefrnd  jstfrnd  cutefrnd  lifpartnr  belovd  swtheart  bstfrnd  rply  mean  enemy',
#  'think  ur  smart  win  week  weekly  quiz  text  play  nowtcs  winnersclub  po  box  uz  gbpweek',
#  'say  hell  give  call  friend  got  money  he  definitely  buying  end  week',
#  'hi  way  u  day  normal  waythis  real  ur  uniquei  hope  know  u  rest  mylife  hope  u  find  wot  lost',
#  'made  day  great  day',
#  'kkadvance  happy  pongal',
#  'hmmm  guess  go  kb  n  power  yoga  haha  dunno  tahan  power  yoga  anot  thk  got  lo  oso  forgot  liao',
#  'really  dude  friend  im  afraid',
#  'december  mobile  mths  entitled  update  latest  colour  camera  mobile  free  call  mobile  update  co  free',
#  'coffee  cake  guess',
#  'merry  christmas  babe  love  ya  kiss',
#  'hey  dont  go  watch  x  men  lunch  haha',
#  'cud  u  tell  ppl  im  gona  b  bit  l  co  bus  hav  gon  past  co  full  im  still  waitin  pete  x',
#  'would  great  well  guild  could  meet  bristol  road  somewhere  get  touch  weekend  plan  take  flight  good  week',
#  'problem',
#  'callsmessagesmissed  call',
#  'hi  dahow  today  class',
#  'id  say  thats  good  sign  well  know  track  record  reading  woman',
#  'cool  text  youre  parked',
#  'im  reading  text  sent  meant  joke  read  light',
#  'kkapo  kgood  movie',
#  'maybe  could  get  book  tomo  return  immediately  something',
#  'call  germany  penny  per  minute  call  fixed  line  via  access  number  prepayment  direct  access',
#  'chance  might  evaporated  soon  violated  privacy  stealing  phone  number  employer  paperwork  cool  please  contact  report  supervisor',
#  'valentine  day  special  win  quiz  take  partner  trip  lifetime  send  go  pmsg  rcvd  custcare',
#  'tadaaaaa  home  babe  still',
#  'cool  come  havent  wined  dined',
#  'sleepingand  surfing',
#  'sorry  ill  call  later',
#  'u  calling  right  call  hand  phone',
#  'ok  thats  great  thanx  lot',
#  'take  post  come  must  text  happy  reading  one  wiv  hello  caroline  end  favourite  bless',
#  'u  hiding  stranger',
#  'interested  like',
#  'sister  cleared  two  round  birla  soft  yesterday',
#  'gudnitetcpractice  going',
#  'dis  yijue  jus  saw  ur  mail  case  huiming  havent  sent  u  num  dis  num',
#  'one  small  prestige  problem',
#  'fancy  shag  dointerested  sextextukcom  txt  xxuk  suzy  txts  cost  per  msg  tncs  website  x',
#  'checking  really  miss  seeing  jeremiah  great  month',
#  'nah  cant  help  ive  never  iphone',
#  'youre  car  hour  half  im  going  apeshit',
#  'today  sorry  day  ever  angry  ever  misbehaved  hurt  plz  plz  slap  urself  bcoz  ur  fault  im  basically  good',
#  'yo  guy  ever  figure  much  need  alcohol  jay  trying  figure  much  safely  spend  weed',
#  'ltgt  ish  minute  minute  ago  wtf',
#  'thank  callingforgot  say  happy  onam  sirjii  fine  remembered  met  insurance  personmeet  qatar  insha  allahrakhesh  ex  tata  aig  joined  tisscotayseer',
#  'congratulation  ur  awarded  cd  voucher  gift  guaranteed  free  entry  wkly  draw  txt  music  tncs  wwwldewcomwinppmxage',
#  'ur  cashbalance  currently  pound  maximize  ur  cashin  send  cash  pmsg  cc  hgsuitelands  rowwjhl',
#  'im  actor  work  work  evening  sleep  late  since  im  unemployed  moment  always  sleep  late  youre  unemployed  every  day  saturday',
#  'hello  got  st  andrewsboy  long  way  cold  keep  posted',
#  'ha  ha  cool  cool  chikku  chikkudb',
#  'oh  ok  prob',
#  'check  audreys  status  right',
#  'busy  trying  finish  new  year  looking  forward  finally  meeting',
#  'good  afternoon  sunshine  dawn  day  refreshed  happy  alive  breathe  air  smile  think  love  always',
#  'well  know  z  take  care  worry',
#  'updatenow  xmas  offer  latest  motorola  sonyericsson  nokia  free  bluetooth  double  min  txt  orange  call  mobileupd  calloptoutfq',
#  'discount  code  rp  stop  message  reply  stop  wwwregalportfoliocouk  customer  service',
#  'wat  uniform  get',
#  'cool  text  youre  ready',
#  'hello  boytoy  geeee  miss  already  woke  wish  bed  cuddling  love',
#  'spoil  bed  well',
#  'im  going  bath  msg  next  ltgt  min',
#  'cant  keep  talking  people  sure  pay  agree  price  pls  tell  want  really  buy  much  willing  pay',
#  'thanks  ringtone  order  reference  charged  gbp  per  week  unsubscribe  anytime  calling  customer  service',
#  'say  happen',
#  'could  seen  mei  didt  recognise  face',
#  'well  there  lot  thing  happening  lindsay  new  year  sigh  bar  ptbo  blue  heron  something  going',
#  'keep  payasam  rinu  brings',
#  'taught  ranjith  sir  called  sm  like  becaus  he  verifying  project  prabu  told  today  pa  dont  mistake',
#  'guess  thats  worried  must  know  there  way  body  repair  im  quite  sure  shouldnt  worry  well  take  slow  first  test  guide  ovulation  relax  nothing  youve  said  reason  worry  ill  keep  followin',
#  'yeah  sure  give  couple  minute  track  wallet',
#  'hey  leave  big  deal  take  care',
#  'hey  late  ah  meet',
#  'double  min  txts  month  free  bluetooth  orange  available  sony  nokia  motorola  phone  call  mobileupd  calloptoutndx',
#  'took  mr  owl  lick',
#  'customer  place  call',
#  'mm  time  dont  like  fun',
#  'mths  half  price  orange  line  rental  latest  camera  phone  free  phone  mths  call  mobilesdirect  free  update  orstoptxt',
#  'yup  lunch  buffet  u  eat  already',
#  'huh  late  fr  dinner',
#  'hey  sat  going  intro  pilate  kickboxing',
#  'morning  ok',
#  'yes  think  office  lap  room  think  thats  last  day  didnt  shut',
#  'pick  bout  ish  time  going',
#  'performance  award  calculated  every  two  monthnot  current  one  month  period',
#  'actually  sleeping  still  might  u  call  back  text  gr  rock  si  send  u  text  wen  wake',
#  'always  putting  business  put  picture  as  facebook  one  open  people  ive  ever  met  would  think  picture  room  would  hurt  make  feel  violated',
#  'good  evening  sir  al  salam  wahleykkumsharing  happy  newsby  grace  god  got  offer  tayseertissco  joinedhope  fineinshah  allahmeet  sometimerakheshvisitor  india',
#  'hmmmkbut  want  change  field  quickly  dai  wanna  get  system  administrator  network  administrator',
#  'free  ringtone  text  first  poly  text  get  true  tone  help  st  free  tone  xpw  end  txt  stop',
#  'dear  chechi  talk',
#  'hair  cream  shipped',
#  'none  thats  happening  til  get  though',
#  'yep  great  loxahatchee  xmas  tree  burning  ltgt  start  hour',
#  'haha  get  used  driving  usf  man  know  lot  stoner',
#  'well  slightly  disastrous  class  pm  fav  darling  hope  day  ok  coffee  wld  good  cant  stay  late  tomorrow  time  place  always',
#  'hello  good  week  fancy  drink  something  later',
#  'headin  towards  busetop',
#  'messagesome  text  missing  sendername  missing  number  missing  sentdate  missing  missing  u  lot  thats  everything  missing  sent  via  fullonsmscom',
#  'come  room  point  iron  plan  weekend',
#  'co  want  thing',
#  'okies  ill  go  yan  jiu  skip  ard  oso  go  cine  den  go  mrt  one  blah  blah  blah',
#  'bring  home  wendy',
#  'dating  service  call  boxskch',
#  'whatsup  dont  u  want  sleep',
#  'alright  new  goal',
#  'free  entry  weekly  competition  text  word  win  tc  wwwtxttowincouk',
#  'alright  ill  head  minute  text  meet',
#  'send  logo  ur  lover  name  joined  heart  txt  love  name  name  mobno  eg  love  adam  eve  yahoo  poboxwwq  txtno  ad  p',
#  'yesfrom  last  week  im  taking  live  call',
#  'someone  contacted  dating  service  entered  phone  fancy  find  call  landline  poboxntfp',
#  'siva  hostel  aha',
#  'urgent  mobile  number  awarded  prize  guaranteed  call  land  line  claim  valid  hr',
#  'send  ur  friend  receive  something  ur  voice  speaking  expression  childish  naughty  sentiment  rowdy  ful  attitude  romantic  shy  attractive  funny  ltgt  irritating  ltgt  lovable  reply',
#  'ok  shell  ok  guess',
#  'aathiwhere  dear',
#  'pain  urination  thing  else',
#  'esplanade  mind  giving  lift  co  got  car  today',
#  'wnt  buy  bmw  car  urgentlyits  vry  urgentbut  hv  shortage  ltgt  lacsthere  source  arng  dis  amt  ltgt  lacsthats  prob',
#  'home  watching  tv  lor',
#  'usually  take  fifteen  fucking  minute  respond  yes  question',
#  'congrats  nokia  video  camera  phone  call  call  cost  ppm  ave  call  min  vary  mobile  close  post  bcm  ldn  wcnxx',
#  'booked  ticket  pongal',
#  'available  im  like  right  around  hillsborough  amp  ltgt  th',
#  'message  sent  askin  ltgt  dollar  shoul  pay  ltgt  ltgt',
#  'ask  g  iouri  ive  told  story  like  ten  time  already',
#  'long  applebees  fucking  take',
#  'hi  hope  u  get  txtjourney  hasnt  gdnow  min  late  think',
#  'like  love  arrange',
#  'yeshe  really  greatbhaji  told  kallis  best  cricketer  sachin  worldvery  tough  get',
#  'supposed  wake  gt',
#  'oic  saw  tot  din  c  found  group  liao',
#  'sorry  ill  call  later',
#  'sorry  battery  died  come  im  getting  gram  wheres  place',
#  'well  done  blimey  exercise  yeah  kinda  remember  wot  hmm',
#  'wont  get  concentration  dear  know  mind  everything',
#  'lol  made  plan  new  year',
#  'min  later  k',
#  'hank  lotsly',
#  'thanks  hope  good  day  today',
#  'kkwhat  detail  want  transferacc  enough',
#  'ok  tell  stay  yeah  tough  optimistic  thing  improve  month',
#  'loan  purpose  homeowner  tenant  welcome  previously  refused  still  help  call  free  text  back  help',
#  'si  si  think  ill  go  make  oreo  truffle',
#  'look  amy  ure  beautiful  intelligent  woman  like  u  lot  know  u  dont  like  like  dont  worry',
#  'hope  thats  result  consistently  intelligent  kind  start  asking  practicum  link  keep  ear  open  best  ttyl',
#  'call  cost  guess  isnt  bad  miss  ya  need  ya  want  ya  love  ya',
#  'going  thru  different  feelingwavering  decision  coping  individualtime  heal  everything  believe',
#  'u  go  phone  gonna  die  stay',
#  'great  never  better  day  give  even  reason  thank  god',
#  'upgrdcentre  orange  customer  may  claim  free  camera  phone  upgrade  loyalty  call  offer  end  th  july  tc  apply  optout  available',
#  'sorry  ill  call  later  ok  bye',
#  'ok  way  railway',
#  'great  princess  love  giving  receiving  oral  doggy  style  fave  position  enjoy  making  love  ltgt  time  per  night',
#  'dont  put  stuff  road  keep  getting  slippery',
#  'going  ride  bike',
#  'yup  need  ill  jus  wait  e  rain  stop',
#  'many  company  tell  language',
#  'okmail  dear  dave  final  notice  collect  tenerife  holiday  cash  award  call  landline  tc  sae  box  cwwx  ppm',
#  'long  since  screamed  princess',
#  'nothing  meant  money  enters  account  bank  remove  flat  rate  someone  transfered  ltgt  account  ltgt  dollar  got  removed  bank  differ  charge  also  differbe  sure  trust  ja  person  sending  account  detail  co',
#  'want  get  laid  tonight  want  real  dogging  location  sent  direct  ur  mob  join  uk  largest  dogging  network  txting  moan  nyt  eca  pmsgp',
#  'nice  line  said  broken  heart  plz  dont  cum  time  infront  wise  trust  u  good',
#  'ok  im  gonna  head  usf  like  fifteen  minute',
#  'love  aathilove  u  lot',
#  'tension  ahwhat  machiany  problem',
#  'k  pick  another  th  youre  done',
#  'whenre  guy  getting  back  g  said  thinking  staying  mcr',
#  'almost  see  u  sec',
#  'yo  carlos  friend  already  asking  working  weekend',
#  'watching  tv  lor',
#  'thank  baby  cant  wait  taste  real  thing',
#  'change  fb  jaykwon  thuglyfe  falconerf',
#  'win  really  side  long  time',
#  'free  message  activate  free  text  message  replying  message  word  free  term  condition  visit  wwwcom',
#  'dear  reached  railway  happen',
#  'depends  quality  want  type  sent  boye  faded  glory  want  ralphs  maybe',
#  'think  ive  fixed  send  test  message',
#  'sorry  man  account  dry  would  want  could  trade  back  half  could  buy  shit  credit  card',
#  'congrats  year  special  cinema  pas  call  c  suprman  v  matrix  starwars  etc  free  bxipwe  pm  dont  miss',
#  'sorryin  meeting  ill  call  later',
#  'class  ltgt  reunion',
#  'free  nowcan  call',
#  'got  meh',
#  'nope  think  go  monday  sorry  replied  late',
#  'told  accenture  confirm  true',
#  'kate  jackson  rec  center  ish  right',
#  'dear  reache  room',
#  'fighting  world  easy  u  either  win  lose  bt  fightng  close  u  dificult  u  lose  u  lose  u  win  u  still  lose',
#  'come',
#  'check  nuerologist',
#  'lolnice  went  fish  water',
#  'congratulation  week  competition  draw  u  prize  claim  call  b  tcsstop  sm  ppm',
#  'waiting  e  car  dat  bored  wat  co  wait  outside  got  nothing  home  stuff  watch  tv  wat',
#  'maybe  westshore  hyde  park  village  place  near  house',
#  'know  hows  anthony  bringing  money  ive  school  fee  pay  rent  stuff  like  thats  need  help  friend  need',
#  'whats  significance',
#  'opinion  jada  kusruthi  lovable  silent  spl  character  matured  stylish  simple  pls  reply',
#  'latest  g  still  scrounge  ammo  want  give  new  ak  try',
#  'prabhaim  sorydarealyfrm  heart  im  sory',
#  'lol  ok  forgiven',
#  'nojst  change  tat',
#  'guaranteed  latest  nokia  phone  gb  ipod  mp  player  prize  txt  word  collect  ibhltd  ldnwh  pmtmsgrcvd',
#  'sno  competition',
#  'boltblue  tone  p  reply  poly  mono  eg  poly  cha  cha  slide  yeah  slow  jamz  toxic  come  stop  tone  txt',
#  'credit  topped  httpwwwbubbletextcom  renewal  pin  tgxxrz',
#  'way  transport  less  problematic  sat  night  way  u  want  ask  n  join  bday  feel  free  need  know  definite  no  booking  fri',
#  'usually  person  unconscious  thats  child  adult  may  behave  abnormally  ill  call',
#  'thats  ebay  might  less  elsewhere',
#  'shall  come  get  pickle',
#  'gonna  go  get  taco',
#  'thats  rude  campus',
#  'urgent  mobile  awarded  bonus  caller  prize  nd  attempt  contact  call  boxqu',
#  'hi  wont  b  ard  christmas  enjoy  n  merry  xmas',
#  'today  offer  claim  ur  worth  discount  voucher  text  yes  savamob  member  offer  mobile  c  sub  unsub  reply  x',
#  'yes  pretty  lady  like  single',
#  'recieve  tone  within  next  hr  term  condition  please  see  channel  u  teletext  pg',
#  'jay  say  youre  doublefaggot',
#  'private  account  statement  show  unredeemed  sim  point  call  identifier  code  expires',
#  'todaysundaysunday  holidayso  work',
#  'gudnitetcpractice  going',
#  'ill  late',
#  'ive  called  hoping  lr  malaria  know  miss  guy  miss  ban  big  pls  give  love  especially  great  day',
#  'good  afternoon  love  go  day  hope  maybe  got  lead  job  think  boytoy  send  passionate  kiss  across  sea',
#  'probably  gonna  see  later  tonight  lt',
#  'maybe  fat  finger  press  button  doesnt  know',
#  'ummmmmaah  many  many  happy  return  day  dear  sweet  heart  happy  birthday  dear',
#  'tirupur  da  started  office  call',
#  'wwwapplausestorecom  monthlysubscriptionpmsg  maxmonth  tcsc  web  age  stop  txt  stop',
#  'famous  quote  develop  ability  listen  anything  unconditionally  without  losing  temper  self  confidence  mean  married',
#  'going  college  pa  else  ill  come  self  pa',
#  'oclock  mine  bash  flat  plan',
#  'girl  stay  bed  girl  doesnt  need  recovery  time  id  rather  pas  fun  cooped  bed',
#  'special',
#  'know  need  get  hotel  got  invitation  apologise  cali  sweet  come  english  bloke  weddin',
#  'sorry  took  long  omw',
#  'wait  ltgt  min',
#  'ok  give  minute  think  see  btw  youre  alibi  cutting  hair  whole  time',
#  'imagine  finally  get  sink  bath  put  pace  maybe  even  eat  left  also  imagine  feel  cage  cock  surrounded  bath  water  reminding  always  owns  enjoy  cuck',
#  'hurry  ive  weeddeficient  like  three  day',
#  'sure  get  acknowledgement  astoundingly  tactless  generally  faggy  demand  blood  oath  fo',
#  'ok  every  night  take  warm  bath  drink  cup  milk  youll  see  work  magic  still  need  loose  weight  know',
#  'ill  look  frying  pan  case  cheap  book  perhaps  thats  silly  frying  pan  isnt  likely  book',
#  'well  uv  cause  mutation  sunscreen  like  essential  thesedays',
#  'lunchyou  onlinewhy',
#  'know  friend  already  told',
#  'hi  princess  thank  pic  pretty',
#  'aiyo  u  always  c  ex  one  dunno  abt  mei  reply  first  time  u  reply  fast  lucky  workin  huh  got  bao  ur  sugardad  ahgee',
#  'hi  msg  meim  office',
#  'thanx  e  brownie  v  nice',
#  'geeeee  love  much  barely  stand',
#  'gent  trying  contact  last  weekend  draw  show  prize  guaranteed  call  claim  code  k  valid  hr  ppm',
#  'fuck  babe  miss  already  know  cant  let  send  money  towards  net  need  want  crave',
#  'ill  call  u  mrw  ninish  address  icky  american  freek  wont  stop  callin  bad  jen  k  eh',
#  'oooh  bed  ridden  ey  thinking',
#  'anyways  go  gym  whatever  love  smile  hope  ok  good  day  babe  miss  much  already',
#  'love  daddy  make  scream  pleasure  going  slap  as  dick',
#  'wot  u  wanna  missy',
#  'yar  lor  wait  mum  finish  sch  lunch  lor  whole  morning  stay  home  clean  room  room  quite  clean  hee',
#  'know  lab  goggles  went',
#  'open  door',
#  'waiting  call',
#  'nope  waiting  sch  daddy',
#  'cash  prize  claim  call',
#  'im  tired  arguing  week  week  want  ill',
#  'wait  sch  finish  ard',
#  'mobile  number  claim  call  u  back  ring  claim  hot  line',
#  'arngd  marriage  u  r  walkin  unfortuntly  snake  bite  u  bt  love  marriage  dancing  frnt  snake  amp  sayin  bite  bite',
#  'huh  early  dinner  outside  izzit',
#  'ok  anyway  need  change  said',
#  'tried  contact  reply  offer  min  textand  new  video  phone  call  reply  free  delivery  tomorrow',
#  'exwife  able  kid  want  kid  one  day',
#  'hows  scotland  hope  showing  jjc  tendency  take  care  live  dream',
#  'tell  u  headache  want  use  hour  sick  time',
#  'dun  thk  ill  quit  yet  hmmm  go  jazz  yogasana  oso  go  meet  em  lesson  den',
#  'pete  please  ring  meive  hardly  gotany  credit',
#  'ya  srsly  better  yi  tho',
#  'im  meeting  call  later',
#  'ur  chance  win  wkly  shopping  spree  txt  shop  tscs  wwwtxtshopcom  custcare  xpwk',
#  'specially  selected  receive  pound  award  call  line  close  cost  ppm  tc  apply  ag  promo',
#  'private  account  statement  show  unredeemed  point  call  identifier  code  expires',
#  'still  grand  prix',
#  'met  stranger  choose  friend  long  world  stand  friendship  never  end  let  friend  forever  gud  nitz',
#  'great',
#  'gud  mrng  dear  nice  day',
#  'important  customer  service  announcement  call  freephone',
#  'exhausted  train  morning  much  wine  pie  sleep  well',
#  'im  going  buy  mum  present  ar',
#  'mind  blastin  tsunami  occur  rajnikant  stopped  swimming  indian  oceand',
#  'u  sending  home  first  ok  lor  im  ready  yet',
#  'speaking  cash  yet',
#  'happy  come  noon',
#  'meet  lunch  la',
#  'take  care  n  get  well  soon',
#  'xclusiveclubsaisai  morow  soiree  speciale  zouk  nichols  parisfree  rose  lady  info',
#  'meant  say  cant  wait  see  u  getting  bored  bridgwater  banter',
#  'neva  mind  ok',
#  'fine  imma  get  drink  somethin  want  come  find',
#  'day  kick  euro  u  kept  date  latest  news  result  daily  removed  send  get  txt  stop',
#  'valentine  game  send  dis  msg  ur  friend  answer  r  someone  really  love  u  ques  colour  suit  bestrply',
#  'many  dependent',
#  'thanx  today  cer  nice  catch  ave  find  time  often  oh  well  take  care  c  u  soonc',
#  'called  said  himthen  choose  future',
#  'happy  valentine  day  know  early  hundred  handsomes  beauty  wish  thought  finish  aunty  uncle  st',
#  'like  v  shock  leh  co  telling  shuhui  like  telling  leona  also  like  dat  almost  know  liao  got  ask  abt  ur  reaction  lor',
#  'family  happiness',
#  'come  n  pick  come  immediately  aft  ur  lesson',
#  'let  snow  let  snow  kind  weather  brings  ppl  together  friendship  grow',
#  'dear  got  ltgt  dollar  hi  hi',
#  'good  word  word  may  leave  u  dismay  many  time',
#  'make  sure  alex  know  birthday  fifteen  minute  far  youre  concerned',
#  'sorry  got  thing  may  pub  later',
#  'nah  straight  bring  bud  drink  something  thats  actually  little  useful  straight  cash',
#  'haha  good  hear  im  officially  paid  market  th',
#  'many  lick  take  get  center  tootsie  pop',
#  'yup  thk  r  e  teacher  said  make  face  look  longer  darren  ask  cut  short',
#  'new  textbuddy  chat  horny  guy  ur  area  p  free  receive  search  postcode  gaytextbuddycom  txt  one  name',
#  'today  vodafone  number  ending  selected  receive  award  number  match  call  receive  award',
#  'please  dont  say  like  hi  hi  hi',
#  'thank  u',
#  'oh  forwarded  message  thought  send',
#  'got  seventeen  pound  seven  hundred  ml  hope  ok',
#  'dear  voucher  holder  claim  week  offer  pc  go  httpwwwetlpcoukexpressoffer  tscs  apply  stop  text  txt  stop',
#  'n  funny',
#  'sweetheart  hope  kind  day  one  load  reason  smile  biola',
#  'login  dat  time  dad  fetching  home',
#  'shower  baby',
#  'askd  u  question  hour  answer',
#  'well  imma  definitely  need  restock  thanksgiving  ill  let  know  im',
#  'said  kiss  kiss  cant  sound  effect  gorgeous  man  isnt  kind  person  need  smile  brighten  day',
#  'probably  gonna  swing  wee  bit',
#  'ya  nice  ready  thursday',
#  'allo  braved  bus  taken  train  triumphed  mean  bham  jolly  good  rest  week',
#  'watching  cartoon  listening  music  amp  eve  go  temple  amp  church  u',
#  'mind  ask  happened  dont  say  uncomfortable',
#  'private  account  statement  show  unredeemed  point  call  identifier  code  expires',
#  'prob  send  email',
#  'cash  prize  claim  call  tc  rstm  sw  s  ppm',
#  'thats  cool  sometimes  slow  gentle  sonetimes  rough  hard',
#  'im  gonna  say  sorry  would  normal  starting  panic  time  sorry  seeing  tuesday',
#  'wait  know  wesley  town  bet  hella  drug',
#  'fine  miss  much',
#  'u  got  person  story',
#  'tell  drug  dealer  getting  impatient',
#  'sun  cant  come  earth  send  luv  ray  cloud  cant  come  river  send  luv  rain  cant  come  meet  u  send  care  msg  u  gud  evng',
#  'place  man',
#  'doesnt  make  sense  take  unless  free  need  know  wikipediacom',
#  'premium  phone  service  call',
#  'sea  lay  rock  rock  envelope  envelope  paper  paper  word',
#  'mum  repent',
#  'sorry  going  home  first  daddy  come  fetch  later',
#  'leave  de  start  prepare  next',
#  'yes  baby  study  position  kama  sutra',
#  'en  chikku  nange  bakra  msg  kalstiyathen  teacoffee',
#  'carlosll  minute  still  need  buy',
#  'pay  ltdecimalgt  lakh',
#  'good  evening  ttyl',
#  'u  receive  msg',
#  'ho  ho  big  belly  laugh  see  ya  tomo',
#  'get  ur  st  ringtone  free  reply  msg  tone  gr  top  tone  phone  every  week  per  wk  opt  send  stop',
#  'ditto  wont  worry  saying  anything  anymore  like  said  last  night  whatever  want  ill  peace',
#  'ive  got  ltgt  way  could  pick',
#  'dont  knw  pa  drink  milk',
#  'maybe  say  hi  find  got  card  great  escape  wetherspoons',
#  'piggy  r  u  awake  bet  ure  still  sleeping  im  going  lunch',
#  'cause  im  freaky  lol',
#  'missed  call  cause  yelling  scrappy  miss  u  cant  wait  u  come  home  im  lonely  today',
#  'hex  place  talk  explain',
#  'log  wat  sdrybi',
#  'xy  going  e  lunch',
#  'hi  im  sue  year  old  work  lapdancer  love  sex  text  live  im  bedroom  text  sue  textoperator  g  da  ppmsg',
#  'wanted  ask  wait  finish  lect  co  lect  finish  hour  anyway',
#  'finished  work  yet',
#  'every  king  cry  baby  every  great  building  map  imprtant  u  r  today  u  wil  reach  tomorw  gud  ni',
#  'dearme  cherthalain  case  u  r  coming  cochin  pls  call  bfore  u  starti  shall  also  reach  accordinglyor  tell  day  u  r  comingtmorow  engaged  an  holiday',
#  'thanks  love  torch  bold',
#  'forwarded  please  call  immediately  urgent  message  waiting',
#  'farm  open',
#  'sorry  trouble  u  buy  dad  big  small  sat  n  sun  thanx',
#  'sister  law  hope  great  month  saying  hey  abiola',
#  'purchase  stuff  today  mail  po  box  number',
#  'ah  poop  look  like  ill  prob  send  laptop  get  fixed  cuz  gpu  problem',
#  'good  good  job  like  entrepreneur',
#  'aight  close  still  around  alexs  place',
#  'meet  corporation  st  outside  gap  see  mind  working',
#  'mum  ask  buy  food  home',
#  'ku  also  dont  msg  reply  msg',
#  'much  r  willing  pay',
#  'sorry  ill  call  later',
#  'important  prevent  dehydration  giving  enough  fluid',
#  'thats  bit  weird  even  supposed  happening  good  idea  sure  pub',
#  'true  deari  sat  pray  evening  felt  soso  smsd  time',
#  'dont  think  get  away  trek  long  family  town  sorry',
#  'wanna  gym  harri',
#  'quite  late  lar  ard  anyway  wun  b  drivin',
#  'review  keep  fantastic  nokia  ngage  game  deck  club  nokia  go  wwwcnupdatescomnewsletter  unsubscribe  alert  reply  word',
#  'mths  half  price  orange  line  rental  latest  camera  phone  free  phone  mths  call  mobilesdirect  free  update  orstoptxt  tc',
#  'seems  like  weird  timing  night  g  want  come  smoke  day  shitstorm  attributed  always  coming  making  everyone  smoke',
#  'ampm  cost  p',
#  'save  stress  person  dorm  account  send  account  detail  money  sent',
#  'also  know  lunch  menu  da  know',
#  'stuff  sell  ill  tell',
#  'urgent  nd  attempt  contact  uu  call  b  tcsbcmwcnxx  callcost  ppm  mobilesvary  max',
#  'book  lesson  msg  call  work  sth  im  going  get  spec  membership  px',
#  'guaranteed  cash  prize  claim  yr  prize  call  customer  service  representative  ampm',
#  'macha  dont  feel  upseti  assume  mindsetbelieve  one  evening  wonderful  plan  uslet  life  begin  againcall  anytime',
#  'oh  send  address',
#  'sfine  anytime  best',
#  'wondar  full  flim',
#  'ya  even  cooky  jelly',
#  'world  running  stillmaybe  feeling  sameso  itor  admiti  madthen  correctionor  let  call  lifeand  keep  running  worldmay  u  r  also  runninglets  run',
#  'got  look  scrumptious  daddy  want  eat  night  long',
#  'co  lar  im  ba  dao  ok  pm  lor  u  never  ask  go  ah  said  u  would  ask  fri  said  u  ask  today',
#  'alright  omw  gotta  change  order  halfth',
#  'exactly  anyways  far  jide  study  visiting',
#  'dunno  u  ask',
#  'email  alertfrom  jeri  stewartsize  kbsubject  lowcost  prescripiton  drvgsto  listen  email  call',
#  'didnt  spring  coming  early  yay',
#  'lol  wont  feel  bad  use  money  take  steak  dinner',
#  'even  u  dont  get  trouble  convincingjust  tel  twice  tel  neglect  msg  dont  c  read  itjust  dont  reply',
#  'leaving  qatar  tonite  search  opportunityall  went  fastpls  add  ur  prayer  dearrakhesh',
#  'one  talking',
#  'thanks  looking  really  appreciate',
#  'hi  customer  loyalty  offerthe  new  nokia  mobile  txtauction  txt  word  start  get  tctxt  tc  pmtmsg',
#  'wish',
#  'haha  mayb  ure  rite  u  know  well  da  feeling  liked  someone  gd  lor  u  faster  go  find  one  gal  group  attached  liao',
#  'yes  glad  made',
#  'well  little  time  thing  good  time  ahead',
#  'got  room  soon  hadnt  put  clock  back  til  shouted  everyone  get  realised  wahay  another  hour  bed',
#  'ok  may  free  gym',
#  'men  like  shorter  lady  gaze  eye',
#  'dunno  jus  say  go  lido  time',
#  'promise  take  good  care  princess  run  please  send  pic  get  chance  ttyl',
#  'u  subscribed  best  mobile  content  service  uk  per  day  send  stop  helpline',
#  'reason  weve  spoken  year  anyways  great  week  best  exam',
#  'monday  next  week  give  full  gist',
#  'realize  year  well  thousand  old  lady  running  around  tattoo',
#  'important  customer  service  announcement  premier',
#  'dont  gimme  lip  caveboy',
#  'get  library',
#  'realy  sorryi  dont  recognise  number  confused  r  u  please',
#  'didnt  holla',
#  'cant  think  anyone  spare  room  top  head',
#  'faith  make  thing  possiblehope  make  thing  worklove  make  thing  beautifulmay  three  christmasmerry  christmas',
#  'u  made  appointment',
#  'call  youcarlos  isare  phone  vibrate  acting  might  hear  text',
#  'romantic  paris  night  flight  book  next  year  call  tscs  apply',
#  'grandma  oh  dear  u  still  ill  felt  shit  morning  think  hungover  another  night  leave  sat',
# ...
#  'lol  know  theyre  dramatic  school  already  closed  tomorrow  apparently  cant  drive  inch  snow  supposed  get',
#  'getting  anywhere  damn  job  hunting',
#  'lol  u  drunkard  hair  moment  yeah  still  tonight  wats  plan',
#  'idc  get  weaseling  way  shit  twice  row',
#  'wil  ltgt  minute  got  space',
#  'sleepingand  surfing',
#  'thanks  picking  trash',
#  'dont  go  tell  friend  youre  sure  want  live  smoke  much  spend  hour  begging  come  smoke',
#  'hi  kate  lovely  see  tonight  ill  phone  tomorrow  got  sing  guy  gave  card  xxx',
#  'happy  new  year  dear  brother  really  miss  got  number  decided  send  text  wishing  happiness  abiola',
#  'mean  get  door',
#  'opinion  jada  kusruthi  lovable  silent  spl  character  matured  stylish  simple  pls  reply',
#  'hmmm  thought  said  hour  slave  late  punish',
#  'beerage',
#  'important  customer  service  announcement  premier  call  freephone',
#  'dont  think  turn  like  randomlly  within  min  opening',
#  'supposed  couldnt  make  shes  still  town  though',
#  'time  fix  spelling  sometimes  get  completely  diff  word  go  figure',
#  'ever  thought  living  good  life  perfect  partner  txt  back  name  age  join  mobile  community  psms',
#  'free  top  polyphonic  tone  call  national  rate  get  toppoly  tune  sent  every  week  text  subpoly  per  pole  unsub',
#  'gud  mrng  dear  hav  nice  day',
#  'hoping  enjoyed  game  yesterday  sorry  ive  touch  pls  know  fondly  bein  thot  great  week  abiola',
#  'e  best  ur  driving  tmr',
#  'ywhere  u  dogbreath  sounding  like  jan  c  thats  al',
#  'omg  want  scream  weighed  lost  weight  woohoo',
#  'generally  isnt  one  uncountable  noun  u  dictionary  piece  research',
#  'really  getting  hanging  around',
#  'orange  customer  may  claim  free  camera  phone  upgrade  loyalty  call  offer  end  thmarch  tc  apply  optout  availa',
#  'petey  boy  whereare  friendsare  thekingshead  come  canlove  nic',
#  'ok  msg  u  b  leave  house',
#  'gimme  ltgt  minute  ago',
#  'last  chance  claim  ur  worth  discount  voucher  today  text  shop  savamob  offer  mobile  c  savamob  pobox  muz  sub',
#  'appt  lttimegt  fault  u  dont  listen  told  u  twice',
#  'free  st  week  nokia  tone  ur  mobile  every  week  txt  nokia  get  txting  tell  ur  mate  wwwgetzedcouk  pobox  wwq  normptone',
#  'guaranteed  award  even  cashto  claim  ur  award  call  free  stop  getstop  php  rg  jx',
#  'k  ill',
#  'dled  imp',
#  'sure  make  sure  know  aint  smokin  yet',
#  'boooo  always  work  quit',
#  'taking  half  day  leave  bec  well',
#  'ugh  dont  wanna  get  bed  warm',
#  'ssnervous  ltgt',
#  'there  ring  come  guy  costume  gift  future  yowifes  hint  hint',
#  'congratulation  ur  awarded  either  cd  gift  voucher  free  entry  weekly  draw  txt  music  tncs  wwwldewcomwinppmxage',
#  'borrow  ur  bag  ok',
#  'u  outbid  simonwatson  shinco  dvd  plyr  bid  visit  sm  acsmsrewards  end  bid  notification  reply  end',
#  'wheres  boytoy  miss  happened',
#  'lot  used  one  babe  model  doesnt  help  youi  bring  hell  match',
#  'also  bringing  galileo  dobby',
#  'responding',
#  'boo  babe  u  enjoyin  yourjob  u  seemed  b  gettin  well  hunnyhope  ure  oktake  care  illspeak  u  soonlots  loveme  xxxx',
#  'good  afternoon  starshine  hows  boytoy  crave  yet  ache  fuck  sip  cappuccino  miss  babe  teasing  kiss',
#  'road  cant  txt',
#  'smsservices  yourinclusive  text  credit  pls  goto  wwwcomuknet  login  qxj  unsubscribe  stop  extra  charge  help  comuk  cm  ae',
#  'p  alfie  moon  child  need  song  ur  mob  tell  ur  m  txt  tone  charity  nokias  poly  charity  polys  zed  profit  charity',
#  'good  evening  ttyl',
#  'hmm  bit  piece  lol  sigh',
#  'hahahause  brain  dear',
#  'hey  got  mail',
#  'sorry  light  turned  green  meant  another  friend  wanted  ltgt  worth  may  around',
#  'thanks  yesterday  sir  wonderful  hope  enjoyed  burial  mojibiola',
#  'u  secret  admirer  reveal  think  u  r  special  call  opt  reply  reveal  stop  per  msg  recd  cust  care',
#  'hi  mate  rv  u  hav  nice  hol  message  say  hello  coz  havent  sent  u  age  started  driving  stay  roadsrvx',
#  'dear  voucher  holder  claim  week  offer  pc  please  go  httpwwwetlpcoukexpressoffer  tscs  apply  stop  text  txt  stop',
#  'thank  much  skyped  wit  kz  sura  didnt  get  pleasure  company  hope  good  weve  given  ultimatum  oh  countin  aburo  enjoy  message  sent  day  ago',
#  'surely  result  offer',
#  'good  morning  dear  great  amp  successful  day',
#  'want  anytime  network  min  text  new  video  phone  five  pound  per  week  call  reply  delivery  tomorrow',
#  'sir  late  paying  rent  past  month  pay  ltgt  charge  felt  would  inconsiderate  nag  something  give  great  cost  thats  didnt  speak  however  recession  wont  able  pay  charge  month  hence  askin  well  ahead  month  end  please  help  thanks',
#  'tried  contact  offer  new  video  phone  anytime  network  min  half  price  rental  camcorder  call  reply  delivery  wed',
#  'last  chance  claim  ur  worth  discount  voucherstext  yes  nowsavamobmember  offer  mobile  c  sub  remove  txt  x  stop',
#  'luv  u  soo  much  u  dont  understand  special  u  r  ring  u  morrow  luv  u  xxx',
#  'pls  send  comprehensive  mail  im  paying  much',
#  'prashanthettans  mother  passed  away  last  night  pray  family',
#  'urgent  call  landline  complimentary  ibiza  holiday  cash  await  collection  sae  tc  po  box  sk  wp  ppm',
#  'kkwhen  going',
#  'meanwhile  shit  suite  xavier  decided  give  u  ltgt  second  warning  samantha  coming  playing  jay  guitar  impress  shit  also  dont  think  doug  realizes  dont  live  anymore',
#  'stomach  thru  much  trauma  swear  cant  eat  better  lose  weight',
#  'officewhats  mattermsg  nowi  call  break',
#  'yeah  there  barely  enough  room  two  u  x  many  fucking  shoe  sorry  man  see  later',
#  'today  offer  claim  ur  worth  discount  voucher  text  yes  savamob  member  offer  mobile  c  sub  unsub  reply  x',
#  'u  reach  orchard  already  u  wan  go  buy  ticket  first',
#  'real  baby  want  bring  inner  tigress',
#  'da  run  activate  full  version  da',
#  'ah  poor  babyhope  urfeeling  bettersn  luv  probthat  overdose  work  hey  go  careful  spk  u  sn  lot  lovejen  xxx',
#  'stop  story  ive  told  ive  returned  he  saying  order',
#  'talk  sexy  make  new  friend  fall  love  world  discreet  text  dating  service  text  vip  see  could  meet',
#  'going  take  babe',
#  'hai  ana  tomarrow  coming  morning  ltdecimalgt  ill  sathy  go  rto  office  reply  came  home',
#  'spoon  okay',
#  'say  somebody  named  tampa',
#  'work  going  min',
#  'brother  genius',
#  'sorry  guess  whenever  get  hold  connection  maybe  hour  two  ill  text',
#  'u  find  time  bus  coz  need  sort  stuff',
#  'dude  ive  seeing  lotta  corvette  lately',
#  'congratulation  ur  awarded  either  yr  supply  cd  virgin  record  mystery  gift  guaranteed  call  tscs  wwwsmsconet  pm  approx  min',
#  'consider  wall  bunker  shit  important  never  play  peaceful  guess  place  high  enough  dont  matter',
#  'private  account  statement  xxxxxx  show  unredeemed  point  call  identifier  code  expires',
#  'hello  need  posh  bird  chap  user  trial  prod  champneys  put  need  address  dob  asap  ta  r',
#  'u  want  xmas  free  text  message  new  video  phone  half  price  line  rental  call  free  find',
#  'well  officially  philosophical  hole  u  wanna  call  home  ready  saved',
#  'going  goodno  problembut  still  need  little  experience  understand  american  customer  voice',
#  'ill  text  drop  x',
#  'ugh  long  day  im  exhausted  want  cuddle  take  nap',
#  'talk  atleast  day  otherwise  miss  best  friend  world  shakespeare  shesil  ltgt',
#  'shop  till  u  drop  either  k  k  cash  travel  voucher  call  ntt  po  box  crbt  fixedline  cost  ppm  mobile  vary',
#  'castor  need  see  something',
#  'sunshine  quiz  wkly  q  win  top  sony  dvd  player  u  know  country  liverpool  played  mid  week  txt  ansr  sptyrone',
#  'u  secret  admirer  looking  make  contact  ufind  rreveal  think  ur  specialcall',
#  'u  secret  admirer  looking  make  contact  ufind  rreveal  think  ur  specialcall  stopsms',
#  'reminder  downloaded  content  already  paid  goto  httpdoit  mymoby  tv  collect  content',
#  'see  knew  giving  break  time  woul  lead  always  wanting  miss  curfew  gonna  gibe  til  one  midnight  movie  gonna  get  til  need  come  home  need  getsleep  anything  need  b  studdying  ear  training',
#  'love  give  massage  use  lot  baby  oil  fave  position',
#  'dude  go  sup',
#  'yoyyooo  u  know  change  permission  drive  mac  usb  flash  drive',
#  'gibbs  unsoldmike  hussey',
#  'like  talk  pa  able  dont  know',
#  'dun  cut  short  leh  u  dun  like  ah  failed  shes  quite  sad',
#  'unbelievable  faglord',
#  'wifehow  knew  time  murder  exactly',
#  'ask  princess',
#  'great  princess  thinking',
#  'nutter  cutter  ctter  cttergg  cttargg  ctargg  ctagg  ie',
#  'ok  noe  ure  busy  im  really  bored  msg  u  oso  dunno  wat  colour  choose  one',
#  'doesnt  g  class  early  tomorrow  thus  shouldnt  trying  smoke  ltgt',
#  'superb  thought  grateful  u  dont  everything  u  want  mean  u  still  opportunity  happier  tomorrow  u  today',
#  'hope  good  week  checking',
#  'im  used  hope  agent  dont  drop  since  ive  booked  thing  year  whole  boston  nyc  experiment',
#  'thursday  night  yeah  sure  thing  well  work',
#  'probably  money  worry  thing  coming  due  several  outstanding  invoice  work  two  three  month  ago',
#  'possible  teach',
#  'wonder  phone  battery  went  dead  tell  love  babe',
#  'lovely  smell  bus  aint  tobacco',
#  'getting  worried  derek  taylor  already  assumed  worst',
#  'hey  whats  charles  sorry  late  reply',
#  'lastest  stereophonics  marley  dizzee  racal  libertine  stroke  win  nookii  game  flirt  click  themob  wap  bookmark  text  wap',
#  'ill  give  plus  said  grinule  greet  whenever  speak',
#  'white  fudge  oreo  store',
#  'january  male  sale  hot  gay  chat  cheaper  call  national  rate  pmin  cheap  pmin  peak  stop  text  call  pmin',
#  'love  come  took  long  leave  zahers  got  word  ym  happy  see  sad  left  miss',
#  'sorry  hurt',
#  'cant  feel  nauseous  im  pissed  didnt  eat  sweet  week  cause  today  planning  pig  dieting  week  im  hungry',
#  'ok  lor  early  still  project  meeting',
#  'call  da  waiting  call',
#  'could  ask  carlos  could  get  anybody  else  chip',
#  'actually  send  reminder  today  wonderful  weekend',
#  'people  see  msg  think  iam  addicted  msging  wrong  bcoz  dont  know  iam  addicted  sweet  friend  bslvyl',
#  'hey  gave  photo  registered  driving  ah  tmr  wanna  meet  yck',
#  'dont  talk  ever  ok  word',
#  'u  wana  see',
#  'way  school  pls  send  ashleys  number',
#  'shall  fine  avalarr  hollalater',
#  'went  attend  another  two  round  todaybut  still  didt  reach  home',
#  'actually  deleted  old  websitenow  blogging  magicalsongsblogspotcom',
#  'k  wait  chikkuil  send  aftr  ltgt  min',
#  'im  diet  ate  many  slice  pizza  yesterday  ugh  im  always  diet',
#  'ki  give  kvb  acc  detail',
#  'oh  come  ah',
#  'money  r  lucky  winner  claim  prize  text  money  million  give  away  pptxnormal  text  rate  box  wtjy',
#  'im  really  sorry  wont  b  able  fridayhope  u  find  alternativehope  yr  term  going  ok',
#  'congratulation  ore  mo  owo  wa  enjoy  wish  many  happy  moment  fro  wherever  go',
#  'samus  shoulder  yet',
#  'time  think  youll  need  know  near  campus',
#  'dear  matthew  please  call  landline  complimentary  lux  tenerife  holiday  cash  await  collection  ppm  sae  tc  box  skxh',
#  'dun  wear  jean  lor',
#  'since  side  fever  vomitin',
#  'kkare  college',
#  'urgent  call  landline  complimentary  tenerife  holiday  cash  await  collection  sae  tc  box  hp  yf  ppm',
#  'better  made  friday  stuffed  like  pig  yesterday  feel  bleh  least  writhing  pain  kind  bleh',
#  'sell  well  ton  coin  sell  coin  someone  thru  paypal  voila  money  back  life  pocket',
#  'theyre  lot  place  hospital  medical  place  safe',
#  'getting  touch  folk  waiting  company  txt  back  name  age  opt  enjoy  community  psms',
#  'also  ive  sorta  blown  couple  time  recently  id  rather  text  blue  looking  weed',
#  'sent  score  sophas  secondary  application  school  think  thinking  applying  research  cost  also  contact  joke  ogunrinde  school  one  less  expensive  one',
#  'cant  wait  see  photo  useful',
#  'ur  cashbalance  currently  pound  maximize  ur  cashin  send  go  pmsg  cc  po  box  tcrw',
#  'hey  booked  kb  sat  already  lesson  going  ah  keep  sat  night  free  need  meet  confirm  lodging',
#  'chk  ur  belovd  m  dict',
#  'time  want  come',
#  'awesome  lemme  know  whenever  youre  around',
#  'shb  b  ok  lor  thanx',
#  'beautiful  truth  gravity  read  carefully  heart  feel  light  someone  feel  heavy  someone  leaf  good  night',
#  'also  remember  get  dobbys  bowl  car',
#  'filthy  story  girl  waiting',
#  'sorry  c  ur  msg  yar  lor  poor  thing  one  night  tmr  ull  brand  new  room  sleep',
#  'love  isnt  decision  feeling  could  decide  love  life  would  much  simpler  less  magical',
#  'welp  apparently  retired',
#  'sort  code  acc  bank  natwest  reply  confirm  ive  sent  right  person',
#  '',
#  'u  sure  u  cant  take  sick  time',
#  'urgent  trying  contact  u  today  draw  show  prize  guaranteed  call  land  line  claim  validhrs',
#  'watching  cartoon  listening  music  amp  eve  go  temple  amp  church  u',
#  'yo  chad  gymnastics  class  wanna  take  site  say  christian  class  full',
#  'much  buzy',
#  'better  still  catch  let  ask  sell  ltgt',
#  'sure  night  menu  know  noon  menu',
#  'u  want  come  backa  beautiful  necklace  token  heart  youthats  give  wife  likingbe  seeno  one  give  thatdont  call  mei  wait  till  come',
#  'willing  go  aptitude  class',
#  'wont  b  trying  sort  house  ok',
#  'yar  lor  wan  go  c  horse  racing  today  mah  eat  earlier  lor  ate  chicken  rice  u',
#  'haha  awesome  omw  back',
#  'yup  thk  e  shop  close  lor',
#  'account  number',
#  'eh  u  send  wrongly  lar',
#  'hey  ad  crap  nite  borin  without  ya  boggy  u  boring  biatch  thanx  u  wait  til  nxt  time  il  ave  ya',
#  'ok  shall  talk',
#  'dont  hesitate  know  second  time  weakness  like  keep  notebook  eat  day  anything  changed  day  sure  nothing',
#  'hey  pay  salary  de  ltgt',
#  'another  month  need  chocolate  weed  alcohol',
#  'started  searching  get  job  dayshe  great  potential  talent',
#  'reckon  need  town  eightish  walk  carpark',
#  'congrats  mobile  g  videophones  r  call  videochat  wid  mate  play  java  game  dload  polyph  music  noline  rentl',
#  'look  fuckin  time  fuck  think',
#  'yo  guess  dropped',
#  'carlos  say  hell  mu  ltgt  minute',
#  'im  office  call  ltgt  min',
#  'geeee  miss  already  know  think  fuck  cant  wait  till  next  year  together  loving  kiss',
#  'yun  ahthe  ubi  one  say  wan  call  tomorrowcall  look  ireneere  got  bus  ubi  cresubi  tech  parkph  st  wkg  daysn',
#  'ugh  gotta  drive  back  sd  la  butt  sore',
#  'th  july',
#  'hi  im  relaxing  time  ever  get  every  day  party  good  night  get  home  tomorrow  ish',
#  'wan  come  come  lor  din  c  stripe  skirt',
#  'xmas  story  peace  xmas  msg  love  xmas  miracle  jesus  hav  blessed  month  ahead  amp  wish  u  merry  xmas',
#  'cant  dont  number',
#  'change  e  one  next  escalator',
#  'yetunde  im  class  run  water  make  ok  pls',
#  'lot  happened  feel  quiet  beth  aunt  charlie  working  lot  helen  mo',
#  'wait  bus  stop  aft  ur  lect  lar  dun  c  go  get  car  come  back  n  pick',
#  'aight  thanks  comin',
#  'nobut  heard  abt  tat',
#  'please  call  customer  service  representative  freephone  ampm  guaranteed  cash  prize',
#  'yeshe  really  greatbhaji  told  kallis  best  cricketer  sachin  worldvery  tough  get',
#  'ltgt  think  say  syllabus',
#  'umma  say  anything',
#  'give  sec  think  think',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=2500, binary=True)

X = cv.fit_transform(tokenized_messages)

cv.vocabulary_
# Out:
# {'go': np.int64(877),
#  'point': np.int64(1623),
#  'crazy': np.int64(489),
#  'available': np.int64(144),
#  'bugis': np.int64(280),
#  'great': np.int64(901),
#  'world': np.int64(2436),
#  'la': np.int64(1146),
#  'buffet': np.int64(279),
#  'cine': np.int64(407),
#  'got': np.int64(893),
#  'wat': np.int64(2361),
#  'ok': np.int64(1478),
#  'lar': np.int64(1155),
#  'joking': np.int64(1098),
#  'wif': np.int64(2401),
#  'oni': np.int64(1488),
#  'free': np.int64(809),
#  'entry': np.int64(666),
#  'wkly': np.int64(2422),
#  'comp': np.int64(443),
#  'win': np.int64(2406),
#  'cup': np.int64(501),
#  'final': np.int64(751),
#  'tkts': np.int64(2197),
#  'st': np.int64(2021),
#  'may': np.int64(1304),
#  'text': np.int64(2149),
#  'receive': np.int64(1730),
#  'txt': np.int64(2257),
#  'apply': np.int64(100),
#  'dun': np.int64(625),
#  'say': np.int64(1832),
#  'early': np.int64(630),
#  'already': np.int64(66),
#  'nah': np.int64(1408),
#  'dont': np.int64(602),
#  'think': np.int64(2171),
#  'usf': np.int64(2298),
#  'life': np.int64(1195),
#  'around': np.int64(117),
#  'though': np.int64(2178),
#  'freemsg': np.int64(813),
#  'hey': np.int64(958),
#  'darling': np.int64(525),
#  'week': np.int64(2378),
#  'word': np.int64(2432),
#  'back': np.int64(157),
#  'id': np.int64(1020),
#  'like': np.int64(1201),
#  'fun': np.int64(838),
#  'still': np.int64(2037),
#  'tb': np.int64(2115),
#  'xxx': np.int64(2465),
#  'std': np.int64(2035),
#  'send': np.int64(1864),
#  'rcv': np.int64(1712),
#  'even': np.int64(680),
#  'brother': np.int64(266),
#  'speak': np.int64(2004),
#  'treat': np.int64(2235),
#  'per': np.int64(1557),
#  'request': np.int64(1765),
#  'melle': np.int64(1321),
#  'oru': np.int64(1509),
#  'minnaminunginte': np.int64(1343),
#  'nurungu': np.int64(1464),
#  'vettam': np.int64(2317),
#  'set': np.int64(1874),
#  'callertune': np.int64(315),
#  'caller': np.int64(314),
#  'press': np.int64(1652),
#  'copy': np.int64(469),
#  'friend': np.int64(822),
#  'winner': np.int64(2410),
#  'valued': np.int64(2311),
#  'network': np.int64(1428),
#  'customer': np.int64(506),
#  'selected': np.int64(1857),
#  'prize': np.int64(1660),
#  'reward': np.int64(1778),
#  'claim': np.int64(411),
#  'call': np.int64(309),
#  'code': np.int64(427),
#  'valid': np.int64(2307),
#  'hour': np.int64(997),
#  'mobile': np.int64(1358),
#  'month': np.int64(1373),
#  'entitled': np.int64(665),
#  'update': np.int64(2284),
#  'latest': np.int64(1160),
#  'colour': np.int64(436),
#  'camera': np.int64(329),
#  'co': np.int64(425),
#  'im': np.int64(1029),
#  'gonna': np.int64(885),
#  'home': np.int64(982),
#  'soon': np.int64(1988),
#  'want': np.int64(2354),
#  'talk': np.int64(2106),
#  'stuff': np.int64(2056),
#  'anymore': np.int64(88),
#  'tonight': np.int64(2215),
#  'ive': np.int64(1076),
#  'enough': np.int64(662),
#  'today': np.int64(2204),
#  'six': np.int64(1940),
#  'chance': np.int64(374),
#  'cash': np.int64(354),
#  'pound': np.int64(1641),
#  'cost': np.int64(472),
#  'pday': np.int64(1549),
#  'day': np.int64(531),
#  'reply': np.int64(1761),
#  'hl': np.int64(969),
#  'info': np.int64(1044),
#  'urgent': np.int64(2290),
#  'membership': np.int64(1323),
#  'tc': np.int64(2116),
#  'pobox': np.int64(1619),
#  'searching': np.int64(1845),
#  'right': np.int64(1781),
#  'thank': np.int64(2157),
#  'promise': np.int64(1668),
#  'wont': np.int64(2431),
#  'take': np.int64(2102),
#  'help': np.int64(956),
#  'wonderful': np.int64(2429),
#  'blessing': np.int64(220),
#  'time': np.int64(2192),
#  'date': np.int64(528),
#  'sunday': np.int64(2075),
#  'use': np.int64(2295),
#  'credit': np.int64(492),
#  'click': np.int64(416),
#  'wap': np.int64(2357),
#  'link': np.int64(1206),
#  'next': np.int64(1434),
#  'message': np.int64(1327),
#  'oh': np.int64(1476),
#  'watching': np.int64(2363),
#  'eh': np.int64(643),
#  'remember': np.int64(1751),
#  'spell': np.int64(2009),
#  'name': np.int64(1410),
#  'yes': np.int64(2478),
#  'naughty': np.int64(1418),
#  'make': np.int64(1277),
#  'wet': np.int64(2388),
#  'fine': np.int64(754),
#  'thats': np.int64(2162),
#  'way': np.int64(2366),
#  'feel': np.int64(736),
#  'england': np.int64(658),
#  'miss': np.int64(1347),
#  'news': np.int64(1433),
#  'ur': np.int64(2288),
#  'national': np.int64(1414),
#  'team': np.int64(2123),
#  'eg': np.int64(641),
#  'scotland': np.int64(1839),
#  'seriously': np.int64(1872),
#  'going': np.int64(882),
#  'try': np.int64(2244),
#  'ha': np.int64(915),
#  'pay': np.int64(1543),
#  'first': np.int64(759),
#  'da': np.int64(512),
#  'stock': np.int64(2038),
#  'comin': np.int64(439),
#  'aft': np.int64(40),
#  'finish': np.int64(756),
#  'lunch': np.int64(1261),
#  'str': np.int64(2046),
#  'lor': np.int64(1234),
#  'ard': np.int64(108),
#  'smth': np.int64(1969),
#  'alright': np.int64(67),
#  'meet': np.int64(1315),
#  'sooner': np.int64(1989),
#  'eat': np.int64(634),
#  'slice': np.int64(1954),
#  'really': np.int64(1725),
#  'hungry': np.int64(1009),
#  'tho': np.int64(2177),
#  'suck': np.int64(2068),
#  'mark': np.int64(1289),
#  'getting': np.int64(868),
#  'worried': np.int64(2437),
#  'know': np.int64(1142),
#  'sick': np.int64(1920),
#  'turn': np.int64(2252),
#  'pizza': np.int64(1591),
#  'lol': np.int64(1225),
#  'always': np.int64(70),
#  'catch': np.int64(358),
#  'bus': np.int64(288),
#  'egg': np.int64(642),
#  'tea': np.int64(2120),
#  'eating': np.int64(637),
#  'mom': np.int64(1366),
#  'left': np.int64(1179),
#  'dinner': np.int64(579),
#  'love': np.int64(1245),
#  'amp': np.int64(76),
#  'car': np.int64(341),
#  'ill': np.int64(1028),
#  'let': np.int64(1188),
#  'there': np.int64(2166),
#  'room': np.int64(1794),
#  'work': np.int64(2433),
#  'wait': np.int64(2340),
#  'clear': np.int64(415),
#  'sure': np.int64(2087),
#  'sarcastic': np.int64(1822),
#  'doesnt': np.int64(595),
#  'live': np.int64(1213),
#  'yeah': np.int64(2474),
#  'child': np.int64(396),
#  'caught': np.int64(360),
#  'till': np.int64(2191),
#  'cheer': np.int64(392),
#  'tell': np.int64(2133),
#  'anything': np.int64(91),
#  'fear': np.int64(732),
#  'quick': np.int64(1690),
#  'thanks': np.int64(2158),
#  'subscription': np.int64(2065),
#  'ringtone': np.int64(1783),
#  'uk': np.int64(2266),
#  'charged': np.int64(380),
#  'please': np.int64(1602),
#  'confirm': np.int64(454),
#  'replying': np.int64(1762),
#  'yup': np.int64(2498),
#  'look': np.int64(1230),
#  'timing': np.int64(2193),
#  'msg': np.int64(1394),
#  'xuhui': np.int64(2463),
#  'learn': np.int64(1173),
#  'nd': np.int64(1419),
#  'lesson': np.int64(1187),
#  'oops': np.int64(1492),
#  'roommate': np.int64(1795),
#  'done': np.int64(601),
#  'see': np.int64(1851),
#  'letter': np.int64(1189),
#  'decide': np.int64(541),
#  'hello': np.int64(955),
#  'hows': np.int64(1001),
#  'saturday': np.int64(1826),
#  'texting': np.int64(2152),
#  'youd': np.int64(2491),
#  'decided': np.int64(542),
#  'tomo': np.int64(2212),
#  'trying': np.int64(2245),
#  'invite': np.int64(1061),
#  'pls': np.int64(1607),
#  'ahead': np.int64(47),
#  'wanted': np.int64(2355),
#  'weekend': np.int64(2379),
#  'abiola': np.int64(5),
#  'forget': np.int64(793),
#  'need': np.int64(1423),
#  'crave': np.int64(488),
#  'sweet': np.int64(2092),
#  'yummy': np.int64(2496),
#  'burn': np.int64(286),
#  'tried': np.int64(2237),
#  'sm': np.int64(1962),
#  'nokia': np.int64(1446),
#  'camcorder': np.int64(327),
#  'delivery': np.int64(552),
#  'tomorrow': np.int64(2213),
#  'seeing': np.int64(1852),
#  'hope': np.int64(988),
#  'man': np.int64(1282),
#  'well': np.int64(2384),
#  'ltgt': np.int64(1256),
#  'inch': np.int64(1036),
#  'callsmessagesmissed': np.int64(322),
#  'didnt': np.int64(564),
#  'get': np.int64(866),
#  'nigeria': np.int64(1438),
#  'fair': np.int64(713),
#  'hopefully': np.int64(989),
#  'tyler': np.int64(2262),
#  'cant': np.int64(340),
#  'could': np.int64(476),
#  'maybe': np.int64(1306),
#  'ask': np.int64(125),
#  'bit': np.int64(214),
#  'hospital': np.int64(993),
#  'kept': np.int64(1122),
#  'telling': np.int64(2134),
#  'weak': np.int64(2369),
#  'saw': np.int64(1831),
#  'class': np.int64(412),
#  'gram': np.int64(898),
#  'usually': np.int64(2302),
#  'run': np.int64(1805),
#  'half': np.int64(922),
#  'almost': np.int64(63),
#  'whole': np.int64(2399),
#  'second': np.int64(1848),
#  'fyi': np.int64(841),
#  'ride': np.int64(1780),
#  'morning': np.int64(1379),
#  'he': np.int64(944),
#  'place': np.int64(1592),
#  'wow': np.int64(2444),
#  'never': np.int64(1430),
#  'realized': np.int64(1724),
#  'embarassed': np.int64(650),
#  'thought': np.int64(2179),
#  'liked': np.int64(1202),
#  'since': np.int64(1929),
#  'best': np.int64(197),
#  'seemed': np.int64(1854),
#  'happy': np.int64(935),
#  'sorry': np.int64(1991),
#  'give': np.int64(873),
#  'ac': np.int64(9),
#  'new': np.int64(1431),
#  'red': np.int64(1736),
#  'play': np.int64(1597),
#  'ice': np.int64(1019),
#  'correct': np.int64(471),
#  'end': np.int64(652),
#  'yesterday': np.int64(2481),
#  'find': np.int64(753),
#  'lturlgt': np.int64(1258),
#  'congrats': np.int64(456),
#  'year': np.int64(2475),
#  'special': np.int64(2005),
#  'cinema': np.int64(408),
#  'pas': np.int64(1535),
#  'suprman': np.int64(2085),
#  'matrix': np.int64(1298),
#  'starwars': np.int64(2030),
#  'etc': np.int64(677),
#  'bxipwe': np.int64(298),
#  'pm': np.int64(1610),
#  'later': np.int64(1159),
#  'meeting': np.int64(1317),
#  'reached': np.int64(1716),
#  'series': np.int64(1870),
#  'pick': np.int64(1577),
#  'burger': np.int64(285),
#  'move': np.int64(1386),
#  'pain': np.int64(1522),
#  'killing': np.int64(1132),
#  'good': np.int64(886),
#  'joke': np.int64(1097),
#  'girl': np.int64(871),
#  'situation': np.int64(1939),
#  'part': np.int64(1532),
#  'checking': np.int64(391),
#  'iq': np.int64(1067),
#  'took': np.int64(2217),
#  'forever': np.int64(791),
#  'come': np.int64(437),
#  'double': np.int64(605),
#  'check': np.int64(389),
#  'hair': np.int64(920),
#  'dresser': np.int64(611),
#  'said': np.int64(1814),
#  'wun': np.int64(2450),
#  'cut': np.int64(507),
#  'short': np.int64(1906),
#  'nice': np.int64(1436),
#  'pleased': np.int64(1603),
#  'advise': np.int64(35),
#  'following': np.int64(783),
#  'recent': np.int64(1733),
#  'review': np.int64(1777),
#  'mob': np.int64(1357),
#  'awarded': np.int64(152),
#  'bonus': np.int64(231),
#  'song': np.int64(1985),
#  'valuable': np.int64(2309),
#  'frnds': np.int64(827),
#  'rply': np.int64(1800),
#  'complimentary': np.int64(448),
#  'trip': np.int64(2238),
#  'acoentry': np.int64(18),
#  'dis': np.int64(584),
#  'hear': np.int64(947),
#  'wah': np.int64(2339),
#  'lucky': np.int64(1260),
#  'save': np.int64(1829),
#  'money': np.int64(1370),
#  'hee': np.int64(951),
#  'finished': np.int64(757),
#  'hi': np.int64(961),
#  'babe': np.int64(155),
#  'wanna': np.int64(2353),
#  'something': np.int64(1981),
#  'xx': np.int64(2464),
#  'waiting': np.int64(2342),
#  'machan': np.int64(1267),
#  'cool': np.int64(468),
#  'gentleman': np.int64(862),
#  'dignity': np.int64(576),
#  'respect': np.int64(1767),
#  'people': np.int64(1556),
#  'much': np.int64(1398),
#  'shy': np.int64(1918),
#  'pa': np.int64(1517),
#  'looking': np.int64(1233),
#  'job': np.int64(1093),
#  'ta': np.int64(2099),
#  'ah': np.int64(45),
#  'stop': np.int64(2041),
#  'urgnt': np.int64(2293),
#  'real': np.int64(1721),
#  'yo': np.int64(2486),
#  'ticket': np.int64(2189),
#  'one': np.int64(1487),
#  'used': np.int64(2296),
#  'started': np.int64(2028),
#  'came': np.int64(328),
#  'bed': np.int64(184),
#  'coin': np.int64(429),
#  'gotta': np.int64(895),
#  'download': np.int64(606),
#  'wen': np.int64(2386),
#  'stand': np.int64(2023),
#  'close': np.int64(419),
#  'youll': np.int64(2492),
#  'another': np.int64(82),
#  'night': np.int64(1439),
#  'spent': np.int64(2012),
#  'late': np.int64(1158),
#  'afternoon': np.int64(41),
#  'mean': np.int64(1308),
#  'havent': np.int64(941),
#  'sheet': np.int64(1886),
#  'smile': np.int64(1965),
#  'pleasure': np.int64(1604),
#  'trouble': np.int64(2239),
#  'rain': np.int64(1700),
#  'sum': np.int64(2072),
#  'hurt': np.int64(1011),
#  'becoz': np.int64(183),
#  'someone': np.int64(1979),
#  'smiling': np.int64(1966),
#  'service': np.int64(1873),
#  'representative': np.int64(1764),
#  'ampm': np.int64(77),
#  'guaranteed': np.int64(908),
#  'planning': np.int64(1596),
#  'buy': np.int64(292),
#  'lido': np.int64(1193),
#  'show': np.int64(1913),
#  'abt': np.int64(7),
#  'load': np.int64(1217),
#  'loan': np.int64(1218),
#  'wk': np.int64(2419),
#  'hols': np.int64(981),
#  'forgot': np.int64(796),
#  'appointment': np.int64(101),
#  'four': np.int64(804),
#  'shower': np.int64(1914),
#  'cause': np.int64(361),
#  'prob': np.int64(1661),
#  'nothing': np.int64(1457),
#  'else': np.int64(646),
#  'okay': np.int64(1479),
#  'price': np.int64(1657),
#  'long': np.int64(1228),
#  'legal': np.int64(1181),
#  'ave': np.int64(146),
#  'gone': np.int64(884),
#  'driving': np.int64(616),
#  'test': np.int64(2147),
#  'yet': np.int64(2482),
#  'youre': np.int64(2493),
#  'guess': np.int64(910),
#  'gave': np.int64(851),
#  'boston': np.int64(241),
#  'men': np.int64(1324),
#  'changed': np.int64(376),
#  'search': np.int64(1844),
#  'location': np.int64(1220),
#  'nyc': np.int64(1468),
#  'cuz': np.int64(510),
#  'page': np.int64(1520),
#  'umma': np.int64(2268),
#  'vava': np.int64(2314),
#  'lot': np.int64(1240),
#  'dear': np.int64(536),
#  'wish': np.int64(2413),
#  'birthday': np.int64(212),
#  'making': np.int64(1278),
#  'truly': np.int64(2241),
#  'aight': np.int64(49),
#  'hit': np.int64(967),
#  'would': np.int64(2442),
#  'ip': np.int64(1065),
#  'address': np.int64(29),
#  'considering': np.int64(460),
#  'computer': np.int64(449),
#  'isnt': np.int64(1072),
#  'old': np.int64(1484),
#  'better': np.int64(199),
#  'worry': np.int64(2438),
#  'busy': np.int64(290),
#  'research': np.int64(1766),
#  'thing': np.int64(2170),
#  'scared': np.int64(1834),
#  'mah': np.int64(1273),
#  'loud': np.int64(1241),
#  'contact': np.int64(461),
#  'last': np.int64(1157),
#  'draw': np.int64(608),
#  'hr': np.int64(1003),
#  'ppm': np.int64(1645),
#  'wa': np.int64(2338),
#  'sentence': np.int64(1868),
#  'anyway': np.int64(93),
#  'juz': np.int64(1108),
#  'tt': np.int64(2248),
#  'eatin': np.int64(636),
#  'anythin': np.int64(90),
#  'happened': np.int64(931),
#  'entered': np.int64(664),
#  'cabin': np.int64(300),
#  'bday': np.int64(178),
#  'bos': np.int64(240),
#  'felt': np.int64(739),
#  'askd': np.int64(126),
#  'invited': np.int64(1062),
#  'apartment': np.int64(96),
#  'went': np.int64(2387),
#  'specially': np.int64(2007),
#  'holiday': np.int64(978),
#  'flight': np.int64(770),
#  'inc': np.int64(1035),
#  'operator': np.int64(1495),
#  'pmin': np.int64(1611),
#  'must': np.int64(1405),
#  'friday': np.int64(821),
#  'needed': np.int64(1424),
#  'uncle': np.int64(2271),
#  'informed': np.int64(1047),
#  'paying': np.int64(1545),
#  'school': np.int64(1837),
#  'directly': np.int64(582),
#  'food': np.int64(785),
#  'private': np.int64(1659),
#  'account': np.int64(15),
#  'statement': np.int64(2031),
#  'unredeemed': np.int64(2280),
#  'identifier': np.int64(1022),
#  'expires': np.int64(704),
#  'landline': np.int64(1153),
#  'voda': np.int64(2329),
#  'number': np.int64(1463),
#  'ending': np.int64(654),
#  'award': np.int64(151),
#  'match': np.int64(1295),
#  'quoting': np.int64(1696),
#  'standard': np.int64(2024),
#  'rate': np.int64(1709),
#  'app': np.int64(98),
#  'mu': np.int64(1397),
#  'buying': np.int64(294),
#  'hasnt': np.int64(938),
#  'sent': np.int64(1867),
#  'bother': np.int64(242),
#  'sending': np.int64(1865),
#  'shouldnt': np.int64(1911),
#  'apologise': np.int64(97),
#  'del': np.int64(547),
#  'bak': np.int64(160),
#  'kkhow': np.int64(1138),
#  'answer': np.int64(84),
#  'question': np.int64(1688),
#  'sunshine': np.int64(2077),
#  'quiz': np.int64(1694),
#  'top': np.int64(2218),
#  'sony': np.int64(1986),
#  'dvd': np.int64(627),
#  'player': np.int64(1599),
#  'country': np.int64(480),
#  'ansr': np.int64(83),
#  'sptyrone': np.int64(2020),
#  'laid': np.int64(1151),
#  'dogging': np.int64(597),
#  'direct': np.int64(581),
#  'join': np.int64(1095),
#  'largest': np.int64(1156),
#  'bt': np.int64(271),
#  'txting': np.int64(2260),
#  'nt': np.int64(1459),
#  'eca': np.int64(638),
#  'pmsgp': np.int64(1613),
#  'haf': np.int64(916),
#  'befor': np.int64(187),
#  'activity': np.int64(23),
#  'chat': np.int64(384),
#  'hardcore': np.int64(937),
#  'age': np.int64(43),
#  'yr': np.int64(2495),
#  'lazy': np.int64(1167),
#  'type': np.int64(2263),
#  'lect': np.int64(1177),
#  'sir': np.int64(1933),
#  'mail': np.int64(1274),
#  'tired': np.int64(2194),
#  'little': np.int64(1212),
#  'lovable': np.int64(1244),
#  'person': np.int64(1562),
#  'biggest': np.int64(205),
#  'heart': np.int64(949),
#  'gud': np.int64(909),
#  'ni': np.int64(1435),
#  'open': np.int64(1493),
#  'ya': np.int64(2469),
#  'dot': np.int64(604),
#  'whats': np.int64(2391),
#  'taking': np.int64(2104),
#  'replied': np.int64(1760),
#  'sexy': np.int64(1880),
#  'female': np.int64(740),
#  'local': np.int64(1219),
#  'luv': np.int64(1262),
#  'netcollex': np.int64(1427),
#  'ltd': np.int64(1254),
#  'begin': np.int64(188),
#  'qatar': np.int64(1685),
#  'pray': np.int64(1647),
#  'hard': np.int64(936),
#  'ki': np.int64(1126),
#  'deleted': np.int64(548),
#  'birla': np.int64(210),
#  'soft': np.int64(1974),
#  'wine': np.int64(2409),
#  'flowing': np.int64(776),
#  'thk': np.int64(2174),
#  'plaza': np.int64(1601),
#  'floor': np.int64(774),
#  'window': np.int64(2408),
#  'shirt': np.int64(1897),
#  'sometimes': np.int64(1983),
#  'dream': np.int64(609),
#  'without': np.int64(2417),
#  'joy': np.int64(1101),
#  'tv': np.int64(2253),
#  'become': np.int64(182),
#  'leaving': np.int64(1176),
#  'house': np.int64(998),
#  'interview': np.int64(1059),
#  'boy': np.int64(250),
#  'missing': np.int64(1349),
#  'arrange': np.int64(118),
#  'keep': np.int64(1118),
#  'safe': np.int64(1813),
#  'everyone': np.int64(686),
#  'hand': np.int64(924),
#  'spend': np.int64(2010),
#  'inviting': np.int64(1063),
#  'frnd': np.int64(826),
#  'order': np.int64(1503),
#  'content': np.int64(463),
#  'goto': np.int64(894),
#  'menu': np.int64(1325),
#  'module': np.int64(1364),
#  'wit': np.int64(2415),
#  'escape': np.int64(672),
#  'fancy': np.int64(717),
#  'completely': np.int64(447),
#  'formclark': np.int64(799),
#  'also': np.int64(69),
#  'waste': np.int64(2360),
#  'bank': np.int64(163),
#  'hmmm': np.int64(972),
#  'hop': np.int64(987),
#  'muz': np.int64(1406),
#  'discus': np.int64(586),
#  'liao': np.int64(1190),
#  'coming': np.int64(440),
#  'bloody': np.int64(223),
#  'hell': np.int64(953),
#  'believe': np.int64(192),
#  'mr': np.int64(1390),
#  'spanish': np.int64(2002),
#  'bath': np.int64(169),
#  'youve': np.int64(2494),
#  'carlos': np.int64(350),
#  'mall': np.int64(1281),
#  'staying': np.int64(2034),
#  'til': np.int64(2190),
#  'smoke': np.int64(1967),
#  'worth': np.int64(2440),
#  'log': np.int64(1221),
#  'spoke': np.int64(2014),
#  'maneesha': np.int64(1285),
#  'wed': np.int64(2374),
#  'satisfied': np.int64(1825),
#  'experience': np.int64(703),
#  'toll': np.int64(2209),
#  'offer': np.int64(1471),
#  'especially': np.int64(674),
#  'studying': np.int64(2055),
#  'anyways': np.int64(94),
#  'gr': np.int64(897),
#  'trust': np.int64(2242),
#  'guy': np.int64(913),
#  'working': np.int64(2435),
#  'towards': np.int64(2227),
#  'net': np.int64(1426),
#  'mummy': np.int64(1400),
#  'wheres': np.int64(2394),
#  'boytoy': np.int64(252),
#  'haha': np.int64(917),
#  'awesome': np.int64(154),
#  'minute': np.int64(1344),
#  'freephone': np.int64(814),
#  'xmas': np.int64(2461),
#  'radio': np.int64(1698),
#  'jus': np.int64(1107),
#  'bathe': np.int64(170),
#  'si': np.int64(1919),
#  'using': np.int64(2299),
#  'unique': np.int64(2276),
#  'th': np.int64(2155),
#  'august': np.int64(140),
#  'joined': np.int64(1096),
#  'touch': np.int64(2223),
#  'deal': np.int64(535),
#  'personal': np.int64(1563),
#  'finally': np.int64(752),
#  'course': np.int64(482),
#  'however': np.int64(1000),
#  'suggest': np.int64(2070),
#  'stay': np.int64(2033),
#  'able': np.int64(6),
#  'every': np.int64(684),
#  'settled': np.int64(1877),
#  'mrng': np.int64(1391),
#  'hav': np.int64(940),
#  'story': np.int64(2045),
#  'dead': np.int64(534),
#  'tmr': np.int64(2200),
#  'orchard': np.int64(1502),
#  'mrt': np.int64(1392),
#  'kate': np.int64(1113),
#  'evening': np.int64(681),
#  'found': np.int64(803),
#  'buck': np.int64(274),
#  'darlin': np.int64(524),
#  'college': np.int64(435),
#  'successfully': np.int64(2067),
#  'ltdecimalgt': np.int64(1255),
#  'balance': np.int64(161),
#  'transaction': np.int64(2232),
#  'goodmorning': np.int64(887),
#  'sleeping': np.int64(1951),
#  'dat': np.int64(527),
#  'oso': np.int64(1510),
#  'cannot': np.int64(338),
#  'oredi': np.int64(1505),
#  'straight': np.int64(2047),
#  'connection': np.int64(459),
#  'bill': np.int64(206),
#  'shoot': np.int64(1903),
#  'big': np.int64(203),
#  'ready': np.int64(1720),
#  'bruv': np.int64(268),
#  'break': np.int64(255),
#  'semester': np.int64(1862),
#  'noe': np.int64(1445),
#  'leh': np.int64(1182),
#  'sound': np.int64(1996),
#  'slept': np.int64(1953),
#  'past': np.int64(1540),
#  'easy': np.int64(633),
#  'exam': np.int64(693),
#  'march': np.int64(1288),
#  'gt': np.int64(907),
#  'atm': np.int64(135),
#  'register': np.int64(1742),
#  'called': np.int64(313),
#  'important': np.int64(1033),
#  'file': np.int64(748),
#  'system': np.int64(2098),
#  'repair': np.int64(1759),
#  'shop': np.int64(1904),
#  'happen': np.int64(929),
#  'romantic': np.int64(1792),
#  'nite': np.int64(1442),
#  'collect': np.int64(432),
#  'wwwtcbiz': np.int64(2456),
#  'optout': np.int64(1500),
#  'gbpmtmsg': np.int64(855),
#  'appreciate': np.int64(102),
#  'partner': np.int64(1533),
#  'career': np.int64(346),
#  'start': np.int64(2027),
#  'followed': np.int64(782),
#  'star': np.int64(2026),
#  'sign': np.int64(1924),
#  'company': np.int64(444),
#  'po': np.int64(1618),
#  'teacher': np.int64(2122),
#  'bcoz': np.int64(176),
#  'teach': np.int64(2121),
#  'walk': np.int64(2346),
#  'cross': np.int64(494),
#  'road': np.int64(1786),
#  'side': np.int64(1921),
#  'street': np.int64(2048),
#  'battery': np.int64(172),
#  'died': np.int64(567),
#  'flirt': np.int64(772),
#  'sam': np.int64(1819),
#  'penny': np.int64(1555),
#  'closer': np.int64(421),
#  'wil': np.int64(2404),
#  'reach': np.int64(1715),
#  'theory': np.int64(2165),
#  'argument': np.int64(113),
#  'loses': np.int64(1236),
#  'argue': np.int64(112),
#  'kick': np.int64(1127),
#  'secret': np.int64(1849),
#  'admirer': np.int64(30),
#  'ufind': np.int64(2264),
#  'rreveal': np.int64(1801),
#  'specialcall': np.int64(2006),
#  'tomarrow': np.int64(2211),
#  'laptop': np.int64(1154),
#  'case': np.int64(353),
#  'tel': np.int64(2131),
#  'avent': np.int64(147),
#  'shining': np.int64(1893),
#  'meant': np.int64(1309),
#  'told': np.int64(2208),
#  'face': np.int64(709),
#  'watch': np.int64(2362),
#  'fr': np.int64(805),
#  'thanx': np.int64(2160),
#  'everything': np.int64(687),
#  'uve': np.int64(2304),
#  'touched': np.int64(2224),
#  'website': np.int64(2373),
#  'slipper': np.int64(1958),
#  'asked': np.int64(127),
#  'kallis': np.int64(1110),
#  'bat': np.int64(168),
#  'inning': np.int64(1049),
#  'goodnight': np.int64(888),
#  'fix': np.int64(763),
#  'wake': np.int64(2344),
#  'dearly': np.int64(538),
#  'missed': np.int64(1348),
#  'sleep': np.int64(1950),
#  'congratulation': np.int64(457),
#  'cd': np.int64(364),
#  'voucher': np.int64(2336),
#  'gift': np.int64(869),
#  'music': np.int64(1404),
#  'tncs': np.int64(2201),
#  'wwwldewcomwinppmxage': np.int64(2454),
#  'ranjith': np.int64(1708),
#  'cal': np.int64(304),
#  'min': np.int64(1339),
#  'hold': np.int64(975),
#  'bcums': np.int64(177),
#  'angry': np.int64(80),
#  'wid': np.int64(2400),
#  'dnt': np.int64(592),
#  'coz': np.int64(484),
#  'childish': np.int64(397),
#  'true': np.int64(2240),
#  'showing': np.int64(1915),
#  'deep': np.int64(544),
#  'affection': np.int64(38),
#  'care': np.int64(344),
#  'kettoda': np.int64(1124),
#  'manda': np.int64(1284),
#  'shipping': np.int64(1896),
#  'wks': np.int64(2423),
#  'lemme': np.int64(1184),
#  'expect': np.int64(700),
#  'mmm': np.int64(1353),
#  'lover': np.int64(1248),
#  'video': np.int64(2319),
#  'handset': np.int64(927),
#  'anytime': np.int64(92),
#  'unlimited': np.int64(2279),
#  'parked': np.int64(1531),
#  'mini': np.int64(1342),
#  'shopping': np.int64(1905),
#  'disturb': np.int64(590),
#  'ring': np.int64(1782),
#  'horny': np.int64(991),
#  'naked': np.int64(1409),
#  'hot': np.int64(995),
#  'unsubscribe': np.int64(2283),
#  'dint': np.int64(580),
#  'wana': np.int64(2352),
#  'plan': np.int64(1594),
#  'choose': np.int64(403),
#  'club': np.int64(422),
#  'pwk': np.int64(1684),
#  'box': np.int64(247),
#  'flash': np.int64(768),
#  'jealous': np.int64(1089),
#  'single': np.int64(1931),
#  'chart': np.int64(382),
#  'quality': np.int64(1686),
#  'charge': np.int64(379),
#  'sorting': np.int64(1993),
#  'ended': np.int64(653),
#  'sunny': np.int64(2076),
#  'ray': np.int64(1711),
#  'leaf': np.int64(1172),
#  'blue': np.int64(225),
#  'bay': np.int64(173),
#  'hmv': np.int64(973),
#  'genuine': np.int64(864),
#  'infowwwpercentrealcom': np.int64(1048),
#  'might': np.int64(1335),
#  'bf': np.int64(201),
#  'handed': np.int64(925),
#  'celebration': np.int64(367),
#  'full': np.int64(836),
#  'swing': np.int64(2095),
#  'far': np.int64(720),
#  'okie': np.int64(1481),
#  'usual': np.int64(2300),
#  'passed': np.int64(1536),
#  'anybody': np.int64(87),
#  'throw': np.int64(2182),
#  'baby': np.int64(156),
#  'fone': np.int64(784),
#  'ge': np.int64(857),
#  'sense': np.int64(1866),
#  'gautham': np.int64(850),
#  'stupid': np.int64(2057),
#  'cam': np.int64(326),
#  'buzy': np.int64(295),
#  'accidentally': np.int64(14),
#  'tmobile': np.int64(2199),
#  'phone': np.int64(1572),
#  'upgrade': np.int64(2285),
#  'sim': np.int64(1926),
#  'card': np.int64(342),
#  'loyalty': np.int64(1251),
#  'unless': np.int64(2278),
#  'tease': np.int64(2125),
#  'cry': np.int64(497),
#  'die': np.int64(566),
#  'plz': np.int64(1609),
#  'rose': np.int64(1796),
#  'bslvyl': np.int64(269),
#  'coffee': np.int64(428),
#  'somebody': np.int64(1978),
#  'high': np.int64(963),
#  'shit': np.int64(1898),
#  'shocking': np.int64(1902),
#  'scary': np.int64(1835),
#  'imagine': np.int64(1030),
#  'def': np.int64(545),
#  'somewhere': np.int64(1984),
#  'taxi': np.int64(2113),
#  'meal': np.int64(1307),
#  'hide': np.int64(962),
#  'book': np.int64(233),
#  'friendship': np.int64(823),
#  'hanging': np.int64(928),
#  'themob': np.int64(2164),
#  'newest': np.int64(1432),
#  'selection': np.int64(1858),
#  'game': np.int64(843),
#  'tone': np.int64(2214),
#  'gossip': np.int64(892),
#  'sport': np.int64(2017),
#  'fit': np.int64(761),
#  'garage': np.int64(846),
#  'key': np.int64(1125),
#  'arent': np.int64(110),
#  'accept': np.int64(11),
#  'dayu': np.int64(532),
#  'sister': np.int64(1935),
#  'clos': np.int64(418),
#  'lvblefrnd': np.int64(1264),
#  'jstfrnd': np.int64(1103),
#  'cutefrnd': np.int64(509),
#  'lifpartnr': np.int64(1197),
#  'belovd': np.int64(195),
#  'swtheart': np.int64(2096),
#  'bstfrnd': np.int64(270),
#  'enemy': np.int64(655),
#  'smart': np.int64(1964),
#  'weekly': np.int64(2380),
#  'uz': np.int64(2305),
#  ...}
